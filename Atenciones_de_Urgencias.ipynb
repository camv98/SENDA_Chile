# %%
import pandas as pd

# %%
# !pip install chardet

import chardet

with open("AtencionesUrgencia2025.csv", 'rb') as f:
    result = chardet.detect(f.read(10000))
    print(result)
# Out:
# ...
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}

# %%
df = pd.read_csv("AtencionesUrgencia2025.csv", encoding='ISO-8859-1', sep=';')
df.head()
# Out:
#   IdEstablecimiento          NEstablecimiento  IdCausa  \
# 0            01-901  SAR E.U. Iris Véliz Hume       15
# 1            01-901  SAR E.U. Iris Véliz Hume       16
# 2            01-901  SAR E.U. Iris Véliz Hume       17
# 3            01-901  SAR E.U. Iris Véliz Hume       18
# 4            01-901  SAR E.U. Iris Véliz Hume       19
#
#                             GlosaCausa  Total  Menores_1  De_1_a_4  De_5_a_14  \
# 0                  Crisis hipertensiva      1          0         0          0
# 1                       Arritmia grave      0          0         0          0
# 2           Otras causas circulatorias      4          0         0          0
# 3  TOTAL TRAUMATISMOS Y ENVENENAMIENTO     14          1         1          1
# 4              Accidentes del tránsito      0          0         0          0
#
#    De_15_a_64  De_65_y_mas  ... semana  GLOSATIPOESTABLECIMIENTO  \
# 0           0            1  ...      4                       SAR
# ...

# %%
hospitales = pd.read_csv("hospitales_unicos_merge.csv", encoding='ISO-8859-1', sep=';')
hospitales.head()
# Out:
#                            Nombre Establecimiento
# 0  Hospital Dr. Ernesto Torres Galdames (Iquique)
# 1     Hospital Dr. Leonardo GuzmÃ¡n (Antofagasta)
# 2          Hospital Dr. Carlos Cisternas (Calama)
# 3         Hospital Dr. Marcos Macuada (Tocopilla)
# 4                          Hospital de Mejillones

# %%
establecimientos_validos = hospitales['Nombre Establecimiento'].unique()
df_filtrado = df[df['NEstablecimiento'].isin(establecimientos_validos)]

# %%
df_filtrado.head(10)
# Out:
#       IdEstablecimiento                                NEstablecimiento  \
# 14282            04-104  Hospital Dr. Manuel Magalhaes Medling (Huasco)
# 14283            04-104  Hospital Dr. Manuel Magalhaes Medling (Huasco)
# 14284            04-104  Hospital Dr. Manuel Magalhaes Medling (Huasco)
# 14285            04-104  Hospital Dr. Manuel Magalhaes Medling (Huasco)
# 14286            04-104  Hospital Dr. Manuel Magalhaes Medling (Huasco)
# 14287            04-104  Hospital Dr. Manuel Magalhaes Medling (Huasco)
# 14288            04-104  Hospital Dr. Manuel Magalhaes Medling (Huasco)
# 14289            04-104  Hospital Dr. Manuel Magalhaes Medling (Huasco)
# 14290            04-104  Hospital Dr. Manuel Magalhaes Medling (Huasco)
# 14291            04-104  Hospital Dr. Manuel Magalhaes Medling (Huasco)
#
#        IdCausa                                GlosaCausa  Total  Menores_1  \
# 14282        7               CAUSAS SISTEMA RESPIRATORIO      0          0
# ...

# %%
df_filtrado.to_csv("Atenciones_Urgencias_2025_Filtrado.csv", index=False, encoding="ISO-8859-1", sep=";")

# %%
lista_establecimientos = df_filtrado['NEstablecimiento'].dropna().unique().tolist()
len(lista_establecimientos)
# Out:
# 62
