# %% [markdown]
# ### Importaciones

# %%
import pandas as pd
from datetime import datetime
import pandas as pd
import numpy as np
import random
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV, train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %% [markdown]
# #
# Mes -> 	Fecha del mes en formato YYYY-MM-DD. Representa el mes al que corresponden los datos climáticos.
# temperature_2m_max	-> Temperatura máxima promedio del mes medida a 2 metros de altura, en grados Celsius (°C).
# temperature_2m_min -> Temperatura mínima promedio del mes, también a 2 metros de altura, en grados Celsius (°C).
# precipitation_sum -> Precipitación total del mes en milímetros (mm). Suma de toda el agua caída durante ese mes.
# winddirection_10m_dominant -> Dirección dominante del viento a 10 metros de altura, en grados. Se mide en sentido azimutal desde el norte. (Ej.: 0° = norte, 90° = este, etc.).
# SEREMI -> Nombre de la región sanitaria (SEREMI) a la que corresponde esta fila.

# %% [markdown]
# ### Creación de DataSet's de clima mensual por año y SEREMI:

# %%
# 1. Cargar todos los archivos seremi
seremi_data = {
    "2014": pd.read_csv("seremi_2014.csv"),
    "2015": pd.read_csv("seremi_2015.csv"),
    "2016": pd.read_csv("seremi_2016.csv"),
    "2017": pd.read_csv("seremi_2017.csv"),
    "2018": pd.read_csv("seremi_2018.csv"),
    "2019": pd.read_csv("seremi_2019.csv"),
    "2020": pd.read_csv("seremi_2020.csv"),
    "2021": pd.read_csv("seremi_2021.csv"),
    "2022": pd.read_csv("seremi_2022.csv"),
    "2023": pd.read_csv("seremi_2023.csv"),
    "2024": pd.read_csv("seremi_2024.csv"),
    "2025": pd.read_csv("seremi_2025.csv"),
}

# 2. Función para procesar cada dataset climático
def procesar_datasets_climaticos(seremi_data_dict):
    def grados_a_cardinal(grados):
        if pd.isna(grados):
            return None
        direcciones = ['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW']
        index = int((grados + 22.5) % 360 // 45)
        return direcciones[index]

    for año, df in seremi_data_dict.items():
        # Eliminar columna innecesaria
        if "Unnamed: 0" in df.columns:
            df = df.drop(columns=["Unnamed: 0"])

        # Crear columna cardinal
        if "winddirection_10m_dominant" in df.columns:
            df["wind_direction_cardinal"] = df["winddirection_10m_dominant"].apply(grados_a_cardinal)

        # Renombrar columnas
        df = df.rename(columns={
            "temperature_2m_max": "Temperatura Máxima",
            "temperature_2m_min": "Temperatura Mínima",
            "precipitation_sum": "Precipitaciones (suma)",
            "winddirection_10m_dominant": "Dirección Viento"
        })

        # Limpiar columna de grados si existe y renombrar cardinal
        if "Dirección Viento" in df.columns:
            df = df.drop(columns=["Dirección Viento"])
        if "wind_direction_cardinal" in df.columns:
            df = df.rename(columns={"wind_direction_cardinal": "Dirección del Viento"})

        # Guardar el dataframe procesado
        seremi_data_dict[año] = df

    return seremi_data_dict

# 3. Aplicar la función a todos los datasets climáticos
seremi_data = procesar_datasets_climaticos(seremi_data)

# 4. Verificar que todo esté correcto (opcional)
seremi_data["2015"].head(12)
# Out:
#            Mes  Temperatura Máxima  Temperatura Mínima  \
# 0   2015-01-01           12.277419            6.867742
# 1   2015-02-01           12.142857            7.100000
# 2   2015-03-01           11.561290            6.393548
# 3   2015-04-01            9.093333            4.446667
# 4   2015-05-01            5.935484            2.541935
# 5   2015-06-01            3.943333            1.150000
# 6   2015-07-01            3.032258           -0.138710
# 7   2015-08-01            4.180645            0.509677
# 8   2015-09-01            5.266667            1.120000
# 9   2015-10-01            8.925806            2.803226
# 10  2015-11-01            9.626667            4.630000
# 11  2015-12-01           11.200000            5.090323
#
#     Precipitaciones (suma)      SEREMI Dirección del Viento
# 0                     33.7  Magallanes                    W
# 1                     36.9  Magallanes                    W
# 2                     92.1  Magallanes                    W
# 3                     57.9  Magallanes                    W
# 4                    100.0  Magallanes                    S
# 5                     92.8  Magallanes                   SW
# 6                     98.4  Magallanes                   SW
# 7                     59.8  Magallanes                   SW
# 8                     46.0  Magallanes                   SW
# 9                     24.2  Magallanes                   SW
# 10                    44.3  Magallanes                    W
# 11                    26.0  Magallanes                    W

# %% [markdown]
# ### Creación de DataSet's sobre ocupación de camas por mes y por año según hospital:

# %%
# Archivos filtrados hospitalarios
archivos_filtrados = {
    "2014": "2014_filtrado.csv",
    "2015": "2015_filtrado.csv",
    "2016": "2016_filtrado.csv",
    "2017": "2017_filtrado.csv",
    "2018": "2018_filtrado.csv",
    "2019": "2019_filtrado.csv",
    "2020": "2020_filtrado.csv",
    "2021": "2021_filtrado.csv",
    "2022": "2022_filtrado.csv",
    "2023": "2023_filtrado.csv",
    "2024": "2024_filtrado.csv",
    "2025": "2025_filtrado.csv"
}

# Diccionario para guardar los dataframes ya limpios
filtrado_limpio = {}

# Abreviaturas de los meses
meses_abreviados = ['Ene', 'Feb', 'Mar', 'Abr', 'May', 'Jun',
                    'Jul', 'Ago', 'Sep', 'Oct', 'Nov', 'Dic']

# Columnas que se eliminarán si existen
columnas_a_eliminar = ["Cód. SS/SEREMI", "Cód. Estab.", "Cód. Nivel Cuidado", "Acum", "Año"]

# Procesamiento de los archivos
for año, archivo in archivos_filtrados.items():
    # Cargar CSV
    df = pd.read_csv(archivo)

    # Eliminar filas irrelevantes
    df = df[~df["Nombre Nivel Cuidado"].isin([
      "330 - Area Pensionado",
      "330 - Área Pensionado",
      "401 - Área Médica Adulto Cuidados Básicos",
      "402 - Área Médica Adulto Cuidados Medios",
      "403 - Área Médico-Quirúrgico Cuidados Básicos",
      "404 - Área Médico-Quirúrgico Cuidados Medios",
      "405 - Área Cuidados Intensivos Adultos",
      "406 - Área Cuidados Intermedios Adultos",
      "407 - Área Médica Pediátrica Cuidados Básicos",
      "408 - Área Médica Pediátrica Cuidados Medios",
      "409 - Área Médico-Quirúrgico Pediátrica Cuidados Básicos",
      "410 - Área Médico-Quirúrgico Pediátrica Cuidados Medios",
      "411 - Área Cuidados Intensivos Pediátricos",
      "412 - Área Cuidados Intermedios Pediátricos",
      "413 - Área Neonatología Cuidados Básicos",
      "414 - Área Neonatología Cuidados Intensivos",
      "415 - Área Neonatología Cuidados Intermedios",
      "416 - Área Obstetricia",
      "418 - Área Psiquiatría Adulto Corta estadía",
      "419 - Área Psiquiatría Adulto Mediana estadía",
      "420 - Área Psiquiatría Adulto Larga estadía",
      "421 - Área Psiquiatría Infanto-adolescente corta estadía",
      "427 - Área Sociosanitaria Adulto",
      "428 - Área de Hospitalización de Cuidados Intensivos en Psiquiatría Adulto",
      "429 - Área de Hospitalización de Cuidados Intensivos en Psiquiatría Infanto Adolescente",
      "Área Cuidados Intensivos Adultos",
      "Área Cuidados Intensivos Pediátricos",
      "Área Cuidados Intermedios Adultos",
      "Área Cuidados Intermedios Pediátricos",
      "Área Médica Adulto Cuidados Básicos",
      "Área Médica Adulto Cuidados Medios",
      "Área Médica Pediátrica Cuidados Básicos",
      "Área Médica Pediátrica Cuidados Medios",
      "Área Médico-Quirúrgico Cuidados Básicos",
      "Área Médico-Quirúrgico Cuidados Medios",
      "Área Médico-Quirúrgico Pediátrica Cuidados Básicos",
      "Área Médico-Quirúrgico Pediátrica Cuidados Medios",
      "Área Neonatología Cuidados Básicos",
      "Área Neonatología Cuidados Intensivos",
      "Área Neonatología Cuidados Intermedios",
      "Área Obstetricia",
      "Área Pensionado",
      "Área Psiquiatría Adulto Corta estadía",
      "Área Psiquiatría Adulto Larga estadía",
      "Área Psiquiatría Adulto Mediana estadía",
      "Área Psiquiatría Infanto-adolescente corta estadía"
    ]
    )].copy()

    # Eliminar columnas innecesarias
    df = df.drop(columns=columnas_a_eliminar, errors='ignore')

    # Renombrar columnas clave
    df = df.rename(columns={
        "Nombre SS/SEREMI": "SEREMI",
        "Nombre Nivel Cuidado": "Area"
    })

    # Renombrar columnas de meses abreviados por fecha
    nuevo_nombre_columnas = {}
    año_int = int(año)

    for i, mes_abrev in enumerate(meses_abreviados, start=1):
        if mes_abrev in df.columns:
            fecha = datetime(año_int, i, 1).strftime('%Y-%m-%d')
            nuevo_nombre_columnas[mes_abrev] = fecha

    df = df.rename(columns=nuevo_nombre_columnas)

    # Guardar DataFrame limpio
    filtrado_limpio[año] = df

# Ejemplo: verificar que todo cargó bien
filtrado_limpio["2020"].head(5)
# Out:
#        SEREMI Nombre Establecimiento        Area                      Glosa  \
# 0  Datos País             Datos País  Datos País      Dias Cama Disponibles
# 1  Datos País             Datos País  Datos País         Dias Cama Ocupados
# 2  Datos País             Datos País  Datos País             Dias de Estada
# 3  Datos País             Datos País  Datos País  Promedio Cama Disponibles
# 4  Datos País             Datos País  Datos País          Numero de Egresos
#
#    2020-01-01  2020-02-01  2020-03-01  2020-04-01  2020-05-01  2020-06-01  \
# 0   800179.00    745007.0   789700.00    745965.0   802598.00    795021.0
# 1   627256.00    577307.0   540914.00    412450.0   477211.00    498858.0
# 2   627876.00    557377.0   602302.00    406231.0   439175.00    503875.0
# 3    25812.23     25689.9    25474.19     24865.5    25890.26     26500.7
# 4    89177.00     80451.0    79438.00     54961.0    58717.00     59720.0
#
#    2020-07-01  2020-08-01  2020-09-01  2020-10-01  2020-11-01  2020-12-01
# 0   832573.00   827810.00   779335.00   805056.00   776759.00   793770.00
# 1   545163.00   557324.00   540777.00   567446.00   559618.00   552408.00
# 2   548854.00   515769.00   527973.00   554252.00   532859.00   589847.00
# 3    26857.19    26703.55    25977.83    25969.55    25891.97    25605.48
# 4    65544.00    66102.00    67836.00    71445.00    70530.00    72361.00

# %% [markdown]
# ### Función para unión de datos:

# %%
def extraer_info_hospital_area_todo_el_año(hospital_nombre, filtrado_limpio, seremi_data):
    registros = []

    for año, df in filtrado_limpio.items():
        df_seremi = seremi_data[año].copy()

        df_seremi['Mes'] = pd.to_datetime(df_seremi['Mes'], errors='coerce')
        df_seremi.dropna(subset=['Mes'], inplace=True)
        df_seremi['Mes'] = df_seremi['Mes'].dt.to_period("M").dt.to_timestamp()

        columnas_mes = [col for col in df.columns if col.startswith("20")]
        for col in columnas_mes:
            df_tmp = df[
                (df["Nombre Establecimiento"] == hospital_nombre) &
                (df["Area"] == "Datos Establecimiento")
            ][["SEREMI", "Nombre Establecimiento", "Area", "Glosa", col]].copy()

            if df_tmp.empty:
                continue

            df_tmp = df_tmp.rename(columns={col: "Valor"})
            df_tmp["Fecha"] = pd.to_datetime(col)

            clima_mes = df_seremi[df_seremi["Mes"] == df_tmp["Fecha"].iloc[0]].copy()
            df_merge = df_tmp.merge(clima_mes, on=["SEREMI"], how="left")

            registros.append(df_merge)

    if registros:
        return pd.concat(registros, ignore_index=True).sort_values("Fecha")
    else:
        print("⚠️ No se encontraron datos para ese hospital y área.")
        return pd.DataFrame()


ejemplo_df_hospital = extraer_info_hospital_area_todo_el_año(
    "Hospital Barros Luco Trudeau (Santiago, San Miguel)",
    filtrado_limpio,
    seremi_data
)

ejemplo_df_hospital.head()
# Out:
#               SEREMI                             Nombre Establecimiento  \
# 0  Metropolitano Sur  Hospital Barros Luco Trudeau (Santiago, San Mi...
# 1  Metropolitano Sur  Hospital Barros Luco Trudeau (Santiago, San Mi...
# 2  Metropolitano Sur  Hospital Barros Luco Trudeau (Santiago, San Mi...
# 3  Metropolitano Sur  Hospital Barros Luco Trudeau (Santiago, San Mi...
# 4  Metropolitano Sur  Hospital Barros Luco Trudeau (Santiago, San Mi...
#
#                     Area                      Glosa     Valor      Fecha  \
# 0  Datos Establecimiento      Dias Cama Disponibles  21236.00 2014-01-01
# 1  Datos Establecimiento         Dias Cama Ocupados  20034.00 2014-01-01
# 2  Datos Establecimiento             Dias de Estada  19132.00 2014-01-01
# 3  Datos Establecimiento  Promedio Cama Disponibles    685.03 2014-01-01
# 4  Datos Establecimiento          Numero de Egresos   2311.00 2014-01-01
#
#          Mes  Temperatura Máxima  Temperatura Mínima  Precipitaciones (suma)  \
# 0 2014-01-01           28.964516           15.748387                     0.4
# 1 2014-01-01           28.964516           15.748387                     0.4
# 2 2014-01-01           28.964516           15.748387                     0.4
# 3 2014-01-01           28.964516           15.748387                     0.4
# 4 2014-01-01           28.964516           15.748387                     0.4
#
#   Dirección del Viento
# 0                   SW
# 1                   SW
# 2                   SW
# 3                   SW
# 4                   SW

# %% [markdown]
# ### Preparación de datos pre modelación:

# %%
def preparar_dataset_climatico_avanzado(df_datos):
    if 'Area' in df_datos.columns:
        df_datos = df_datos[df_datos['Area'] == "Datos Establecimiento"].copy()

    df_modelo = df_datos.pivot(index='Fecha', columns='Glosa', values='Valor').reset_index()

    columnas_necesarias = [
        'Dias Cama Disponibles', 'Dias Cama Ocupados',
        'Promedio Cama Disponibles', 'Numero de Egresos', 'Egresos Fallecidos'
    ]
    columnas_faltantes = [col for col in columnas_necesarias if col not in df_modelo.columns]
    if columnas_faltantes:
        print("❌ Faltan columnas en los datos pivotados:", columnas_faltantes)
        return None

    clima = df_datos.drop_duplicates(subset='Fecha')[[
        'Fecha', 'Temperatura Máxima', 'Temperatura Mínima',
        'Precipitaciones (suma)', 'Dirección del Viento'
    ]] if 'Temperatura Máxima' in df_datos.columns else pd.DataFrame()

    if not clima.empty:
        df_modelo = pd.merge(df_modelo, clima, on='Fecha', how='left')
        df_modelo = pd.get_dummies(df_modelo, columns=['Dirección del Viento'], prefix='Viento')

    df_modelo = df_modelo.sort_values('Fecha')
    df_modelo['Mes'] = df_modelo['Fecha'].dt.month
    df_modelo['Trimestre'] = df_modelo['Fecha'].dt.quarter

    df_modelo['lag_1'] = df_modelo['Dias Cama Disponibles'].shift(1)
    df_modelo['lag_2'] = df_modelo['Dias Cama Disponibles'].shift(2)
    df_modelo['lag_3'] = df_modelo['Dias Cama Disponibles'].shift(3)
    df_modelo['media_movil_3'] = df_modelo['Dias Cama Disponibles'].rolling(window=3).mean()
    df_modelo['variacion_disponibles'] = df_modelo['Dias Cama Disponibles'].diff()
    df_modelo['porcentaje_ocupacion'] = df_modelo['Dias Cama Ocupados'] / df_modelo['Dias Cama Disponibles']
    df_modelo['ocupados_media_movil'] = df_modelo['Dias Cama Ocupados'].rolling(window=3).mean()
    df_modelo['promedio_media_movil'] = df_modelo['Promedio Cama Disponibles'].rolling(window=3).mean()
    df_modelo['egresos_media_movil'] = df_modelo['Numero de Egresos'].rolling(window=3).mean()
    df_modelo['egresos_fallecidos_media_movil'] = df_modelo['Egresos Fallecidos'].rolling(window=3).mean()

    if 'Temperatura Máxima' in df_modelo.columns and 'Temperatura Mínima' in df_modelo.columns:
        df_modelo['Diferencia Térmica'] = df_modelo['Temperatura Máxima'] - df_modelo['Temperatura Mínima']
        df_modelo['temp_max_movil'] = df_modelo['Temperatura Máxima'].rolling(window=3).mean()
        df_modelo['precipitacion_movil'] = df_modelo['Precipitaciones (suma)'].rolling(window=3).mean()
        df_modelo['interaccion_ocupacion_temp'] = df_modelo['porcentaje_ocupacion'] * df_modelo['Temperatura Máxima']
        df_modelo['interaccion_precipitacion_disp'] = df_modelo['Precipitaciones (suma)'] * df_modelo['Dias Cama Disponibles']

    df_modelo['same_month_last_year'] = df_modelo['Dias Cama Disponibles'].shift(12)
    df_modelo['hist_avg_mes'] = df_modelo.groupby('Mes')['Dias Cama Disponibles'].transform('mean')

    return df_modelo.dropna().copy()

# %% [markdown]
# ### Automatización de extración de datos y preparación de dataset - MODELO XGBOOST:

# %% [markdown]
# Estamos prediciendo aproximadamente el 20% de los meses más recientes del historial disponible para ese hospital y área. Por ejemplo:
#
# Si el hospital tiene datos desde 2014 hasta 2025, son 12 años × 12 meses = 144 - 10 (meses faltantes del 2025) -> 134 meses totales.
#
# El 20% de 134 son aprox 27 meses -> estamos prediciendo los últimos 27 meses, desde fines de 2022 hasta marzo de 2025 (en nuestro caso actual).

# %%
def pipeline_final_mae_reducido(nombre_hospital, filtrado_limpio, seremi_data):
    print(f"🔍 Extrayendo datos para: {nombre_hospital} | Datos Establecimiento")

    df_hospital_raw = extraer_info_hospital_area_todo_el_año(
        hospital_nombre=nombre_hospital,
        filtrado_limpio=filtrado_limpio,
        seremi_data=seremi_data
    )

    if df_hospital_raw.empty:
        print("❌ No se encontraron datos para el hospital o área especificada.")
        return None

    print("🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...")
    df_modelo_features = preparar_dataset_climatico_avanzado(df_hospital_raw)
    print(df_modelo_features.shape)

    if df_modelo_features is None or df_modelo_features.empty:
        print("❌ No se pudo preparar el dataset.")
        return None

    columnas_features_modelo = [
        'Dias Cama Ocupados', 'Promedio Cama Disponibles', 'Numero de Egresos',
        'Mes', 'Trimestre', 'lag_1', 'lag_2', 'lag_3', 'media_movil_3',
        'porcentaje_ocupacion', 'variacion_disponibles',
        'ocupados_media_movil', 'promedio_media_movil', 'egresos_media_movil',
        'egresos_fallecidos_media_movil',
        'Temperatura Máxima', 'Temperatura Mínima', 'Precipitaciones (suma)',
        'Diferencia Térmica', 'temp_max_movil', 'precipitacion_movil',
        'same_month_last_year', 'hist_avg_mes',
        'interaccion_ocupacion_temp', 'interaccion_precipitacion_disp'
    ] + [col for col in df_modelo_features.columns if col.startswith('Viento_')]

    X_modelo = df_modelo_features[columnas_features_modelo]
    y_modelo = df_modelo_features['Dias Cama Disponibles']
    X_train, X_test, y_train, y_test = train_test_split(X_modelo, y_modelo, shuffle=False, test_size=0.2)

    print("🔧 Ajustando modelo con GridSearchCV...")
    grid_params = {
        'n_estimators': [50, 100],
        'max_depth': [2, 3],
        'learning_rate': [0.05, 0.1]
    }

    modelo_xgb = XGBRegressor(n_jobs=1, random_state=42)
    grid_search_modelo = GridSearchCV(
        estimator=modelo_xgb,
        param_grid=grid_params,
        scoring='neg_mean_absolute_error',
        cv=TimeSeriesSplit(n_splits=3),
        verbose=1
    )
    grid_search_modelo.fit(X_train, y_train)
    modelo_final = grid_search_modelo.best_estimator_

    print("📌 Mejores parámetros encontrados:", grid_search_modelo.best_params_)
    print("📊 Evaluando sobre el 20% final de los datos...")

    y_predicho = modelo_final.predict(X_test)
    mae = mean_absolute_error(y_test, y_predicho)
    rmse = mean_squared_error(y_test, y_predicho) ** 0.5
    error_porcentaje = np.mean(np.abs((y_test.values - y_predicho) / y_test.values)) * 100

    resultados_df = pd.DataFrame({
        'Fecha': df_modelo_features['Fecha'].iloc[-len(y_test):].values,
        'Real': y_test.values,
        'Predicho': y_predicho,
        'Error Absoluto': np.abs(y_test.values - y_predicho),
        'Error Porcentual (%)': np.abs((y_test.values - y_predicho) / y_test.values) * 100
    })

    print(f"✅ MAE (camas): {mae:.2f}")
    print(f"✅ RMSE (camas): {rmse:.2f}")
    print(f"📉 Error promedio porcentual: {error_porcentaje:.2f}%")

    return resultados_df

# %% [markdown]
# ### Ejemplo de uso - MODELO XGBOOST:

# %%
pd.set_option("display.max_columns", None)
resultados_final = pipeline_final_mae_reducido("Hospital Barros Luco Trudeau (Santiago, San Miguel)", filtrado_limpio, seremi_data)

resultados_final
# Out:
# 🔍 Extrayendo datos para: Hospital Barros Luco Trudeau (Santiago, San Miguel) | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 37)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 679.60
# ✅ RMSE (camas): 1228.32
# 📉 Error promedio porcentual: 3.11%
#         Fecha     Real      Predicho  Error Absoluto  Error Porcentual (%)
# 0  2023-02-01  18759.0  19594.283203      835.283203              4.452706
# 1  2023-03-01  21183.0  21600.634766      417.634766              1.971556
# 2  2023-04-01  20731.0  20724.978516        6.021484              0.029046
# 3  2023-05-01  21618.0  21562.519531       55.480469              0.256640
# 4  2023-06-01  20804.0  20826.691406       22.691406              0.109072
# 5  2023-07-01  21456.0  21484.648438       28.648438              0.133522
# 6  2023-08-01  21494.0  21424.523438       69.476562              0.323237
# 7  2023-09-01  21119.0  20872.548828      246.451172              1.166964
# 8  2023-10-01  21913.0  21575.701172      337.298828              1.539264
# 9  2023-11-01  21247.0  21230.496094       16.503906              0.077676
# 10 2023-12-01  29777.0  24762.892578     5014.107422             16.838860
# 11 2024-01-01  20166.0  20787.824219      621.824219              3.083528
# 12 2024-02-01  19168.0  21069.550781     1901.550781              9.920444
# 13 2024-03-01  20469.0  21208.246094      739.246094              3.611540
# 14 2024-04-01  19482.0  20590.781250     1108.781250              5.691311
# 15 2024-05-01  20382.0  21071.947266      689.947266              3.385081
# 16 2024-06-01  20466.0  20876.449219      410.449219              2.005518
# 17 2024-07-01  21113.0  21215.417969      102.417969              0.485094
# 18 2024-08-01  21081.0  21054.617188       26.382812              0.125150
# 19 2024-09-01  20547.0  20774.714844      227.714844              1.108263
# 20 2024-10-01  21216.0  21225.837891        9.837891              0.046370
# 21 2024-11-01  20278.0  20781.214844      503.214844              2.481580
# 22 2024-12-01  20057.0  20954.937500      897.937500              4.476928
# 23 2025-01-01  19979.0  20924.279297      945.279297              4.731364
# 24 2025-02-01  18021.0  19776.804688     1755.804688              9.743104

# %% [markdown]
# ### Ejemplo de uso extendido a mas hospitales - MODELO XGBOOST:

# %%
# 1. Extraer todos los hospitales válidos con área "Datos Establecimiento"
def extraer_hospitales_validos(filtrado_limpio):
    hospitales = set()
    for df in filtrado_limpio.values():
        if "Nombre Establecimiento" in df.columns and "Area" in df.columns:
            validos = df[df["Area"] == "Datos Establecimiento"][["Nombre Establecimiento"]].dropna().drop_duplicates()
            for _, row in validos.iterrows():
                hospitales.add(row["Nombre Establecimiento"])
    return sorted(list(hospitales))

# 2. Obtener todos los hospitales válidos
hospitales_validos = extraer_hospitales_validos(filtrado_limpio)

# 3. Evaluar modelo para cada hospital
resultados_todos = {}

for hospital in hospitales_validos:
    try:
        resultados = pipeline_final_mae_reducido(hospital,filtrado_limpio,seremi_data)
        if resultados is not None:
            resultados_todos[hospital] = resultados
    except:
        continue  # Silenciosamente ignora errores

# 4. Crear tabla resumen
tabla_resumen = []

for hospital, resultados in resultados_todos.items():
    if "Error Absoluto" in resultados.columns and "Error Porcentual (%)" in resultados.columns:
        mae = resultados["Error Absoluto"].mean()
        error_pct = resultados["Error Porcentual (%)"].mean()
        tabla_resumen.append({
            "Hospital": hospital,
            "MAE (camas)": round(mae, 2),
            "Error Porcentual Promedio (%)": round(error_pct, 2)
        })

# 5. Mostrar tabla ordenada por MAE
df_tabla_resumen = pd.DataFrame(tabla_resumen).sort_values("MAE (camas)").reset_index(drop=True)
display(df_tabla_resumen)

# 6. Calcular MAE promedio general
mae_promedio_general = df_tabla_resumen["MAE (camas)"].mean()
print(f"\n📊 MAE promedio general: {mae_promedio_general:.2f} camas")
# Out:
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 37)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 190.19
# ✅ RMSE (camas): 236.52
# 📉 Error promedio porcentual: 1.13%
# 🔍 Extrayendo datos para: Hospital Adalberto Steeger (Talagante) | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 37)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 79.96
# ✅ RMSE (camas): 88.55
# 📉 Error promedio porcentual: 2.31%
# 🔍 Extrayendo datos para: Hospital Adriana Cousiño (Quintero) | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 39)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 21.67
# ✅ RMSE (camas): 25.41
# 📉 Error promedio porcentual: 2.75%
# 🔍 Extrayendo datos para: Hospital Barros Luco Trudeau (Santiago, San Miguel) | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 37)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 679.60
# ✅ RMSE (camas): 1228.32
# 📉 Error promedio porcentual: 3.11%
# 🔍 Extrayendo datos para: Hospital Carlos Van Buren (Valparaíso) | Datos Establecimiento
# 🔍 Extrayendo datos para: Hospital Centro Geriátrico Paz de la Tarde (Limache) | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 39)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 37.72
# ✅ RMSE (camas): 48.55
# 📉 Error promedio porcentual: 2.32%
# 🔍 Extrayendo datos para: Hospital Clorinda Avello (Santa Juana) | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 38)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 32.21
# ✅ RMSE (camas): 47.03
# 📉 Error promedio porcentual: 2.64%
# 🔍 Extrayendo datos para: Hospital Clínico Herminda Martín (Chillán) | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 39)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 48.81
# ✅ RMSE (camas): 73.92
# 📉 Error promedio porcentual: 0.34%
# 🔍 Extrayendo datos para: Hospital Comunitario de Salud Familiar Pedro Morales Campos (Yungay) | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 39)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 18.21
# ✅ RMSE (camas): 25.10
# 📉 Error promedio porcentual: 1.44%
# 🔍 Extrayendo datos para: Hospital Comunitario de Salud Familiar de Bulnes | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 39)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 27.83
# ✅ RMSE (camas): 34.66
# 📉 Error promedio porcentual: 1.71%
# 🔍 Extrayendo datos para: Hospital Comunitario de Salud Familiar de El Carmen | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 39)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 9.67
# ✅ RMSE (camas): 13.10
# 📉 Error promedio porcentual: 1.34%
# 🔍 Extrayendo datos para: Hospital Comunitario de Salud Familiar de Quirihue | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 39)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 20.91
# ✅ RMSE (camas): 26.06
# 📉 Error promedio porcentual: 1.40%
# 🔍 Extrayendo datos para: Hospital El Pino (Santiago, San Bernardo) | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 37)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 76.77
# ✅ RMSE (camas): 97.48
# 📉 Error promedio porcentual: 0.84%
# 🔍 Extrayendo datos para: Hospital Hanga Roa (Isla De Pascua) | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 37)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 18.09
# ✅ RMSE (camas): 28.36
# 📉 Error promedio porcentual: 3.38%
# 🔍 Extrayendo datos para: Hospital Intercultural Kallvu Llanka (Cañete) | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 37)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 50.31
# ✅ RMSE (camas): 61.46
# 📉 Error promedio porcentual: 1.83%
# 🔍 Extrayendo datos para: Hospital Juan Morey (La Unión) | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (96, 37)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 89.62
# ✅ RMSE (camas): 143.28
# 📉 Error promedio porcentual: 2.99%
# 🔍 Extrayendo datos para: Hospital Juana Ross de Edwards (Peñablanca, Villa Alemana) | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 39)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 259.60
# ✅ RMSE (camas): 388.71
# 📉 Error promedio porcentual: 14.04%
# 🔍 Extrayendo datos para: Hospital Las Higueras (Talcahuano) | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 38)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 110.27
# ✅ RMSE (camas): 147.19
# 📉 Error promedio porcentual: 0.85%
# 🔍 Extrayendo datos para: Hospital Lord Cochrane | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 38)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 2.03
# ✅ RMSE (camas): 4.13
# 📉 Error promedio porcentual: 1.00%
# 🔍 Extrayendo datos para: Hospital Padre Alberto Hurtado (San Ramón) | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 37)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 150.88
# ✅ RMSE (camas): 188.84
# 📉 Error promedio porcentual: 1.37%
# 🔍 Extrayendo datos para: Hospital Presidente Carlos Ibáñez del Campo (Linares) | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (119, 38)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 147.05
# ✅ RMSE (camas): 177.19
# 📉 Error promedio porcentual: 2.17%
# 🔍 Extrayendo datos para: Hospital Provincial del Huasco Monseñor Fernando Ariztía Ruiz (Vallenar) | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 36)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 9.47
# ✅ RMSE (camas): 15.81
# 📉 Error promedio porcentual: 0.28%
# 🔍 Extrayendo datos para: Hospital Psiquiátrico El Peral (Santiago, Puente Alto) | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 37)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 480.96
# ✅ RMSE (camas): 536.13
# 📉 Error promedio porcentual: 14.40%
# 🔍 Extrayendo datos para: Hospital San Agustín (La Ligua) | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 39)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 47.45
# ✅ RMSE (camas): 67.23
# 📉 Error promedio porcentual: 2.92%
# 🔍 Extrayendo datos para: Hospital San Antonio (Putaendo) | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 36)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 26.58
# ✅ RMSE (camas): 48.06
# 📉 Error promedio porcentual: 2.84%
# 🔍 Extrayendo datos para: Hospital San Francisco (Llaillay) | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 36)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 36.00
# ✅ RMSE (camas): 42.74
# 📉 Error promedio porcentual: 3.51%
# 🔍 Extrayendo datos para: Hospital San José (Casablanca) | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 38)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 24.77
# ✅ RMSE (camas): 44.10
# 📉 Error promedio porcentual: 5.62%
# 🔍 Extrayendo datos para: Hospital San José (Coronel) | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 38)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 42.05
# ✅ RMSE (camas): 51.62
# 📉 Error promedio porcentual: 1.30%
# 🔍 Extrayendo datos para: Hospital San José (Melipilla) | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 37)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 27.45
# ✅ RMSE (camas): 41.26
# 📉 Error promedio porcentual: 0.68%
# 🔍 Extrayendo datos para: Hospital San José (Parral) | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (119, 38)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 12.23
# ✅ RMSE (camas): 15.78
# 📉 Error promedio porcentual: 0.40%
# 🔍 Extrayendo datos para: Hospital San José de Maipo | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 37)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 50.33
# ✅ RMSE (camas): 63.09
# 📉 Error promedio porcentual: 0.88%
# 🔍 Extrayendo datos para: Hospital San Juan de Dios (Cauquenes) | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (119, 38)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 49.40
# ✅ RMSE (camas): 69.24
# 📉 Error promedio porcentual: 1.43%
# 🔍 Extrayendo datos para: Hospital San Juan de Dios (Combarbalá) | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 38)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 0.19
# ✅ RMSE (camas): 0.79
# 📉 Error promedio porcentual: 0.03%
# 🔍 Extrayendo datos para: Hospital San Juan de Dios (Curicó) | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (119, 38)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 1507.16
# ✅ RMSE (camas): 1955.90
# 📉 Error promedio porcentual: 13.15%
# 🔍 Extrayendo datos para: Hospital San Juan de Dios (La Serena) | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 38)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 335.87
# ✅ RMSE (camas): 399.06
# 📉 Error promedio porcentual: 3.20%
# 🔍 Extrayendo datos para: Hospital San Juan de Dios (Los Andes) | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 36)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 38.59
# ✅ RMSE (camas): 61.89
# 📉 Error promedio porcentual: 0.84%
# 🔍 Extrayendo datos para: Hospital San Juan de Dios (Santiago, Santiago) | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 37)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 240.21
# ✅ RMSE (camas): 318.83
# 📉 Error promedio porcentual: 1.53%
# 🔍 Extrayendo datos para: Hospital San Luis (Buin) | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 37)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 21.73
# ✅ RMSE (camas): 30.26
# 📉 Error promedio porcentual: 0.74%
# 🔍 Extrayendo datos para: Hospital San Pablo (Coquimbo) | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 38)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 64.36
# ✅ RMSE (camas): 79.35
# 📉 Error promedio porcentual: 0.64%
# 🔍 Extrayendo datos para: Hospital San Pedro (Los Vilos) | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 38)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 12.22
# ✅ RMSE (camas): 15.74
# 📉 Error promedio porcentual: 1.26%
# 🔍 Extrayendo datos para: Hospital San Vicente de Tagua-Tagua | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 36)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 42.50
# ✅ RMSE (camas): 67.15
# 📉 Error promedio porcentual: 3.05%
# 🔍 Extrayendo datos para: Hospital Traumatológico (Concepción) | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 38)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 93.39
# ✅ RMSE (camas): 110.97
# 📉 Error promedio porcentual: 3.12%
# 🔍 Extrayendo datos para: Hospital de Ancud | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 37)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 39.08
# ✅ RMSE (camas): 49.60
# 📉 Error promedio porcentual: 2.03%
# 🔍 Extrayendo datos para: Hospital de Calbuco | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (119, 39)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 13.67
# ✅ RMSE (camas): 17.14
# 📉 Error promedio porcentual: 1.44%
# 🔍 Extrayendo datos para: Hospital de Carahue | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 38)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 14.33
# ✅ RMSE (camas): 23.39
# 📉 Error promedio porcentual: 1.64%
# 🔍 Extrayendo datos para: Hospital de Castro | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 37)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 70.91
# ✅ RMSE (camas): 105.69
# 📉 Error promedio porcentual: 1.75%
# 🔍 Extrayendo datos para: Hospital de Collipulli | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 39)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 93.62
# ✅ RMSE (camas): 112.02
# 📉 Error promedio porcentual: 9.45%
# 🔍 Extrayendo datos para: Hospital de Constitución | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (118, 38)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 217.58
# ✅ RMSE (camas): 270.19
# 📉 Error promedio porcentual: 8.20%
# 🔍 Extrayendo datos para: Hospital de Contulmo | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 37)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 7.40
# ✅ RMSE (camas): 9.68
# 📉 Error promedio porcentual: 2.37%
# 🔍 Extrayendo datos para: Hospital de Corral | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (96, 37)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 1.70
# ✅ RMSE (camas): 3.76
# 📉 Error promedio porcentual: 0.82%
# 🔍 Extrayendo datos para: Hospital de Curacaví | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (121, 37)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 0.04
# ✅ RMSE (camas): 0.20
# 📉 Error promedio porcentual: 0.01%
# 🔍 Extrayendo datos para: Hospital de Curepto | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (119, 38)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 65.90
# ✅ RMSE (camas): 107.77
# 📉 Error promedio porcentual: 49.85%
# 🔍 Extrayendo datos para: Hospital de Fresia | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (119, 39)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 6.40
# ✅ RMSE (camas): 10.62
# 📉 Error promedio porcentual: 0.97%
# 🔍 Extrayendo datos para: Hospital de Frutillar | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (119, 39)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 29.58
# ✅ RMSE (camas): 39.07
# 📉 Error promedio porcentual: 2.92%
# 🔍 Extrayendo datos para: Hospital de Futaleufú | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (119, 39)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 0.83
# ✅ RMSE (camas): 1.62
# 📉 Error promedio porcentual: 0.46%
# 🔍 Extrayendo datos para: Hospital de Galvarino | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 38)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 4.68
# ✅ RMSE (camas): 9.39
# 📉 Error promedio porcentual: 0.63%
# 🔍 Extrayendo datos para: Hospital de Gorbea | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 38)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 44.90
# ✅ RMSE (camas): 57.72
# 📉 Error promedio porcentual: 5.87%
# 🔍 Extrayendo datos para: Hospital de Hualañé | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (118, 38)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 17.42
# ✅ RMSE (camas): 25.38
# 📉 Error promedio porcentual: 4.30%
# 🔍 Extrayendo datos para: Hospital de Lanco | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (78, 37)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 0.01
# ✅ RMSE (camas): 0.01
# 📉 Error promedio porcentual: 0.00%
# 🔍 Extrayendo datos para: Hospital de Lebu | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 37)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 57.27
# ✅ RMSE (camas): 75.90
# 📉 Error promedio porcentual: 3.09%
# 🔍 Extrayendo datos para: Hospital de Litueche | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 36)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 0.56
# ✅ RMSE (camas): 1.05
# 📉 Error promedio porcentual: 0.24%
# 🔍 Extrayendo datos para: Hospital de Llanquihue | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (119, 39)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 144.65
# ✅ RMSE (camas): 147.78
# 📉 Error promedio porcentual: 23.76%
# 🔍 Extrayendo datos para: Hospital de Lolol | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 36)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 0.05
# ✅ RMSE (camas): 0.11
# 📉 Error promedio porcentual: 0.02%
# 🔍 Extrayendo datos para: Hospital de Lonquimay | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 39)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 14.62
# ✅ RMSE (camas): 23.36
# 📉 Error promedio porcentual: 2.87%
# 🔍 Extrayendo datos para: Hospital de Los Lagos | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (96, 37)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 25.46
# ✅ RMSE (camas): 30.85
# 📉 Error promedio porcentual: 2.69%
# 🔍 Extrayendo datos para: Hospital de Lota | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 38)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 88.93
# ✅ RMSE (camas): 107.59
# 📉 Error promedio porcentual: 2.97%
# 🔍 Extrayendo datos para: Hospital de Marchigüe | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 36)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 0.68
# ✅ RMSE (camas): 2.37
# 📉 Error promedio porcentual: 0.26%
# 🔍 Extrayendo datos para: Hospital de Maullín | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (119, 39)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 19.02
# ✅ RMSE (camas): 24.68
# 📉 Error promedio porcentual: 2.48%
# 🔍 Extrayendo datos para: Hospital de Mejillones | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 35)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 1.31
# ✅ RMSE (camas): 2.87
# 📉 Error promedio porcentual: 0.50%
# 🔍 Extrayendo datos para: Hospital de Molina | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (119, 38)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 137.50
# ✅ RMSE (camas): 141.78
# 📉 Error promedio porcentual: 8.87%
# 🔍 Extrayendo datos para: Hospital de Nancagua | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 36)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 0.00
# ✅ RMSE (camas): 0.01
# 📉 Error promedio porcentual: 0.00%
# 🔍 Extrayendo datos para: Hospital de Paillaco | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (96, 37)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 119.97
# ✅ RMSE (camas): 141.79
# 📉 Error promedio porcentual: 15.23%
# 🔍 Extrayendo datos para: Hospital de Peñaflor | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (121, 37)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 5.82
# ✅ RMSE (camas): 16.13
# 📉 Error promedio porcentual: 0.53%
# 🔍 Extrayendo datos para: Hospital de Pichidegua | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 36)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 4.26
# ✅ RMSE (camas): 5.47
# 📉 Error promedio porcentual: 1.17%
# 🔍 Extrayendo datos para: Hospital de Pichilemu | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 36)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 5.86
# ✅ RMSE (camas): 9.30
# 📉 Error promedio porcentual: 0.82%
# 🔍 Extrayendo datos para: Hospital de Pitrufquén | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 38)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 107.87
# ✅ RMSE (camas): 115.25
# 📉 Error promedio porcentual: 4.75%
# 🔍 Extrayendo datos para: Hospital de Puerto Montt | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (119, 39)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 487.11
# ✅ RMSE (camas): 950.70
# 📉 Error promedio porcentual: 2.52%
# 🔍 Extrayendo datos para: Hospital de Puerto Octay | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 38)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 22.48
# ✅ RMSE (camas): 25.50
# 📉 Error promedio porcentual: 6.75%
# 🔍 Extrayendo datos para: Hospital de Purén | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (121, 39)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 66.56
# ✅ RMSE (camas): 72.48
# 📉 Error promedio porcentual: 9.55%
# 🔍 Extrayendo datos para: Hospital de Quellón | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 37)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 8.02
# ✅ RMSE (camas): 11.37
# 📉 Error promedio porcentual: 0.81%
# 🔍 Extrayendo datos para: Hospital de Quilpué | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 39)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 53.95
# ✅ RMSE (camas): 78.33
# 📉 Error promedio porcentual: 1.23%
# 🔍 Extrayendo datos para: Hospital de Río Bueno | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (96, 37)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 154.53
# ✅ RMSE (camas): 163.42
# 📉 Error promedio porcentual: 10.59%
# 🔍 Extrayendo datos para: Hospital de Río Negro | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 38)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 18.47
# ✅ RMSE (camas): 24.46
# 📉 Error promedio porcentual: 2.39%
# 🔍 Extrayendo datos para: Hospital de Salamanca | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 38)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 4.80
# ✅ RMSE (camas): 11.24
# 📉 Error promedio porcentual: 0.87%
# 🔍 Extrayendo datos para: Hospital de Teno | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (118, 38)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 38.17
# ✅ RMSE (camas): 130.58
# 📉 Error promedio porcentual: inf%
# 🔍 Extrayendo datos para: Hospital de Toltén | Datos Establecimiento
# /tmp/ipykernel_45312/2593957667.py:62: RuntimeWarning: divide by zero encountered in divide
#   error_porcentaje = np.mean(np.abs((y_test.values - y_predicho) / y_test.values)) * 100
# /tmp/ipykernel_45312/2593957667.py:69: RuntimeWarning: divide by zero encountered in divide
#   'Error Porcentual (%)': np.abs((y_test.values - y_predicho) / y_test.values) * 100
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 38)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 10.01
# ✅ RMSE (camas): 15.38
# 📉 Error promedio porcentual: 1.45%
# 🔍 Extrayendo datos para: Hospital de Tomé | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 38)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 69.75
# ✅ RMSE (camas): 83.30
# 📉 Error promedio porcentual: 2.54%
# 🔍 Extrayendo datos para: Hospital de Vilcún | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 38)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 25.14
# ✅ RMSE (camas): 37.12
# 📉 Error promedio porcentual: 3.37%
# 🔍 Extrayendo datos para: Hospital de Villarrica | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 38)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 202.34
# ✅ RMSE (camas): 339.18
# 📉 Error promedio porcentual: 7.60%
# 🔍 Extrayendo datos para: Instituto Nacional Geriátrico Presidente Eduardo Frei Montalva | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (121, 37)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 7.90
# ✅ RMSE (camas): 10.95
# 📉 Error promedio porcentual: 0.56%
# 🔍 Extrayendo datos para: Instituto Nacional de Enfermedades Respiratorias y Cirugía Torácica | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 37)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 93.36
# ✅ RMSE (camas): 135.66
# 📉 Error promedio porcentual: 2.58%
# 🔍 Extrayendo datos para: Instituto Nacional de Rehabilitación Infantil Presidente Pedro Aguirre Cerda | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# (122, 37)
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 44.85
# ✅ RMSE (camas): 98.06
# 📉 Error promedio porcentual: 56.19%
#                                              Hospital  MAE (camas)  \
# 0                                Hospital de Nancagua         0.00
# 1                                   Hospital de Lanco         0.01
# 2                                Hospital de Curacaví         0.04
# 3                                   Hospital de Lolol         0.05
# 4              Hospital San Juan de Dios (Combarbalá)         0.19
# ..                                                ...          ...
# 86              Hospital San Juan de Dios (La Serena)       335.87
# 87  Hospital Psiquiátrico El Peral (Santiago, Puen...       480.96
# 88                           Hospital de Puerto Montt       487.11
# 89  Hospital Barros Luco Trudeau (Santiago, San Mi...       679.60
# 90                 Hospital San Juan de Dios (Curicó)      1507.16
#
#     Error Porcentual Promedio (%)
# 0                            0.00
# 1                            0.00
# 2                            0.01
# 3                            0.02
# 4                            0.03
# ..                            ...
# 86                           3.20
# 87                          14.40
# 88                           2.52
# 89                           3.11
# 90                          13.15
#
# [91 rows x 3 columns]
# 📊 MAE promedio general: 86.85 camas

# %% [markdown]
# ---

# %% [markdown]
# ### Listado y cantidad de hospitales con los que trabaja el modelo:

# %%
def obtener_lista_hospitales(filtrado_limpio):
    hospitales = set()
    
    for año, df in filtrado_limpio.items():
        if "Nombre Establecimiento" in df.columns:
            hospitales.update(df["Nombre Establecimiento"].dropna().unique())
    
    return sorted(list(hospitales))

# %%
lista_hospitales = obtener_lista_hospitales(filtrado_limpio)
print(f"Se encontraron {len(lista_hospitales)} hospitales.")
for h in lista_hospitales[:10]:  # muestra los primeros 10 como ejemplo
    print("🏥", h)
# Out:
# Se encontraron 94 hospitales.
# 🏥 Complejo Hospitalario San José (Santiago, Independencia)
# 🏥 Datos País
# 🏥 Datos Servicio Salud
# 🏥 Hospital Adalberto Steeger (Talagante)
# 🏥 Hospital Adriana Cousiño (Quintero)
# 🏥 Hospital Barros Luco Trudeau (Santiago, San Miguel)
# 🏥 Hospital Carlos Van Buren (Valparaíso)
# 🏥 Hospital Centro Geriátrico Paz de la Tarde (Limache)
# 🏥 Hospital Clorinda Avello (Santa Juana)
# 🏥 Hospital Clínico Herminda Martín (Chillán)

# %% [markdown]
# #
# 92 hospitales comunes entre 2014 y 2025

# %% [markdown]
# ### XGBOOST

# %% [markdown]
# ### PREDICCION FUTURA

# %% [markdown]
# ### ***El modelo funciona máximo para 8 meses en el futuro***

# %%
# ✅ Función extendida y refinada para predecir camas disponibles (XGBoost con clima futuro y predicción de hasta 8 meses)
import os
from pathlib import Path
def predecir_camas_mes_futuro_extendida(hospital, filtrado_limpio, seremi_data, clima=None, modo="entrenamiento", mes_futuro=None):
    # Muestra en pantalla el hospital que se va a procesar
    print(f"🔍 Extrayendo datos para: {hospital}")

    # Extrae los datos base hospitalarios del área "Datos Establecimiento"
    df_base = extraer_info_hospital_area_todo_el_año(hospital, filtrado_limpio, seremi_data)

    # Si el DataFrame está vacío, detiene el proceso
    if df_base.empty:
        print("❌ No se encontraron datos para el hospital especificado.")
        return None

    # Muestra mensaje indicando que se está preparando el dataset
    print("🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...")
    df_modelo = preparar_dataset_climatico_avanzado(df_base)

    # Si la preparación falla, se detiene el proceso
    if df_modelo is None or df_modelo.empty:
        print("❌ No se pudo preparar el dataset.")
        return None

    # Definimos todas las features utilizadas por el modelo
    todas_las_features = [
        'Dias Cama Ocupados', 'Promedio Cama Disponibles', 'Numero de Egresos',
        'Mes', 'Trimestre', 'lag_1', 'lag_2', 'lag_3', 'media_movil_3',
        'porcentaje_ocupacion', 'variacion_disponibles',
        'ocupados_media_movil', 'promedio_media_movil', 'egresos_media_movil',
        'Temperatura Máxima', 'Temperatura Mínima', 'Precipitaciones (suma)',
        'Diferencia Térmica', 'temp_max_movil', 'precipitacion_movil',
        'same_month_last_year', 'hist_avg_mes',
        'interaccion_ocupacion_temp', 'interaccion_precipitacion_disp'
    ] + [col for col in df_modelo.columns if col.startswith('Viento_')]

    # Si el modo es entrenamiento, seguimos la lógica clásica
    if modo == "entrenamiento":
        X = df_modelo[todas_las_features]
        y = df_modelo['Dias Cama Disponibles']

        X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=False, test_size=0.2)

        print("🔧 Ajustando modelo con GridSearchCV...")
        param_grid = {
            'n_estimators': [50, 100],
            'max_depth': [2, 3],
            'learning_rate': [0.05, 0.1]
        }

        model = XGBRegressor(n_jobs=1, random_state=42)
        grid_search = GridSearchCV(
            estimator=model,
            param_grid=param_grid,
            scoring='neg_mean_absolute_error',
            cv=TimeSeriesSplit(n_splits=3),
            verbose=0
        )
        grid_search.fit(X_train, y_train)
        mejor_modelo = grid_search.best_estimator_

        print("📌 Mejores parámetros encontrados:", grid_search.best_params_)
        print("📊 Evaluando sobre el 20% final de los datos...")

        y_pred = mejor_modelo.predict(X_test)
        mae = mean_absolute_error(y_test, y_pred)
        rmse = mean_squared_error(y_test, y_pred) ** 0.5
        error_pct = np.mean(np.abs((y_test.values - y_pred) / y_test.values)) * 100

        print(f"✅ MAE (camas): {mae:.2f}")
        print(f"✅ RMSE (camas): {rmse:.2f}")
        print(f"📉 Error promedio porcentual: {error_pct:.2f}%")

        resultados = pd.DataFrame({
            'Fecha': df_modelo['Fecha'].iloc[-len(y_test):].values,
            'Real': y_test.values,
            'Predicho': y_pred,
            'Error Absoluto': np.abs(y_test.values - y_pred),
            'Error Porcentual (%)': np.abs((y_test.values - y_pred) / y_test.values) * 100
        })

        return resultados

    # Si el modo es futuro y se especifica el mes_futuro
    elif modo == "futuro" and mes_futuro is not None:
        mes_dt = pd.to_datetime(mes_futuro)
        print(f"🗕️ Modo futuro: prediciendo camas para {mes_futuro}")

        # Entrena el modelo completo con todos los datos históricos
        X_full = df_modelo[todas_las_features]
        y_full = df_modelo['Dias Cama Disponibles']
        model = XGBRegressor(n_jobs=1, random_state=42)
        model.fit(X_full, y_full)
        ruta_modelo = os.path.join(f"models/{hospital}_modelo_xgb_nativo.ubj") # Puede ser .json, .ubj o .bin
        model.save_model(ruta_modelo)
        # Si hay datos climáticos, creamos un registro futuro
        if clima is not None:
            clima_futuro = clima[clima['Fecha'] == mes_dt].copy()
            if clima_futuro.empty:
                print(f"⚠️ No se encontraron datos climáticos para {mes_futuro}")
                return None

            ultima_fila = df_modelo.iloc[-1].copy()
            fila_nueva = ultima_fila.copy()

            fila_nueva['Fecha'] = mes_dt
            fila_nueva['Mes'] = mes_dt.month
            fila_nueva['Trimestre'] = mes_dt.quarter
            fila_nueva['Temperatura Máxima'] = clima_futuro['Temperatura Máxima'].values[0]
            fila_nueva['Temperatura Mínima'] = clima_futuro['Temperatura Mínima'].values[0]
            fila_nueva['Precipitaciones (suma)'] = clima_futuro['Precipitaciones (suma)'].values[0]
            fila_nueva['Diferencia Térmica'] = fila_nueva['Temperatura Máxima'] - fila_nueva['Temperatura Mínima']

            # Inferencia de valores históricos del mismo mes
            historico_mes = df_modelo[df_modelo['Mes'] == fila_nueva['Mes']]['Dias Cama Disponibles']
            fila_nueva['same_month_last_year'] = historico_mes.iloc[-12] if len(historico_mes) >= 12 else historico_mes.mean()
            fila_nueva['hist_avg_mes'] = historico_mes.mean()

            # Simulación básica de valores faltantes usando promedios recientes
            for col in todas_las_features:
                if col not in fila_nueva:
                    if col in df_modelo.columns:
                        fila_nueva[col] = df_modelo[col].mean()
                    else:
                        fila_nueva[col] = 0

            df_futuro = pd.DataFrame([fila_nueva])
            X_futuro = df_futuro[todas_las_features]
            prediccion = model.predict(X_futuro)[0]

            print(f"📈 Predicción para {mes_futuro}: {prediccion:.2f} camas disponibles")
            return prediccion, model

        else:
            print("⚠️ No se entregaron datos climáticos para predicción futura.")
            return None

    else:
        print("⚠️ Modo no reconocido o mes_futuro no especificado.")
        return None

# %%
# Crear un DataFrame con datos climáticos sintéticos para los próximos meses
fechas_futuras = pd.date_range(start="2025-05-01", periods=8, freq='MS')

clima_futuro_sintetico = pd.DataFrame({
    "Fecha": fechas_futuras,
    "Temperatura Máxima": [25, 27, 30, 29, 28, 26, 24, 22],  # Valores supuestos
    "Temperatura Mínima": [10, 12, 14, 13, 12, 11, 9, 7],    # Valores supuestos
    "Precipitaciones (suma)": [10, 5, 0, 2, 3, 6, 8, 12],     # Valores supuestos
    "Viento_S": [0.2]*8,
    "Viento_SE": [0.3]*8,
    "Viento_SW": [0.3]*8,
    "Viento_W": [0.2]*8
})

clima_futuro_sintetico
# Out:
#        Fecha  Temperatura Máxima  Temperatura Mínima  Precipitaciones (suma)  \
# 0 2025-05-01                  25                  10                      10
# 1 2025-06-01                  27                  12                       5
# 2 2025-07-01                  30                  14                       0
# 3 2025-08-01                  29                  13                       2
# 4 2025-09-01                  28                  12                       3
# 5 2025-10-01                  26                  11                       6
# 6 2025-11-01                  24                   9                       8
# 7 2025-12-01                  22                   7                      12
#
#    Viento_S  Viento_SE  Viento_SW  Viento_W
# 0       0.2        0.3        0.3       0.2
# 1       0.2        0.3        0.3       0.2
# 2       0.2        0.3        0.3       0.2
# 3       0.2        0.3        0.3       0.2
# 4       0.2        0.3        0.3       0.2
# 5       0.2        0.3        0.3       0.2
# 6       0.2        0.3        0.3       0.2
# 7       0.2        0.3        0.3       0.2

# %%
prediccion_junio,model = predecir_camas_mes_futuro_extendida(
    hospital="Hospital de Curacaví",
    filtrado_limpio=filtrado_limpio,
    seremi_data=seremi_data,
    clima=clima_futuro_sintetico,
    modo="futuro",
    mes_futuro="2025-06-01"
)
# Out:
# 🔍 Extrayendo datos para: Hospital de Curacaví
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 558.00 camas disponibles

# %%
model
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=1, num_parallel_tree=None, ...)

# %%
hospital="Hospital de Curacaví"
model.save_model(f"models/{hospital}_modelo_xgb_nativo.ubj")

# %%
for h in lista_hospitales:
    predecir_camas_mes_futuro_extendida(hospital=h,
        filtrado_limpio=filtrado_limpio,
        seremi_data=seremi_data,
        clima=clima_futuro_sintetico,
        modo="futuro",
        mes_futuro="2025-06-01"
    )
# Out:
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia)
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 15663.83 camas disponibles
# 🔍 Extrayendo datos para: Datos País
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital especificado.
# 🔍 Extrayendo datos para: Datos Servicio Salud
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital especificado.
# 🔍 Extrayendo datos para: Hospital Adalberto Steeger (Talagante)
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 3205.57 camas disponibles
# 🔍 Extrayendo datos para: Hospital Adriana Cousiño (Quintero)
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 818.22 camas disponibles
# 🔍 Extrayendo datos para: Hospital Barros Luco Trudeau (Santiago, San Miguel)
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 18908.39 camas disponibles
# 🔍 Extrayendo datos para: Hospital Carlos Van Buren (Valparaíso)
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 12541.27 camas disponibles
# 🔍 Extrayendo datos para: Hospital Centro Geriátrico Paz de la Tarde (Limache)
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 1499.35 camas disponibles
# 🔍 Extrayendo datos para: Hospital Clorinda Avello (Santa Juana)
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 1215.45 camas disponibles
# 🔍 Extrayendo datos para: Hospital Clínico Herminda Martín (Chillán)
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 13257.06 camas disponibles
# 🔍 Extrayendo datos para: Hospital Comunitario de Salud Familiar Pedro Morales Campos (Yungay)
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 1206.20 camas disponibles
# 🔍 Extrayendo datos para: Hospital Comunitario de Salud Familiar de Bulnes
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 1587.33 camas disponibles
# 🔍 Extrayendo datos para: Hospital Comunitario de Salud Familiar de El Carmen
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 711.49 camas disponibles
# 🔍 Extrayendo datos para: Hospital Comunitario de Salud Familiar de Quirihue
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 1457.12 camas disponibles
# 🔍 Extrayendo datos para: Hospital El Pino (Santiago, San Bernardo)
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 8433.90 camas disponibles
# 🔍 Extrayendo datos para: Hospital Hanga Roa (Isla De Pascua)
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 526.46 camas disponibles
# 🔍 Extrayendo datos para: Hospital Intercultural Kallvu Llanka (Cañete)
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 2547.45 camas disponibles
# 🔍 Extrayendo datos para: Hospital Juan Morey (La Unión)
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 3410.05 camas disponibles
# 🔍 Extrayendo datos para: Hospital Juana Ross de Edwards (Peñablanca, Villa Alemana)
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 2271.87 camas disponibles
# 🔍 Extrayendo datos para: Hospital Las Higueras (Talcahuano)
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 11661.63 camas disponibles
# 🔍 Extrayendo datos para: Hospital Lord Cochrane
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 210.00 camas disponibles
# 🔍 Extrayendo datos para: Hospital Padre Alberto Hurtado (San Ramón)
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 10559.26 camas disponibles
# 🔍 Extrayendo datos para: Hospital Presidente Carlos Ibáñez del Campo (Linares)
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 6172.30 camas disponibles
# 🔍 Extrayendo datos para: Hospital Provincial del Huasco Monseñor Fernando Ariztía Ruiz (Vallenar)
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 3390.91 camas disponibles
# 🔍 Extrayendo datos para: Hospital Psiquiátrico El Peral (Santiago, Puente Alto)
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 2985.09 camas disponibles
# 🔍 Extrayendo datos para: Hospital San Agustín (La Ligua)
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 1553.34 camas disponibles
# 🔍 Extrayendo datos para: Hospital San Antonio (Putaendo)
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 868.00 camas disponibles
# 🔍 Extrayendo datos para: Hospital San Francisco (Llaillay)
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 1060.60 camas disponibles
# 🔍 Extrayendo datos para: Hospital San José (Casablanca)
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 362.67 camas disponibles
# 🔍 Extrayendo datos para: Hospital San José (Coronel)
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 3030.16 camas disponibles
# 🔍 Extrayendo datos para: Hospital San José (Melipilla)
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 4066.16 camas disponibles
# 🔍 Extrayendo datos para: Hospital San José (Parral)
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 2958.56 camas disponibles
# 🔍 Extrayendo datos para: Hospital San José de Maipo
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 5330.56 camas disponibles
# 🔍 Extrayendo datos para: Hospital San Juan de Dios (Cauquenes)
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 3323.94 camas disponibles
# 🔍 Extrayendo datos para: Hospital San Juan de Dios (Combarbalá)
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 560.00 camas disponibles
# 🔍 Extrayendo datos para: Hospital San Juan de Dios (Curicó)
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 11275.89 camas disponibles
# 🔍 Extrayendo datos para: Hospital San Juan de Dios (La Serena)
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 9976.11 camas disponibles
# 🔍 Extrayendo datos para: Hospital San Juan de Dios (Los Andes)
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 4805.46 camas disponibles
# 🔍 Extrayendo datos para: Hospital San Juan de Dios (Santiago, Santiago)
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 14965.43 camas disponibles
# 🔍 Extrayendo datos para: Hospital San Luis (Buin)
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 2920.09 camas disponibles
# 🔍 Extrayendo datos para: Hospital San Pablo (Coquimbo)
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 9452.50 camas disponibles
# 🔍 Extrayendo datos para: Hospital San Pedro (Los Vilos)
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 844.14 camas disponibles
# 🔍 Extrayendo datos para: Hospital San Vicente de Tagua-Tagua
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 1156.00 camas disponibles
# 🔍 Extrayendo datos para: Hospital Traumatológico (Concepción)
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 3348.69 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Ancud
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 1754.19 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Calbuco
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 886.34 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Carahue
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 840.00 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Castro
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 3745.29 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Collipulli
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 700.77 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Constitución
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 2791.35 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Contulmo
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 306.85 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Corral
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 187.00 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Curacaví
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 558.00 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Curepto
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 392.01 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Fresia
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 655.38 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Frutillar
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 875.99 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Futaleufú
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 168.00 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Galvarino
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 720.18 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Gorbea
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 761.82 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Hualañé
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 392.00 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Lanco
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 619.93 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Lebu
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 1612.97 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Litueche
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 240.00 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Llanquihue
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 559.40 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Lolol
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 287.33 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Lonquimay
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 522.70 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Los Lagos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 857.19 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Lota
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 2955.06 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Marchigüe
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 257.39 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Maullín
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 668.11 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Mejillones
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 258.17 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Molina
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 1428.00 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Nancagua
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 256.28 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Paillaco
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 738.38 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Peñaflor
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 1125.17 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Pichidegua
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 348.17 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Pichilemu
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 703.21 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Pitrufquén
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 2090.55 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Puerto Montt
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 16700.63 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Puerto Octay
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 320.04 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Purén
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 694.48 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Quellón
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 921.37 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Quilpué
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 4322.48 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Río Bueno
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 1545.78 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Río Negro
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 806.34 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Salamanca
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# 📈 Predicción para 2025-06-01: 556.74 camas disponibles
# 🔍 Extrayendo datos para: Hospital de Teno
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🗕️ Modo futuro: prediciendo camas para 2025-06-01
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# Cell In[30], line 2
#       1 for h in lista_hospitales:
# ----> 2     predecir_camas_mes_futuro_extendida(hospital=h,
#       3         filtrado_limpio=filtrado_limpio,
#       4         seremi_data=seremi_data,
#       5         clima=clima_futuro_sintetico,
#       6         modo="futuro",
#       7         mes_futuro="2025-06-01"
#       8     )
#
# Cell In[27], line 92, in predecir_camas_mes_futuro_extendida(hospital, filtrado_limpio, seremi_data, clima, modo, mes_futuro)
#      90 y_full = df_modelo['Dias Cama Disponibles']
#      91 model = XGBRegressor(n_jobs=1, random_state=42)
# ---> 92 model.fit(X_full, y_full)
#      93 ruta_modelo = os.path.join("", f"models/{hospital}_modelo_xgb_nativo.ubj") # Puede ser .json, .ubj o .bin
#      94 model.save_model(ruta_modelo)
#
# File ~/.pyenv/versions/3.10.6/envs/SENDA_Chile/lib/python3.10/site-packages/xgboost/core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/SENDA_Chile/lib/python3.10/site-packages/xgboost/sklearn.py:1222, in XGBModel.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1217 model, metric, params, feature_weights = self._configure_fit(
#    1218     xgb_model, params, feature_weights
#    1219 )
#    1221 evals_result: TrainingCallback.EvalsLog = {}
# -> 1222 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1223     missing=self.missing,
#    1224     X=X,
#    1225     y=y,
#    1226     group=None,
#    1227     qid=None,
#    1228     sample_weight=sample_weight,
#    1229     base_margin=base_margin,
#    1230     feature_weights=feature_weights,
#    1231     eval_set=eval_set,
#    1232     sample_weight_eval_set=sample_weight_eval_set,
#    1233     base_margin_eval_set=base_margin_eval_set,
#    1234     eval_group=None,
#    1235     eval_qid=None,
#    1236     create_dmatrix=self._create_dmatrix,
#    1237     enable_categorical=self.enable_categorical,
#    1238     feature_types=self.feature_types,
#    1239 )
#    1241 if callable(self.objective):
#    1242     obj: Optional[Objective] = _objective_decorator(self.objective)
#
# File ~/.pyenv/versions/3.10.6/envs/SENDA_Chile/lib/python3.10/site-packages/xgboost/sklearn.py:628, in _wrap_evaluation_matrices(missing, X, y, group, qid, sample_weight, base_margin, feature_weights, eval_set, sample_weight_eval_set, base_margin_eval_set, eval_group, eval_qid, create_dmatrix, enable_categorical, feature_types)
#     607 def _wrap_evaluation_matrices(
#     608     *,
#     609     missing: float,
#    (...)
#     624     feature_types: Optional[FeatureTypes],
#     625 ) -> Tuple[Any, List[Tuple[Any, str]]]:
#     626     """Convert array_like evaluation matrices into DMatrix.  Perform validation on the
#     627     way."""
# --> 628     train_dmatrix = create_dmatrix(
#     629         data=X,
#     630         label=y,
#     631         group=group,
#     632         qid=qid,
#     633         weight=sample_weight,
#     634         base_margin=base_margin,
#     635         feature_weights=feature_weights,
#     636         missing=missing,
#     637         enable_categorical=enable_categorical,
#     638         feature_types=feature_types,
#     639         ref=None,
#     640     )
#     642     n_validation = 0 if eval_set is None else len(eval_set)
#     644     def validate_or_none(meta: Optional[Sequence], name: str) -> Sequence:
#
# File ~/.pyenv/versions/3.10.6/envs/SENDA_Chile/lib/python3.10/site-packages/xgboost/sklearn.py:1137, in XGBModel._create_dmatrix(self, ref, **kwargs)
#    1135 if _can_use_qdm(self.tree_method, self.device) and self.booster != "gblinear":
#    1136     try:
# -> 1137         return QuantileDMatrix(
#    1138             **kwargs, ref=ref, nthread=self.n_jobs, max_bin=self.max_bin
#    1139         )
#    1140     except TypeError:  # `QuantileDMatrix` supports lesser types than DMatrix
#    1141         pass
#
# File ~/.pyenv/versions/3.10.6/envs/SENDA_Chile/lib/python3.10/site-packages/xgboost/core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/SENDA_Chile/lib/python3.10/site-packages/xgboost/core.py:1614, in QuantileDMatrix.__init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, max_bin, ref, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical, max_quantile_batches, data_split_mode)
#    1594     if any(
#    1595         info is not None
#    1596         for info in (
#    (...)
#    1607         )
#    1608     ):
#    1609         raise ValueError(
#    1610             "If data iterator is used as input, data like label should be "
#    1611             "specified as batch argument."
#    1612         )
# -> 1614 self._init(
#    1615     data,
#    1616     ref=ref,
#    1617     label=label,
#    1618     weight=weight,
#    1619     base_margin=base_margin,
#    1620     group=group,
#    1621     qid=qid,
#    1622     label_lower_bound=label_lower_bound,
#    1623     label_upper_bound=label_upper_bound,
#    1624     feature_weights=feature_weights,
#    1625     feature_names=feature_names,
#    1626     feature_types=feature_types,
#    1627     enable_categorical=enable_categorical,
#    1628     max_quantile_blocks=max_quantile_batches,
#    1629 )
#
# File ~/.pyenv/versions/3.10.6/envs/SENDA_Chile/lib/python3.10/site-packages/xgboost/core.py:1680, in QuantileDMatrix._init(self, data, ref, enable_categorical, max_quantile_blocks, **meta)
#    1678 it.reraise()
#    1679 # delay check_call to throw intermediate exception first
# -> 1680 _check_call(ret)
#    1681 self.handle = handle
#    1683 if ref is not None:
#
# File ~/.pyenv/versions/3.10.6/envs/SENDA_Chile/lib/python3.10/site-packages/xgboost/core.py:310, in _check_call(ret)
#     299 """Check the return value of C API call
#     300
#     301 This function will raise exception when error occurs.
#    (...)
#     307     return value from API calls
#     308 """
#     309 if ret != 0:
# --> 310     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
#
# XGBoostError: [10:42:54] /workspace/src/data/gradient_index.h:100: Check failed: valid: Input data contains `inf` or a value too large, while `missing` is not set to `inf`
# Stack trace:
#   [bt] (0) /home/elias/.pyenv/versions/3.10.6/envs/SENDA_Chile/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x2a6acc) [0x7ff88caa6acc]
#   [bt] (1) /home/elias/.pyenv/versions/3.10.6/envs/SENDA_Chile/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x5d6180) [0x7ff88cdd6180]
#   [bt] (2) /home/elias/.pyenv/versions/3.10.6/envs/SENDA_Chile/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x5ea466) [0x7ff88cdea466]
#   [bt] (3) /home/elias/.pyenv/versions/3.10.6/envs/SENDA_Chile/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x5e821b) [0x7ff88cde821b]
#   [bt] (4) /home/elias/.pyenv/versions/3.10.6/envs/SENDA_Chile/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x5e9449) [0x7ff88cde9449]
#   [bt] (5) /home/elias/.pyenv/versions/3.10.6/envs/SENDA_Chile/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x57a041) [0x7ff88cd7a041]
#   [bt] (6) /home/elias/.pyenv/versions/3.10.6/envs/SENDA_Chile/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(XGQuantileDMatrixCreateFromCallback+0x178) [0x7ff88c9b8fc8]
#   [bt] (7) /usr/lib/x86_64-linux-gnu/libffi.so.8(+0x7b16) [0x7ff92200db16]
#   [bt] (8) /usr/lib/x86_64-linux-gnu/libffi.so.8(+0x43ef) [0x7ff92200a3ef]
