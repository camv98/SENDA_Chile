# %%
import pandas as pd

# %%
# Paso 1: Cargar archivo Excel y hoja específica
archivo = 'Estadísticas Hospitalarias Febrero 2025.xlsx'
df = pd.read_excel(archivo)

# %%
df.head()
# Out:
#                                           Unnamed: 0        Unnamed: 1  \
# 0  Indicadores Hospitalarios según Servicio de Sa...               NaN
# 1                                     Cód. SS/SEREMI  Nombre SS/SEREMI
# 2                                                  0        Datos País
# 3                                                  0        Datos País
# 4                                                  0        Datos País
#
#     Unnamed: 2              Unnamed: 3          Unnamed: 4  \
# 0          NaN                     NaN                 NaN
# 1  Cód. Estab.  Nombre Establecimiento  Cód. Nivel Cuidado
# 2            0              Datos País                   0
# 3            0              Datos País                   0
# 4            0              Datos País                   0
#
#              Unnamed: 5             Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0                   NaN                    NaN        NaN        NaN
# ...

# %%
df = df.drop(index=0).reset_index(drop=True)

df.head()
# Out:
#        Unnamed: 0        Unnamed: 1   Unnamed: 2              Unnamed: 3  \
# 0  Cód. SS/SEREMI  Nombre SS/SEREMI  Cód. Estab.  Nombre Establecimiento
# 1               0        Datos País            0              Datos País
# 2               0        Datos País            0              Datos País
# 3               0        Datos País            0              Datos País
# 4               0        Datos País            0              Datos País
#
#            Unnamed: 4            Unnamed: 5                 Unnamed: 6  \
# 0  Cód. Nivel Cuidado  Nombre Nivel Cuidado                      Glosa
# 1                   0            Datos País      Dias Cama Disponibles
# 2                   0            Datos País         Dias Cama Ocupados
# 3                   0            Datos País             Dias de Estada
# 4                   0            Datos País  Promedio Cama Disponibles
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0       Acum        Ene        Feb
# ...

# %%
df.columns = df.iloc[0]

df = df[1:].reset_index(drop=True)

# %%
df.head()
# Out:
# 0 Cód. SS/SEREMI Nombre SS/SEREMI Cód. Estab. Nombre Establecimiento  \
# 0              0       Datos País           0             Datos País
# 1              0       Datos País           0             Datos País
# 2              0       Datos País           0             Datos País
# 3              0       Datos País           0             Datos País
# 4              0       Datos País           0             Datos País
#
# 0 Cód. Nivel Cuidado Nombre Nivel Cuidado                      Glosa  \
# 0                  0           Datos País      Dias Cama Disponibles
# 1                  0           Datos País         Dias Cama Ocupados
# 2                  0           Datos País             Dias de Estada
# 3                  0           Datos País  Promedio Cama Disponibles
# 4                  0           Datos País          Numero de Egresos
#
# 0      Acum       Ene       Feb
# 0   1432106    778034    654072
# 1   1147616    623158    524458
# 2   1151224    635538    515686
# ...

# %%
df.to_csv("Estadísticas Hospitalarias Diciembre 2024.csv", index=False, encoding="utf-8")
