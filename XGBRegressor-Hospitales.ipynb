# %% [markdown]
# ### Importaciones

# %%
import pandas as pd
from datetime import datetime
import pandas as pd
import numpy as np
import random
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV, train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %% [markdown]
# #
# Mes -> 	Fecha del mes en formato YYYY-MM-DD. Representa el mes al que corresponden los datos climáticos.
# temperature_2m_max	-> Temperatura máxima promedio del mes medida a 2 metros de altura, en grados Celsius (°C).
# temperature_2m_min -> Temperatura mínima promedio del mes, también a 2 metros de altura, en grados Celsius (°C).
# precipitation_sum -> Precipitación total del mes en milímetros (mm). Suma de toda el agua caída durante ese mes.
# winddirection_10m_dominant -> Dirección dominante del viento a 10 metros de altura, en grados. Se mide en sentido azimutal desde el norte. (Ej.: 0° = norte, 90° = este, etc.).
# SEREMI -> Nombre de la región sanitaria (SEREMI) a la que corresponde esta fila.

# %% [markdown]
# ### Creación de DataSet's de clima mensual por año y SEREMI:

# %%
# 1. Cargar todos los archivos seremi
seremi_data = {
    "2014": pd.read_csv("seremi_2014.csv"),
    "2015": pd.read_csv("seremi_2015.csv"),
    "2016": pd.read_csv("seremi_2016.csv"),
    "2017": pd.read_csv("seremi_2017.csv"),
    "2018": pd.read_csv("seremi_2018.csv"),
    "2019": pd.read_csv("seremi_2019.csv"),
    "2020": pd.read_csv("seremi_2020.csv"),
    "2021": pd.read_csv("seremi_2021.csv"),
    "2022": pd.read_csv("seremi_2022.csv"),
    "2023": pd.read_csv("seremi_2023.csv"),
    "2024": pd.read_csv("seremi_2024.csv"),
    "2025": pd.read_csv("seremi_2025.csv"),
}

# 2. Función para procesar cada dataset climático
def procesar_datasets_climaticos(seremi_data_dict):
    def grados_a_cardinal(grados):
        if pd.isna(grados):
            return None
        direcciones = ['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW']
        index = int((grados + 22.5) % 360 // 45)
        return direcciones[index]

    for año, df in seremi_data_dict.items():
        # Eliminar columna innecesaria
        if "Unnamed: 0" in df.columns:
            df = df.drop(columns=["Unnamed: 0"])

        # Crear columna cardinal
        if "winddirection_10m_dominant" in df.columns:
            df["wind_direction_cardinal"] = df["winddirection_10m_dominant"].apply(grados_a_cardinal)

        # Renombrar columnas
        df = df.rename(columns={
            "temperature_2m_max": "Temperatura Máxima",
            "temperature_2m_min": "Temperatura Mínima",
            "precipitation_sum": "Precipitaciones (suma)",
            "winddirection_10m_dominant": "Dirección Viento"
        })

        # Limpiar columna de grados si existe y renombrar cardinal
        if "Dirección Viento" in df.columns:
            df = df.drop(columns=["Dirección Viento"])
        if "wind_direction_cardinal" in df.columns:
            df = df.rename(columns={"wind_direction_cardinal": "Dirección del Viento"})

        # Guardar el dataframe procesado
        seremi_data_dict[año] = df

    return seremi_data_dict

# 3. Aplicar la función a todos los datasets climáticos
seremi_data = procesar_datasets_climaticos(seremi_data)

# 4. Verificar que todo esté correcto (opcional)
seremi_data["2015"].head(12)
# Out:
#            Mes  Temperatura Máxima  Temperatura Mínima  \
# 0   2015-01-01           12.277419            6.867742
# 1   2015-02-01           12.142857            7.100000
# 2   2015-03-01           11.561290            6.393548
# 3   2015-04-01            9.093333            4.446667
# 4   2015-05-01            5.935484            2.541935
# 5   2015-06-01            3.943333            1.150000
# 6   2015-07-01            3.032258           -0.138710
# 7   2015-08-01            4.180645            0.509677
# 8   2015-09-01            5.266667            1.120000
# 9   2015-10-01            8.925806            2.803226
# 10  2015-11-01            9.626667            4.630000
# 11  2015-12-01           11.200000            5.090323
#
#     Precipitaciones (suma)      SEREMI Dirección del Viento
# 0                     33.7  Magallanes                    W
# 1                     36.9  Magallanes                    W
# 2                     92.1  Magallanes                    W
# 3                     57.9  Magallanes                    W
# 4                    100.0  Magallanes                    S
# 5                     92.8  Magallanes                   SW
# 6                     98.4  Magallanes                   SW
# 7                     59.8  Magallanes                   SW
# 8                     46.0  Magallanes                   SW
# 9                     24.2  Magallanes                   SW
# 10                    44.3  Magallanes                    W
# 11                    26.0  Magallanes                    W

# %% [markdown]
# ### Creación de DataSet's sobre ocupación de camas por mes y por año según hospital y área:

# %%
# Archivos filtrados hospitalarios
archivos_filtrados = {
    "2014": "2014_filtrado.csv",
    "2015": "2015_filtrado.csv",
    "2016": "2016_filtrado.csv",
    "2017": "2017_filtrado.csv",
    "2018": "2018_filtrado.csv",
    "2019": "2019_filtrado.csv",
    "2020": "2020_filtrado.csv",
    "2021": "2021_filtrado.csv",
    "2022": "2022_filtrado.csv",
    "2023": "2023_filtrado.csv",
    "2024": "2024_filtrado.csv",
    "2025": "2025_filtrado.csv"
}

# Diccionario para guardar los dataframes ya limpios
filtrado_limpio = {}

# Abreviaturas de los meses
meses_abreviados = ['Ene', 'Feb', 'Mar', 'Abr', 'May', 'Jun',
                    'Jul', 'Ago', 'Sep', 'Oct', 'Nov', 'Dic']

# Columnas que se eliminarán si existen
columnas_a_eliminar = ["Cód. SS/SEREMI", "Cód. Estab.", "Cód. Nivel Cuidado", "Acum", "Año"]

# Procesamiento de los archivos
for año, archivo in archivos_filtrados.items():
    # Cargar CSV
    df = pd.read_csv(archivo)

    # Eliminar filas irrelevantes
    df = df[~df["Nombre Nivel Cuidado"].isin([
      "330 - Area Pensionado",
      "330 - Área Pensionado",
      "401 - Área Médica Adulto Cuidados Básicos",
      "402 - Área Médica Adulto Cuidados Medios",
      "403 - Área Médico-Quirúrgico Cuidados Básicos",
      "404 - Área Médico-Quirúrgico Cuidados Medios",
      "405 - Área Cuidados Intensivos Adultos",
      "406 - Área Cuidados Intermedios Adultos",
      "407 - Área Médica Pediátrica Cuidados Básicos",
      "408 - Área Médica Pediátrica Cuidados Medios",
      "409 - Área Médico-Quirúrgico Pediátrica Cuidados Básicos",
      "410 - Área Médico-Quirúrgico Pediátrica Cuidados Medios",
      "411 - Área Cuidados Intensivos Pediátricos",
      "412 - Área Cuidados Intermedios Pediátricos",
      "413 - Área Neonatología Cuidados Básicos",
      "414 - Área Neonatología Cuidados Intensivos",
      "415 - Área Neonatología Cuidados Intermedios",
      "416 - Área Obstetricia",
      "418 - Área Psiquiatría Adulto Corta estadía",
      "419 - Área Psiquiatría Adulto Mediana estadía",
      "420 - Área Psiquiatría Adulto Larga estadía",
      "421 - Área Psiquiatría Infanto-adolescente corta estadía",
      "427 - Área Sociosanitaria Adulto",
      "428 - Área de Hospitalización de Cuidados Intensivos en Psiquiatría Adulto",
      "429 - Área de Hospitalización de Cuidados Intensivos en Psiquiatría Infanto Adolescente",
      "Área Cuidados Intensivos Adultos",
      "Área Cuidados Intensivos Pediátricos",
      "Área Cuidados Intermedios Adultos",
      "Área Cuidados Intermedios Pediátricos",
      "Área Médica Adulto Cuidados Básicos",
      "Área Médica Adulto Cuidados Medios",
      "Área Médica Pediátrica Cuidados Básicos",
      "Área Médica Pediátrica Cuidados Medios",
      "Área Médico-Quirúrgico Cuidados Básicos",
      "Área Médico-Quirúrgico Cuidados Medios",
      "Área Médico-Quirúrgico Pediátrica Cuidados Básicos",
      "Área Médico-Quirúrgico Pediátrica Cuidados Medios",
      "Área Neonatología Cuidados Básicos",
      "Área Neonatología Cuidados Intensivos",
      "Área Neonatología Cuidados Intermedios",
      "Área Obstetricia",
      "Área Pensionado",
      "Área Psiquiatría Adulto Corta estadía",
      "Área Psiquiatría Adulto Larga estadía",
      "Área Psiquiatría Adulto Mediana estadía",
      "Área Psiquiatría Infanto-adolescente corta estadía"
    ]
    )].copy()

    # Eliminar columnas innecesarias
    df = df.drop(columns=columnas_a_eliminar, errors='ignore')

    # Renombrar columnas clave
    df = df.rename(columns={
        "Nombre SS/SEREMI": "SEREMI",
        "Nombre Nivel Cuidado": "Area"
    })

    # Renombrar columnas de meses abreviados por fecha
    nuevo_nombre_columnas = {}
    año_int = int(año)

    for i, mes_abrev in enumerate(meses_abreviados, start=1):
        if mes_abrev in df.columns:
            fecha = datetime(año_int, i, 1).strftime('%Y-%m-%d')
            nuevo_nombre_columnas[mes_abrev] = fecha

    df = df.rename(columns=nuevo_nombre_columnas)

    # Guardar DataFrame limpio
    filtrado_limpio[año] = df

# Ejemplo: verificar que todo cargó bien
filtrado_limpio["2020"].head(50)
# Out:
#          SEREMI                             Nombre Establecimiento  \
# 0    Datos País                                         Datos País
# 1    Datos País                                         Datos País
# 2    Datos País                                         Datos País
# 3    Datos País                                         Datos País
# 4    Datos País                                         Datos País
# 5    Datos País                                         Datos País
# 6         Arica                               Datos Servicio Salud
# 7         Arica                               Datos Servicio Salud
# 8         Arica                               Datos Servicio Salud
# 9         Arica                               Datos Servicio Salud
# 10        Arica                               Datos Servicio Salud
# 11        Arica                               Datos Servicio Salud
# 12      Iquique                               Datos Servicio Salud
# 13      Iquique                               Datos Servicio Salud
# 14      Iquique                               Datos Servicio Salud
# 15      Iquique                               Datos Servicio Salud
# 16      Iquique                               Datos Servicio Salud
# 17      Iquique                               Datos Servicio Salud
# 18  Antofagasta                               Datos Servicio Salud
# 19  Antofagasta                               Datos Servicio Salud
# 20  Antofagasta                               Datos Servicio Salud
# 21  Antofagasta                               Datos Servicio Salud
# 22  Antofagasta                               Datos Servicio Salud
# 23  Antofagasta                               Datos Servicio Salud
# 24  Antofagasta                             Hospital de Mejillones
# 25  Antofagasta                             Hospital de Mejillones
# 26  Antofagasta                             Hospital de Mejillones
# 27  Antofagasta                             Hospital de Mejillones
# 28  Antofagasta                             Hospital de Mejillones
# 29  Antofagasta                             Hospital de Mejillones
# 30  Antofagasta                             Hospital de Mejillones
# 31  Antofagasta                             Hospital de Mejillones
# 32  Antofagasta                             Hospital de Mejillones
# 33  Antofagasta                             Hospital de Mejillones
# 56      Atacama                               Datos Servicio Salud
# 57      Atacama                               Datos Servicio Salud
# 58      Atacama                               Datos Servicio Salud
# 59      Atacama                               Datos Servicio Salud
# 60      Atacama                               Datos Servicio Salud
# 61      Atacama                               Datos Servicio Salud
# 62      Atacama  Hospital Provincial del Huasco Monseñor Fernan...
# 63      Atacama  Hospital Provincial del Huasco Monseñor Fernan...
# 64      Atacama  Hospital Provincial del Huasco Monseñor Fernan...
# 65      Atacama  Hospital Provincial del Huasco Monseñor Fernan...
# 66      Atacama  Hospital Provincial del Huasco Monseñor Fernan...
# 67      Atacama  Hospital Provincial del Huasco Monseñor Fernan...
# 68      Atacama  Hospital Provincial del Huasco Monseñor Fernan...
# 69      Atacama  Hospital Provincial del Huasco Monseñor Fernan...
# 70      Atacama  Hospital Provincial del Huasco Monseñor Fernan...
# 71      Atacama  Hospital Provincial del Huasco Monseñor Fernan...
#
#                      Area                      Glosa  2020-01-01  2020-02-01  \
# 0              Datos País      Dias Cama Disponibles   800179.00   745007.00
# 1              Datos País         Dias Cama Ocupados   627256.00   577307.00
# 2              Datos País             Dias de Estada   627876.00   557377.00
# 3              Datos País  Promedio Cama Disponibles    25812.23    25689.90
# 4              Datos País          Numero de Egresos    89177.00    80451.00
# 5              Datos País         Egresos Fallecidos     2605.00     2261.00
# 6    Datos Servicio Salud      Dias Cama Disponibles     9697.00     9066.00
# 7    Datos Servicio Salud         Dias Cama Ocupados     8977.00     8535.00
# 8    Datos Servicio Salud             Dias de Estada     8196.00     7182.00
# 9    Datos Servicio Salud  Promedio Cama Disponibles      312.81      312.62
# 10   Datos Servicio Salud          Numero de Egresos     1434.00     1334.00
# 11   Datos Servicio Salud         Egresos Fallecidos       44.00       32.00
# 12   Datos Servicio Salud      Dias Cama Disponibles    13804.00    12814.00
# 13   Datos Servicio Salud         Dias Cama Ocupados    11014.00     9762.00
# 14   Datos Servicio Salud             Dias de Estada    10667.00    10169.00
# 15   Datos Servicio Salud  Promedio Cama Disponibles      445.29      441.86
# 16   Datos Servicio Salud          Numero de Egresos     1512.00     1535.00
# 17   Datos Servicio Salud         Egresos Fallecidos       38.00       38.00
# 18   Datos Servicio Salud      Dias Cama Disponibles    25388.00    23674.00
# 19   Datos Servicio Salud         Dias Cama Ocupados    19437.00    17909.00
# 20   Datos Servicio Salud             Dias de Estada    18317.00    17316.00
# 21   Datos Servicio Salud  Promedio Cama Disponibles      818.97      816.34
# 22   Datos Servicio Salud          Numero de Egresos     2753.00     2412.00
# 23   Datos Servicio Salud         Egresos Fallecidos       75.00       76.00
# 24  Datos Establecimiento      Dias Cama Disponibles      279.00      261.00
# 25  Datos Establecimiento         Dias Cama Ocupados       79.00       65.00
# 26  Datos Establecimiento             Dias de Estada       79.00       65.00
# 27  Datos Establecimiento  Promedio Cama Disponibles        9.00        9.00
# 28  Datos Establecimiento          Numero de Egresos       13.00       21.00
# 29  Datos Establecimiento         Egresos Fallecidos        0.00        1.00
# 30  Datos Establecimiento         Indice Ocupacional       28.32       24.90
# 31  Datos Establecimiento    Promedio Días de Estada        6.08        3.10
# 32  Datos Establecimiento         Indice de Rotación        1.44        2.33
# 33  Datos Establecimiento                  Letalidad        0.00        4.76
# 56   Datos Servicio Salud      Dias Cama Disponibles    17455.00    16595.00
# 57   Datos Servicio Salud         Dias Cama Ocupados    10688.00    10293.00
# 58   Datos Servicio Salud             Dias de Estada    11080.00     9379.00
# 59   Datos Servicio Salud  Promedio Cama Disponibles      563.06      572.24
# 60   Datos Servicio Salud          Numero de Egresos     1576.00     1545.00
# 61   Datos Servicio Salud         Egresos Fallecidos       36.00       39.00
# 62  Datos Establecimiento      Dias Cama Disponibles     3821.00     3597.00
# 63  Datos Establecimiento         Dias Cama Ocupados     2122.00     2184.00
# 64  Datos Establecimiento             Dias de Estada     1943.00     1926.00
# 65  Datos Establecimiento  Promedio Cama Disponibles      123.26      124.03
# 66  Datos Establecimiento          Numero de Egresos      437.00      447.00
# 67  Datos Establecimiento         Egresos Fallecidos       10.00        6.00
# 68  Datos Establecimiento         Indice Ocupacional       55.54       60.72
# 69  Datos Establecimiento    Promedio Días de Estada        4.45        4.31
# 70  Datos Establecimiento         Indice de Rotación        3.55        3.60
# 71  Datos Establecimiento                  Letalidad        2.29        1.34
#
#     2020-03-01  2020-04-01  2020-05-01  2020-06-01  2020-07-01  2020-08-01  \
# 0    789700.00   745965.00   802598.00   795021.00   832573.00   827810.00
# 1    540914.00   412450.00   477211.00   498858.00   545163.00   557324.00
# 2    602302.00   406231.00   439175.00   503875.00   548854.00   515769.00
# 3     25474.19    24865.50    25890.26    26500.70    26857.19    26703.55
# 4     79438.00    54961.00    58717.00    59720.00    65544.00    66102.00
# 5      2383.00     2246.00     3222.00     4739.00     3864.00     3381.00
# 6      9608.00     9660.00     9688.00    10159.00    11000.00    11674.00
# 7      8042.00     5209.00     6357.00     6985.00     8342.00     8989.00
# 8      9624.00     4785.00     5341.00     5879.00     7435.00     8042.00
# 9       309.94      322.00      312.52      338.63      354.84      376.58
# 10     1362.00      865.00      982.00      980.00     1101.00     1079.00
# 11       38.00       35.00       19.00       42.00       72.00       75.00
# 12    13742.00    13201.00    14041.00    13734.00    13332.00    12806.00
# 13     9547.00     7125.00     8489.00     8579.00     9094.00     9387.00
# 14    10040.00     6277.00     8136.00     7360.00     9155.00     9126.00
# 15      443.29      440.03      452.94      457.80      430.06      413.10
# 16     1576.00     1124.00     1196.00     1060.00     1185.00     1244.00
# 17       48.00       28.00       60.00       96.00       83.00       59.00
# 18    24245.00    21533.00    24470.00    25167.00    27276.00    25930.00
# 19    17263.00    13784.00    16596.00    18633.00    19982.00    19204.00
# 20    18205.00    13625.00    15968.00    17997.00    20581.00    17406.00
# 21      782.10      717.77      789.35      838.90      879.87      836.45
# 22     2510.00     1796.00     1900.00     2076.00     2220.00     2092.00
# 23       83.00       85.00      104.00      193.00      199.00      143.00
# 24      279.00      270.00      279.00      270.00      279.00      279.00
# 25       43.00      256.00        8.00       35.00       45.00       72.00
# 26       43.00      256.00        8.00       35.00       45.00       72.00
# 27        9.00        9.00        9.00        9.00        9.00        9.00
# 28       13.00       14.00        4.00       12.00        6.00       10.00
# 29        0.00        2.00        0.00        0.00        0.00        1.00
# 30       15.41       94.81        2.87       12.96       16.13       25.81
# 31        3.31       18.29        2.00        2.92        7.50        7.20
# 32        1.44        1.56        0.44        1.33        0.67        1.11
# 33        0.00       14.29        0.00        0.00        0.00       10.00
# 56    17372.00    15548.00    15643.00    15180.00    15229.00    15028.00
# 57     9638.00     7568.00     8175.00     8765.00     9338.00     8485.00
# 58    10019.00     7490.00     7100.00     8120.00    10881.00     7753.00
# 59      560.39      518.27      504.61      506.00      491.26      484.77
# 60     1476.00     1064.00     1072.00     1124.00     1268.00     1128.00
# 61       37.00       39.00       38.00       53.00       52.00       70.00
# 62     3732.00     3300.00     3269.00     3187.00     3109.00     3596.00
# 63     2175.00     1685.00     1510.00     1597.00     2055.00     2105.00
# 64     2302.00     2094.00     1287.00     1699.00     2453.00     1864.00
# 65      120.39      110.00      105.45      106.23      100.29      116.00
# 66      426.00      324.00      274.00      299.00      387.00      343.00
# 67       10.00       14.00       16.00       13.00       12.00       23.00
# 68       58.28       51.06       46.19       50.11       66.10       58.54
# 69        5.40        6.46        4.70        5.68        6.34        5.43
# 70        3.54        2.95        2.60        2.81        3.86        2.96
# 71        2.35        4.32        5.84        4.35        3.10        6.71
#
#     2020-09-01  2020-10-01  2020-11-01  2020-12-01
# 0    779335.00   805056.00   776759.00   793770.00
# 1    540777.00   567446.00   559618.00   552408.00
# 2    527973.00   554252.00   532859.00   589847.00
# 3     25977.83    25969.55    25891.97    25605.48
# 4     67836.00    71445.00    70530.00    72361.00
# 5      3026.00     2924.00     2565.00     2799.00
# 6     11427.00    11426.00    11395.00    11337.00
# 7      8223.00     8957.00     8602.00     8269.00
# 8      7151.00     8490.00     7162.00     8778.00
# 9       380.90      368.58      379.83      365.71
# 10     1140.00     1192.00     1165.00     1211.00
# 11       56.00       54.00       44.00       56.00
# 12    12790.00    13639.00    13094.00    13312.00
# 13     9577.00    10686.00    10214.00     9088.00
# 14     9196.00     9341.00     8702.00    10756.00
# 15      426.33      439.97      436.47      429.42
# 16     1194.00     1312.00     1356.00     1419.00
# 17       49.00       48.00       48.00       45.00
# 18    27271.00    28737.00    27173.00    27760.00
# 19    19636.00    20045.00    19558.00    19503.00
# 20    18969.00    19512.00    18295.00    21416.00
# 21      909.03      927.00      905.77      895.48
# 22     2157.00     2414.00     2427.00     2593.00
# 23      106.00      104.00       82.00      113.00
# 24      270.00      270.00      270.00      279.00
# 25      130.00       74.00       36.00       48.00
# 26      130.00       74.00       36.00       48.00
# 27        9.00        8.71        9.00        9.00
# 28       11.00       13.00       11.00       13.00
# 29        1.00        1.00        0.00        0.00
# 30       48.15       27.41       13.33       17.20
# 31       11.82        5.69        3.27        3.69
# 32        1.22        1.49        1.22        1.44
# 33        9.09        7.69        0.00        0.00
# 56    15097.00    15528.00    15820.00    16015.00
# 57     8386.00     9814.00     9682.00     9154.00
# 58     8614.00     8956.00     8867.00    10064.00
# 59      503.23      500.90      527.33      516.61
# 60     1227.00     1380.00     1275.00     1324.00
# 61       46.00       57.00       36.00       51.00
# 62     3196.00     3307.00     3720.00     3844.00
# 63     1743.00     1978.00     1771.00     1999.00
# 64     1638.00     2042.00     1648.00     2019.00
# 65      106.53      106.68      124.00      124.00
# 66      326.00      373.00      348.00      380.00
# 67       13.00       26.00        9.00       12.00
# 68       54.54       59.81       47.61       52.00
# 69        5.02        5.47        4.74        5.31
# 70        3.06        3.50        2.81        3.06
# 71        3.99        6.97        2.59        3.16

# %% [markdown]
# ### Función para unión de datos:

# %%
def extraer_info_hospital_area_todo_el_año(hospital_nombre, area_nombre):
    registros = []

    for año, df in filtrado_limpio.items():
        df_seremi = seremi_data[año].copy()

        # Aseguramos que 'Mes' esté en formato datetime
        df_seremi['Mes'] = pd.to_datetime(df_seremi['Mes'], errors='coerce')
        df_seremi.dropna(subset=['Mes'], inplace=True)
        df_seremi['Mes'] = df_seremi['Mes'].dt.to_period("M").dt.to_timestamp()

        columnas_mes = [col for col in df.columns if col.startswith("20")]
        for col in columnas_mes:
            # Filtro hospitalario por hospital, área y mes
            df_tmp = df[
                (df["Nombre Establecimiento"] == hospital_nombre) &
                (df["Area"] == area_nombre)
            ][["SEREMI", "Nombre Establecimiento", "Area", "Glosa", col]].copy()

            if df_tmp.empty:
                continue

            df_tmp = df_tmp.rename(columns={col: "Valor"})
            df_tmp["Fecha"] = pd.to_datetime(col)

            # Filtro climático por seremi y mes
            clima_mes = df_seremi[df_seremi["Mes"] == df_tmp["Fecha"].iloc[0]].copy()
            df_merge = df_tmp.merge(clima_mes, on=["SEREMI"], how="left")

            registros.append(df_merge)

    if registros:
        return pd.concat(registros, ignore_index=True).sort_values("Fecha")
    else:
        print("⚠️ No se encontraron datos para ese hospital y área.")
        return pd.DataFrame()

# Ejemplo de prueba
ejemplo_df = extraer_info_hospital_area_todo_el_año(
    "Hospital Barros Luco Trudeau (Santiago, San Miguel)",
    "401 - Área Médica Adulto Cuidados Básicos"
)

dataframe=ejemplo_df

dataframe.head()
# Out:
#               SEREMI                             Nombre Establecimiento  \
# 0  Metropolitano Sur  Hospital Barros Luco Trudeau (Santiago, San Mi...
# 1  Metropolitano Sur  Hospital Barros Luco Trudeau (Santiago, San Mi...
# 2  Metropolitano Sur  Hospital Barros Luco Trudeau (Santiago, San Mi...
# 3  Metropolitano Sur  Hospital Barros Luco Trudeau (Santiago, San Mi...
# 4  Metropolitano Sur  Hospital Barros Luco Trudeau (Santiago, San Mi...
#
#                                         Area                      Glosa  \
# 0  401 - Área Médica Adulto Cuidados Básicos      Dias Cama Disponibles
# 1  401 - Área Médica Adulto Cuidados Básicos         Dias Cama Ocupados
# 2  401 - Área Médica Adulto Cuidados Básicos             Dias de Estada
# 3  401 - Área Médica Adulto Cuidados Básicos  Promedio Cama Disponibles
# 4  401 - Área Médica Adulto Cuidados Básicos          Numero de Egresos
#
#     Valor      Fecha        Mes  Temperatura Máxima  Temperatura Mínima  \
# 0  3469.0 2016-01-01 2016-01-01           28.664516                16.0
# 1  3135.0 2016-01-01 2016-01-01           28.664516                16.0
# 2  2879.0 2016-01-01 2016-01-01           28.664516                16.0
# 3   111.9 2016-01-01 2016-01-01           28.664516                16.0
# 4   332.0 2016-01-01 2016-01-01           28.664516                16.0
#
#    Precipitaciones (suma) Dirección del Viento
# 0                    11.2                   SW
# 1                    11.2                   SW
# 2                    11.2                   SW
# 3                    11.2                   SW
# 4                    11.2                   SW

# %% [markdown]
# ### Preparación de datos pre modelación:

# %%
def preparar_dataset_climatico_avanzado(df):
    # Pivotear la tabla para tener una fila por fecha y cada glosa como columna
    df_pivot = df.pivot(index='Fecha', columns='Glosa', values='Valor').reset_index()

    # Comprobamos que estén todas las columnas hospitalarias necesarias
    columnas_necesarias = ['Dias Cama Disponibles', 'Dias Cama Ocupados',
                           'Promedio Cama Disponibles', 'Numero de Egresos']
    if not all(col in df_pivot.columns for col in columnas_necesarias):
        print("❌ Datos insuficientes para generar el modelo.")
        return None

    # Extraemos variables climáticas (asumimos que son iguales por cada fecha para cada hospital)
    clima = df.drop_duplicates(subset='Fecha')[[
        'Fecha', 'Temperatura Máxima', 'Temperatura Mínima',
        'Precipitaciones (suma)', 'Dirección del Viento'
    ]]

    # Merge de hospital + clima
    df_pivot = pd.merge(df_pivot, clima, on='Fecha', how='left')

    # Codificar dirección del viento
    df_pivot = pd.get_dummies(df_pivot, columns=['Dirección del Viento'], prefix='Viento')

    # Orden cronológico
    df_pivot = df_pivot.sort_values('Fecha')
    
    # Variables de tiempo
    df_pivot['Mes'] = df_pivot['Fecha'].dt.month
    df_pivot['Trimestre'] = df_pivot['Fecha'].dt.quarter

    # Lags
    df_pivot['lag_1'] = df_pivot['Dias Cama Disponibles'].shift(1)
    df_pivot['lag_2'] = df_pivot['Dias Cama Disponibles'].shift(2)
    df_pivot['lag_3'] = df_pivot['Dias Cama Disponibles'].shift(3)

    # Media móvil
    df_pivot['media_movil_3'] = df_pivot['Dias Cama Disponibles'].rolling(window=3).mean()

    # Diferencias hospitalarias
    df_pivot['variacion_disponibles'] = df_pivot['Dias Cama Disponibles'].diff()
    df_pivot['porcentaje_ocupacion'] = df_pivot['Dias Cama Ocupados'] / df_pivot['Dias Cama Disponibles']
    df_pivot['ocupados_media_movil'] = df_pivot['Dias Cama Ocupados'].rolling(window=3).mean()
    df_pivot['promedio_media_movil'] = df_pivot['Promedio Cama Disponibles'].rolling(window=3).mean()
    df_pivot['egresos_media_movil'] = df_pivot['Numero de Egresos'].rolling(window=3).mean()

    # Diferencia térmica
    df_pivot['Diferencia Térmica'] = df_pivot['Temperatura Máxima'] - df_pivot['Temperatura Mínima']

    # Tendencias climáticas
    df_pivot['temp_max_movil'] = df_pivot['Temperatura Máxima'].rolling(window=3).mean()
    df_pivot['precipitacion_movil'] = df_pivot['Precipitaciones (suma)'].rolling(window=3).mean()

    # Estacionalidad
    df_pivot['same_month_last_year'] = df_pivot['Dias Cama Disponibles'].shift(12)
    df_pivot['hist_avg_mes'] = df_pivot.groupby('Mes')['Dias Cama Disponibles'].transform('mean')

    # Interacciones cruzadas
    df_pivot['interaccion_ocupacion_temp'] = df_pivot['porcentaje_ocupacion'] * df_pivot['Temperatura Máxima']
    df_pivot['interaccion_precipitacion_disp'] = df_pivot['Precipitaciones (suma)'] * df_pivot['Dias Cama Disponibles']

    return df_pivot.dropna().copy()

# %% [markdown]
# ### Automatización de extración de datos y preparación de dataset - MODELO XGBOOST:

# %% [markdown]
# Estamos prediciendo aproximadamente el 20% de los meses más recientes del historial disponible para ese hospital y área. Por ejemplo:
#
# Si el hospital tiene datos desde 2014 hasta 2025, son 12 años × 12 meses = 144 - 10 (meses faltantes del 2025) -> 134 meses totales.
#
# El 20% de 134 son aprox 27 meses -> estamos prediciendo los últimos 27 meses, desde fines de 2022 hasta marzo de 2025 (en nuestro caso actual).

# %%
def pipeline_final_mae_reducido(hospital, area):
    print(f"🔍 Extrayendo datos para: {hospital} | {area}")
    df_base = extraer_info_hospital_area_todo_el_año(hospital, area)

    if df_base.empty:
        print("❌ No se encontraron datos para el hospital o área especificada.")
        return None

    print("🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...")
    df_modelo = preparar_dataset_climatico_avanzado(df_base)

    if df_modelo is None or df_modelo.empty:
        print("❌ No se pudo preparar el dataset.")
        return None

    # Selección de features
    features = [
        'Dias Cama Ocupados', 'Promedio Cama Disponibles', 'Numero de Egresos',
        'Mes', 'Trimestre', 'lag_1', 'lag_2', 'lag_3', 'media_movil_3',
        'porcentaje_ocupacion', 'variacion_disponibles',
        'ocupados_media_movil', 'promedio_media_movil', 'egresos_media_movil',
        'Temperatura Máxima', 'Temperatura Mínima', 'Precipitaciones (suma)',
        'Diferencia Térmica', 'temp_max_movil', 'precipitacion_movil',
        'same_month_last_year', 'hist_avg_mes',
        'interaccion_ocupacion_temp', 'interaccion_precipitacion_disp'
    ] + [col for col in df_modelo.columns if col.startswith('Viento_')]

    # División temporal
    X = df_modelo[features]
    y = df_modelo['Dias Cama Disponibles']
    X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=False, test_size=0.2)

    print("🔧 Ajustando modelo con GridSearchCV...")
    param_grid = {
        'n_estimators': [50, 100],
        'max_depth': [2, 3],
        'learning_rate': [0.05, 0.1]
    }

    model = XGBRegressor(n_jobs=1, random_state=42)
    grid_search = GridSearchCV(
        estimator=model,
        param_grid=param_grid,
        scoring='neg_mean_absolute_error',
        cv=TimeSeriesSplit(n_splits=3),
        verbose=1
    )
    grid_search.fit(X_train, y_train)
    mejor_modelo = grid_search.best_estimator_
    print("📌 Mejores parámetros encontrados:", grid_search.best_params_)

    print("📊 Evaluando sobre el 20% final de los datos...")

    # Predicción
    y_pred = mejor_modelo.predict(X_test)

    # Cálculo de métricas
    mae = mean_absolute_error(y_test, y_pred)
    rmse = mean_squared_error(y_test, y_pred) ** 0.5
    error_pct = np.mean(np.abs((y_test.values - y_pred) / y_test.values)) * 100

    # Resultado detallado con valores reales y predichos
    resultados = pd.DataFrame({
        'Fecha': df_modelo['Fecha'].iloc[-len(y_test):].values,
        'Real': y_test.values,                  # 🔹 Valores reales observados
        'Predicho': y_pred,                     # 🔹 Valores predichos por el modelo
        'Error Absoluto': np.abs(y_test.values - y_pred),
        'Error Porcentual (%)': np.abs((y_test.values - y_pred) / y_test.values) * 100
    })

    # Reporte resumen
    print(f"✅ MAE (camas): {mae:.2f}")
    print(f"✅ RMSE (camas): {rmse:.2f}")
    print(f"📉 Error promedio porcentual: {error_pct:.2f}%")

    return resultados

# %% [markdown]
# ### Ejemplo de uso - MODELO XGBOOST:

# %%
resultados_final = pipeline_final_mae_reducido(
    "Hospital Barros Luco Trudeau (Santiago, San Miguel)",
    "401 - Área Médica Adulto Cuidados Básicos"
)

display(resultados_final)
# Out:
# 🔍 Extrayendo datos para: Hospital Barros Luco Trudeau (Santiago, San Miguel) | 401 - Área Médica Adulto Cuidados Básicos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 56.44
# ✅ RMSE (camas): 78.82
# 📉 Error promedio porcentual: 2.65%
#         Fecha    Real     Predicho  Error Absoluto  Error Porcentual (%)
# 0  2023-07-01  2325.0  2275.050049       49.949951              2.148385
# 1  2023-08-01  2325.0  2280.936523       44.063477              1.895203
# 2  2023-09-01  2252.0  2310.750488       58.750488              2.608814
# 3  2023-10-01  2334.0  2330.941162        3.058838              0.131056
# 4  2023-11-01  2252.0  2313.443604       61.443604              2.728402
# 5  2023-12-01  2144.0  2099.135254       44.864746              2.092572
# 6  2024-01-01  2146.0  2104.379639       41.620361              1.939439
# 7  2024-02-01  2035.0  2025.235718        9.764282              0.479817
# 8  2024-03-01  2458.0  2339.992920      118.007080              4.800939
# 9  2024-04-01  2400.0  2326.737061       73.262939              3.052622
# 10 2024-05-01  2465.0  2328.431152      136.568848              5.540318
# 11 2024-06-01  1739.0  1988.123779      249.123779             14.325692
# 12 2024-07-01  2173.0  2134.545410       38.454590              1.769654
# 13 2024-08-01  2196.0  2174.131592       21.868408              0.995829
# 14 2024-09-01  2117.0  2170.962402       53.962402              2.549003
# 15 2024-10-01  2131.0  2115.352783       15.647217              0.734266
# 16 2024-11-01  2044.0  2060.729248       16.729248              0.818456
# 17 2024-12-01  2245.0  2218.792969       26.207031              1.167351
# 18 2025-01-01  2152.0  2103.356201       48.643799              2.260400
# 19 2025-02-01  1912.0  1928.751343       16.751343              0.876116

# %% [markdown]
# ### Ejemplo de uso extendido a mas hospitales - MODELO XGBOOST:

# %%
# 1. Función para extraer todos los pares únicos (hospital, área)
def extraer_hospitales_y_areas_validos(filtrado_limpio):
    pares_hospital_area = set()
    for df in filtrado_limpio.values():
        if "Nombre Establecimiento" in df.columns and "Area" in df.columns:
            pares = df[["Nombre Establecimiento", "Area"]].dropna().drop_duplicates()
            for _, row in pares.iterrows():
                pares_hospital_area.add((row["Nombre Establecimiento"], row["Area"]))
    return sorted(list(pares_hospital_area))

# 2. Obtener los pares válidos y limitar a los primeros 30
hospitales_areas_validos = extraer_hospitales_y_areas_validos(filtrado_limpio)
pares_a_evaluar = hospitales_areas_validos[:30]

# 3. Evaluar modelo para cada hospital
resultados_todos = {}

for hospital, area in pares_a_evaluar:
    try:
        print("\n==========================")
        print(f"🏥 Evaluando: {hospital} | Área: {area}")
        print("==========================")
        resultados = pipeline_final_mae_reducido(hospital, area)
        if resultados is not None:
            resultados_todos[f"{hospital} | {area}"] = resultados
    except Exception as e:
        print(f"❌ Error en {hospital} con área {area}: {e}")
        continue

# 4. Crear tabla resumen
tabla_resumen = []

for nombre_completo, resultados in resultados_todos.items():
    if "Error Absoluto" in resultados.columns and "Error Porcentual (%)" in resultados.columns:
        hospital, area = nombre_completo.split(" | ", 1)
        mae = resultados["Error Absoluto"].mean()
        error_pct = resultados["Error Porcentual (%)"].mean()
        tabla_resumen.append({
            "Hospital": hospital,
            "Área": area,
            "MAE (camas)": round(mae, 2),
            "Error Porcentual Promedio (%)": round(error_pct, 2)
        })

# 5. Mostrar tabla ordenada
df_tabla_resumen = pd.DataFrame(tabla_resumen).sort_values("MAE (camas)").reset_index(drop=True)
display(df_tabla_resumen)
# Out:
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: 330 - Área Pensionado
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | 330 - Área Pensionado
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# ❌ No se pudo preparar el dataset.
#
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: 401 - Área Médica Adulto Cuidados Básicos
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | 401 - Área Médica Adulto Cuidados Básicos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 190.52
# ✅ RMSE (camas): 238.21
# 📉 Error promedio porcentual: 9.28%
#
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: 402 - Área Médica Adulto Cuidados Medios
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | 402 - Área Médica Adulto Cuidados Medios
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 11.55
# ✅ RMSE (camas): 21.11
# 📉 Error promedio porcentual: 0.56%
#
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: 403 - Área Médico-Quirúrgico Cuidados Básicos
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | 403 - Área Médico-Quirúrgico Cuidados Básicos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 255.25
# ✅ RMSE (camas): 280.01
# 📉 Error promedio porcentual: 5.47%
#
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: 404 - Área Médico-Quirúrgico Cuidados Medios
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | 404 - Área Médico-Quirúrgico Cuidados Medios
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 57.03
# ✅ RMSE (camas): 123.02
# 📉 Error promedio porcentual: 11.06%
#
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: 405 - Área Cuidados Intensivos Adultos
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | 405 - Área Cuidados Intensivos Adultos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 57.52
# ✅ RMSE (camas): 66.56
# 📉 Error promedio porcentual: 5.59%
#
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: 406 - Área Cuidados Intermedios Adultos
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | 406 - Área Cuidados Intermedios Adultos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 80.69
# ✅ RMSE (camas): 169.28
# 📉 Error promedio porcentual: 5.17%
#
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: 413 - Área Neonatología Cuidados Básicos
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | 413 - Área Neonatología Cuidados Básicos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 4.50
# ✅ RMSE (camas): 8.93
# 📉 Error promedio porcentual: 0.92%
#
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: 414 - Área Neonatología Cuidados Intensivos
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | 414 - Área Neonatología Cuidados Intensivos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 8.10
# ✅ RMSE (camas): 22.44
# 📉 Error promedio porcentual: 2.40%
#
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: 415 - Área Neonatología Cuidados Intermedios
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | 415 - Área Neonatología Cuidados Intermedios
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 11.05
# ✅ RMSE (camas): 18.92
# 📉 Error promedio porcentual: 1.32%
#
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: 416 - Área Obstetricia
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | 416 - Área Obstetricia
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 133.23
# ✅ RMSE (camas): 192.87
# 📉 Error promedio porcentual: 4.72%
#
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: Datos Establecimiento
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 189.85
# ✅ RMSE (camas): 232.91
# 📉 Error promedio porcentual: 1.13%
#
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: Área Cuidados Intensivos Adultos
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | Área Cuidados Intensivos Adultos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 0.76
# ✅ RMSE (camas): 0.78
# 📉 Error promedio porcentual: 0.23%
#
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: Área Cuidados Intermedios Adultos
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | Área Cuidados Intermedios Adultos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 1.36
# ✅ RMSE (camas): 2.12
# 📉 Error promedio porcentual: 0.14%
#
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: Área Médico-Quirúrgico Cuidados Básicos
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | Área Médico-Quirúrgico Cuidados Básicos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 132.24
# ✅ RMSE (camas): 180.11
# 📉 Error promedio porcentual: 1.47%
#
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: Área Médico-Quirúrgico Cuidados Medios
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | Área Médico-Quirúrgico Cuidados Medios
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 102.61
# ✅ RMSE (camas): 112.80
# 📉 Error promedio porcentual: 3.30%
#
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: Área Neonatología Cuidados Básicos
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | Área Neonatología Cuidados Básicos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 7.63
# ✅ RMSE (camas): 9.44
# 📉 Error promedio porcentual: 1.80%
#
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: Área Neonatología Cuidados Intensivos
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | Área Neonatología Cuidados Intensivos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 4.35
# ✅ RMSE (camas): 5.33
# 📉 Error promedio porcentual: 1.08%
#
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: Área Neonatología Cuidados Intermedios
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | Área Neonatología Cuidados Intermedios
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 0.51
# ✅ RMSE (camas): 0.58
# 📉 Error promedio porcentual: 0.06%
#
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: Área Obstetricia
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | Área Obstetricia
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 106.93
# ✅ RMSE (camas): 162.12
# 📉 Error promedio porcentual: 2.89%
#
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: Área Pensionado
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | Área Pensionado
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 2.43
# ✅ RMSE (camas): 2.76
# 📉 Error promedio porcentual: 0.40%
#
# ==========================
# 🏥 Evaluando: Hospital Adalberto Steeger (Talagante) | Área: 330 - Area Pensionado
# ==========================
# 🔍 Extrayendo datos para: Hospital Adalberto Steeger (Talagante) | 330 - Area Pensionado
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 56.58
# ✅ RMSE (camas): 81.23
# 📉 Error promedio porcentual: 26.31%
#
# ==========================
# 🏥 Evaluando: Hospital Adalberto Steeger (Talagante) | Área: 330 - Área Pensionado
# ==========================
# 🔍 Extrayendo datos para: Hospital Adalberto Steeger (Talagante) | 330 - Área Pensionado
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 8.69
# ✅ RMSE (camas): 12.59
# 📉 Error promedio porcentual: 2.14%
#
# ==========================
# 🏥 Evaluando: Hospital Adalberto Steeger (Talagante) | Área: 401 - Área Médica Adulto Cuidados Básicos
# ==========================
# 🔍 Extrayendo datos para: Hospital Adalberto Steeger (Talagante) | 401 - Área Médica Adulto Cuidados Básicos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 19.84
# ✅ RMSE (camas): 35.11
# 📉 Error promedio porcentual: 4.01%
#
# ==========================
# 🏥 Evaluando: Hospital Adalberto Steeger (Talagante) | Área: 402 - Área Médica Adulto Cuidados Medios
# ==========================
# 🔍 Extrayendo datos para: Hospital Adalberto Steeger (Talagante) | 402 - Área Médica Adulto Cuidados Medios
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 72.68
# ✅ RMSE (camas): 98.62
# 📉 Error promedio porcentual: 21.77%
#
# ==========================
# 🏥 Evaluando: Hospital Adalberto Steeger (Talagante) | Área: 403 - Área Médico-Quirúrgico Cuidados Básicos
# ==========================
# 🔍 Extrayendo datos para: Hospital Adalberto Steeger (Talagante) | 403 - Área Médico-Quirúrgico Cuidados Básicos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 27.72
# ✅ RMSE (camas): 35.02
# 📉 Error promedio porcentual: 22.86%
#
# ==========================
# 🏥 Evaluando: Hospital Adalberto Steeger (Talagante) | Área: 404 - Área Médico-Quirúrgico Cuidados Medios
# ==========================
# 🔍 Extrayendo datos para: Hospital Adalberto Steeger (Talagante) | 404 - Área Médico-Quirúrgico Cuidados Medios
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 47.78
# ✅ RMSE (camas): 72.08
# 📉 Error promedio porcentual: 2.52%
#
# ==========================
# 🏥 Evaluando: Hospital Adalberto Steeger (Talagante) | Área: 405 - Área Cuidados Intensivos Adultos
# ==========================
# 🔍 Extrayendo datos para: Hospital Adalberto Steeger (Talagante) | 405 - Área Cuidados Intensivos Adultos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 1.05
# ✅ RMSE (camas): 1.97
# 📉 Error promedio porcentual: 0.60%
#
# ==========================
# 🏥 Evaluando: Hospital Adalberto Steeger (Talagante) | Área: 406 - Área Cuidados Intermedios Adultos
# ==========================
# 🔍 Extrayendo datos para: Hospital Adalberto Steeger (Talagante) | 406 - Área Cuidados Intermedios Adultos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 12.41
# ✅ RMSE (camas): 23.46
# 📉 Error promedio porcentual: 2.47%
#
# ==========================
# 🏥 Evaluando: Hospital Adalberto Steeger (Talagante) | Área: 407 - Área Médica Pediátrica Cuidados Básicos
# ==========================
# 🔍 Extrayendo datos para: Hospital Adalberto Steeger (Talagante) | 407 - Área Médica Pediátrica Cuidados Básicos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 6.44
# ✅ RMSE (camas): 8.82
# 📉 Error promedio porcentual: 3.80%
#                                              Hospital  \
# 0   Complejo Hospitalario San José (Santiago, Inde...
# 1   Complejo Hospitalario San José (Santiago, Inde...
# 2              Hospital Adalberto Steeger (Talagante)
# 3   Complejo Hospitalario San José (Santiago, Inde...
# 4   Complejo Hospitalario San José (Santiago, Inde...
# 5   Complejo Hospitalario San José (Santiago, Inde...
# 6   Complejo Hospitalario San José (Santiago, Inde...
# 7              Hospital Adalberto Steeger (Talagante)
# 8   Complejo Hospitalario San José (Santiago, Inde...
# 9   Complejo Hospitalario San José (Santiago, Inde...
# 10             Hospital Adalberto Steeger (Talagante)
# 11  Complejo Hospitalario San José (Santiago, Inde...
# 12  Complejo Hospitalario San José (Santiago, Inde...
# 13             Hospital Adalberto Steeger (Talagante)
# 14             Hospital Adalberto Steeger (Talagante)
# 15             Hospital Adalberto Steeger (Talagante)
# 16             Hospital Adalberto Steeger (Talagante)
# 17             Hospital Adalberto Steeger (Talagante)
# 18  Complejo Hospitalario San José (Santiago, Inde...
# 19  Complejo Hospitalario San José (Santiago, Inde...
# 20             Hospital Adalberto Steeger (Talagante)
# 21  Complejo Hospitalario San José (Santiago, Inde...
# 22  Complejo Hospitalario San José (Santiago, Inde...
# 23  Complejo Hospitalario San José (Santiago, Inde...
# 24  Complejo Hospitalario San José (Santiago, Inde...
# 25  Complejo Hospitalario San José (Santiago, Inde...
# 26  Complejo Hospitalario San José (Santiago, Inde...
# 27  Complejo Hospitalario San José (Santiago, Inde...
# 28  Complejo Hospitalario San José (Santiago, Inde...
#
#                                              Área  MAE (camas)  \
# 0          Área Neonatología Cuidados Intermedios         0.51
# 1                Área Cuidados Intensivos Adultos         0.76
# 2          405 - Área Cuidados Intensivos Adultos         1.05
# 3               Área Cuidados Intermedios Adultos         1.36
# 4                                 Área Pensionado         2.43
# 5           Área Neonatología Cuidados Intensivos         4.35
# 6        413 - Área Neonatología Cuidados Básicos         4.50
# 7   407 - Área Médica Pediátrica Cuidados Básicos         6.44
# 8              Área Neonatología Cuidados Básicos         7.63
# 9     414 - Área Neonatología Cuidados Intensivos         8.10
# 10                          330 - Área Pensionado         8.69
# 11   415 - Área Neonatología Cuidados Intermedios        11.05
# 12       402 - Área Médica Adulto Cuidados Medios        11.55
# 13        406 - Área Cuidados Intermedios Adultos        12.41
# 14      401 - Área Médica Adulto Cuidados Básicos        19.84
# 15  403 - Área Médico-Quirúrgico Cuidados Básicos        27.72
# 16   404 - Área Médico-Quirúrgico Cuidados Medios        47.78
# 17                          330 - Area Pensionado        56.58
# 18   404 - Área Médico-Quirúrgico Cuidados Medios        57.03
# 19         405 - Área Cuidados Intensivos Adultos        57.52
# 20       402 - Área Médica Adulto Cuidados Medios        72.68
# 21        406 - Área Cuidados Intermedios Adultos        80.69
# 22         Área Médico-Quirúrgico Cuidados Medios       102.61
# 23                               Área Obstetricia       106.93
# 24        Área Médico-Quirúrgico Cuidados Básicos       132.24
# 25                         416 - Área Obstetricia       133.23
# 26                          Datos Establecimiento       189.85
# 27      401 - Área Médica Adulto Cuidados Básicos       190.52
# 28  403 - Área Médico-Quirúrgico Cuidados Básicos       255.25
#
#     Error Porcentual Promedio (%)
# 0                            0.06
# 1                            0.23
# 2                            0.60
# 3                            0.14
# 4                            0.40
# 5                            1.08
# 6                            0.92
# 7                            3.80
# 8                            1.80
# 9                            2.40
# 10                           2.14
# 11                           1.32
# 12                           0.56
# 13                           2.47
# 14                           4.01
# 15                          22.86
# 16                           2.52
# 17                          26.31
# 18                          11.06
# 19                           5.59
# 20                          21.77
# 21                           5.17
# 22                           3.30
# 23                           2.89
# 24                           1.47
# 25                           4.72
# 26                           1.13
# 27                           9.28
# 28                           5.47

# %% [markdown]
# ### Listado y cantidad de hospitales con los que trabaja el modelo:

# %%
def obtener_lista_hospitales(filtrado_limpio):
    hospitales = set()
    
    for año, df in filtrado_limpio.items():
        if "Nombre Establecimiento" in df.columns:
            hospitales.update(df["Nombre Establecimiento"].dropna().unique())
    
    return sorted(list(hospitales))

# %%
lista_hospitales = obtener_lista_hospitales(filtrado_limpio)
print(f"Se encontraron {len(lista_hospitales)} hospitales.")
for h in lista_hospitales[:10]:  # muestra los primeros 10 como ejemplo
    print("🏥", h)
# Out:
# Se encontraron 92 hospitales.
# 🏥 Complejo Hospitalario San José (Santiago, Independencia)
# 🏥 Hospital Adalberto Steeger (Talagante)
# 🏥 Hospital Adriana Cousiño (Quintero)
# 🏥 Hospital Barros Luco Trudeau (Santiago, San Miguel)
# 🏥 Hospital Carlos Van Buren (Valparaíso)
# 🏥 Hospital Centro Geriátrico Paz de la Tarde (Limache)
# 🏥 Hospital Clorinda Avello (Santa Juana)
# 🏥 Hospital Clínico Herminda Martín (Chillán)
# 🏥 Hospital Comunitario de Salud Familiar Pedro Morales Campos (Yungay)
# 🏥 Hospital Comunitario de Salud Familiar de Bulnes

# %% [markdown]
# #
# 92 hospitales comunes entre 2014 y 2025

# %% [markdown]
# ### Listado y cantidad de Áreas Médicas con los que trabaja el modelo:

# %%
def obtener_lista_areas(filtrado_limpio):
    areas = set()
    
    for año, df in filtrado_limpio.items():
        if "Area" in df.columns:
            areas.update(df["Area"].dropna().unique())
    
    return sorted(list(areas))

# %%
lista_areas = obtener_lista_areas(filtrado_limpio)
print(f"Se encontraron {len(lista_areas)} áreas médicas.")
for a in lista_areas[:48]:  # muestra las primeras 10 como ejemplo
    print("📌", a)
# Out:
# Se encontraron 47 áreas médicas.
# 📌 330 - Area Pensionado
# 📌 330 - Área Pensionado
# 📌 401 - Área Médica Adulto Cuidados Básicos
# 📌 402 - Área Médica Adulto Cuidados Medios
# 📌 403 - Área Médico-Quirúrgico Cuidados Básicos
# 📌 404 - Área Médico-Quirúrgico Cuidados Medios
# 📌 405 - Área Cuidados Intensivos Adultos
# 📌 406 - Área Cuidados Intermedios Adultos
# 📌 407 - Área Médica Pediátrica Cuidados Básicos
# 📌 408 - Área Médica Pediátrica Cuidados Medios
# 📌 409 - Área Médico-Quirúrgico Pediátrica Cuidados Básicos
# 📌 410 - Área Médico-Quirúrgico Pediátrica Cuidados Medios
# 📌 411 - Área Cuidados Intensivos Pediátricos
# 📌 412 - Área Cuidados Intermedios Pediátricos
# 📌 413 - Área Neonatología Cuidados Básicos
# 📌 414 - Área Neonatología Cuidados Intensivos
# 📌 415 - Área Neonatología Cuidados Intermedios
# 📌 416 - Área Obstetricia
# 📌 418 - Área Psiquiatría Adulto Corta estadía
# 📌 419 - Área Psiquiatría Adulto Mediana estadía
# 📌 420 - Área Psiquiatría Adulto Larga estadía
# 📌 421 - Área Psiquiatría Infanto-adolescente corta estadía
# 📌 427 - Área Sociosanitaria Adulto
# 📌 428 - Área de Hospitalización de Cuidados Intensivos en Psiquiatría Adulto
# 📌 429 - Área de Hospitalización de Cuidados Intensivos en Psiquiatría Infanto Adolescente
# 📌 Datos Establecimiento
# 📌 Área Cuidados Intensivos Adultos
# 📌 Área Cuidados Intensivos Pediátricos
# 📌 Área Cuidados Intermedios Adultos
# 📌 Área Cuidados Intermedios Pediátricos
# 📌 Área Médica Adulto Cuidados Básicos
# 📌 Área Médica Adulto Cuidados Medios
# 📌 Área Médica Pediátrica Cuidados Básicos
# 📌 Área Médica Pediátrica Cuidados Medios
# 📌 Área Médico-Quirúrgico Cuidados Básicos
# 📌 Área Médico-Quirúrgico Cuidados Medios
# 📌 Área Médico-Quirúrgico Pediátrica Cuidados Básicos
# 📌 Área Médico-Quirúrgico Pediátrica Cuidados Medios
# 📌 Área Neonatología Cuidados Básicos
# 📌 Área Neonatología Cuidados Intensivos
# 📌 Área Neonatología Cuidados Intermedios
# 📌 Área Obstetricia
# 📌 Área Pensionado
# 📌 Área Psiquiatría Adulto Corta estadía
# 📌 Área Psiquiatría Adulto Larga estadía
# 📌 Área Psiquiatría Adulto Mediana estadía
# 📌 Área Psiquiatría Infanto-adolescente corta estadía

# %% [markdown]
# ### XGBOOST para predicción futura: (MODO ENTRENAMIENTO)

# %%
def predecir_camas_mes_futuro(hospital, area, modo="entrenamiento", mes_futuro=None):
    print(f"🔍 Extrayendo datos para: {hospital} | {area}")
    df_base = extraer_info_hospital_area_todo_el_año(hospital, area)

    if df_base.empty:
        print("❌ No se encontraron datos para el hospital o área especificada.")
        return None

    print("🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...")
    df_modelo = preparar_dataset_climatico_avanzado(df_base)

    if df_modelo is None or df_modelo.empty:
        print("❌ No se pudo preparar el dataset.")
        return None

    # Selección de features
    features = [
        'Dias Cama Ocupados', 'Promedio Cama Disponibles', 'Numero de Egresos',
        'Mes', 'Trimestre', 'lag_1', 'lag_2', 'lag_3', 'media_movil_3',
        'porcentaje_ocupacion', 'variacion_disponibles',
        'ocupados_media_movil', 'promedio_media_movil', 'egresos_media_movil',
        'Temperatura Máxima', 'Temperatura Mínima', 'Precipitaciones (suma)',
        'Diferencia Térmica', 'temp_max_movil', 'precipitacion_movil',
        'same_month_last_year', 'hist_avg_mes',
        'interaccion_ocupacion_temp', 'interaccion_precipitacion_disp'
    ] + [col for col in df_modelo.columns if col.startswith('Viento_')]

    X = df_modelo[features]
    y = df_modelo['Dias Cama Disponibles']

    if modo == "entrenamiento":
        # División entrenamiento/test
        X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=False, test_size=0.2)

        print("🔧 Ajustando modelo con GridSearchCV...")
        param_grid = {
            'n_estimators': [50, 100],
            'max_depth': [2, 3],
            'learning_rate': [0.05, 0.1]
        }

        model = XGBRegressor(n_jobs=1, random_state=42)
        grid_search = GridSearchCV(
            estimator=model,
            param_grid=param_grid,
            scoring='neg_mean_absolute_error',
            cv=TimeSeriesSplit(n_splits=3),
            verbose=0
        )
        grid_search.fit(X_train, y_train)
        mejor_modelo = grid_search.best_estimator_

        print("📌 Mejores parámetros encontrados:", grid_search.best_params_)
        print("📊 Evaluando sobre el 20% final de los datos...")

        y_pred = mejor_modelo.predict(X_test)
        mae = mean_absolute_error(y_test, y_pred)
        rmse = mean_squared_error(y_test, y_pred) ** 0.5
        error_pct = np.mean(np.abs((y_test.values - y_pred) / y_test.values)) * 100

        print(f"✅ MAE (camas): {mae:.2f}")
        print(f"✅ RMSE (camas): {rmse:.2f}")
        print(f"📉 Error promedio porcentual: {error_pct:.2f}%")

        resultados = pd.DataFrame({
            'Fecha': df_modelo['Fecha'].iloc[-len(y_test):].values,
            'Real': y_test.values,
            'Predicho': y_pred,
            'Error Absoluto': np.abs(y_test.values - y_pred),
            'Error Porcentual (%)': np.abs((y_test.values - y_pred) / y_test.values) * 100
        })

        return resultados

    else:
        print("⚠️ Modo no reconocido o no implementado aún.")
        return None

# %%
# Crear resultados para entrenamiento iterando hospitales
resultados_entrenamiento_todos = []

for hospital in lista_hospitales:

    if not lista_areas:
        continue

    area_random = random.choice(lista_areas)
    try:
        print("\n==========================")
        print(f"🏥 Evaluando entrenamiento: {hospital} | Área aleatoria: {area_random}")
        print("==========================")

        resultado_entrenamiento = predecir_camas_mes_futuro(
            hospital=hospital,
            area=area_random,
            modo="entrenamiento"
        )

        if resultado_entrenamiento is not None:
            resultado_entrenamiento["Hospital"] = hospital
            resultado_entrenamiento["Área"] = area_random
            resultados_entrenamiento_todos.append(resultado_entrenamiento)

    except Exception as e:
        print(f"❌ Error en {hospital} | Área: {area_random} -> {e}")
        continue
# Out:
# ==========================
# 🏥 Evaluando entrenamiento: Complejo Hospitalario San José (Santiago, Independencia) | Área aleatoria: Área Médico-Quirúrgico Cuidados Medios
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | Área Médico-Quirúrgico Cuidados Medios
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 102.61
# ✅ RMSE (camas): 112.80
# 📉 Error promedio porcentual: 3.30%
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital Adalberto Steeger (Talagante) | Área aleatoria: 401 - Área Médica Adulto Cuidados Básicos
# ==========================
# 🔍 Extrayendo datos para: Hospital Adalberto Steeger (Talagante) | 401 - Área Médica Adulto Cuidados Básicos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 19.84
# ✅ RMSE (camas): 35.11
# 📉 Error promedio porcentual: 4.01%
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital Adriana Cousiño (Quintero) | Área aleatoria: 401 - Área Médica Adulto Cuidados Básicos
# ==========================
# 🔍 Extrayendo datos para: Hospital Adriana Cousiño (Quintero) | 401 - Área Médica Adulto Cuidados Básicos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 13.53
# ✅ RMSE (camas): 26.84
# 📉 Error promedio porcentual: 2.09%
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital Barros Luco Trudeau (Santiago, San Miguel) | Área aleatoria: 414 - Área Neonatología Cuidados Intensivos
# ==========================
# 🔍 Extrayendo datos para: Hospital Barros Luco Trudeau (Santiago, San Miguel) | 414 - Área Neonatología Cuidados Intensivos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 0.78
# ✅ RMSE (camas): 1.53
# 📉 Error promedio porcentual: 0.20%
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital Carlos Van Buren (Valparaíso) | Área aleatoria: Área Neonatología Cuidados Intensivos
# ==========================
# 🔍 Extrayendo datos para: Hospital Carlos Van Buren (Valparaíso) | Área Neonatología Cuidados Intensivos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 2.13
# ✅ RMSE (camas): 2.43
# 📉 Error promedio porcentual: 1.16%
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital Centro Geriátrico Paz de la Tarde (Limache) | Área aleatoria: 429 - Área de Hospitalización de Cuidados Intensivos en Psiquiatría Infanto Adolescente
# ==========================
# 🔍 Extrayendo datos para: Hospital Centro Geriátrico Paz de la Tarde (Limache) | 429 - Área de Hospitalización de Cuidados Intensivos en Psiquiatría Infanto Adolescente
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital Clorinda Avello (Santa Juana) | Área aleatoria: Área Cuidados Intermedios Adultos
# ==========================
# 🔍 Extrayendo datos para: Hospital Clorinda Avello (Santa Juana) | Área Cuidados Intermedios Adultos
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital Clínico Herminda Martín (Chillán) | Área aleatoria: 421 - Área Psiquiatría Infanto-adolescente corta estadía
# ==========================
# 🔍 Extrayendo datos para: Hospital Clínico Herminda Martín (Chillán) | 421 - Área Psiquiatría Infanto-adolescente corta estadía
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital Comunitario de Salud Familiar Pedro Morales Campos (Yungay) | Área aleatoria: 330 - Area Pensionado
# ==========================
# 🔍 Extrayendo datos para: Hospital Comunitario de Salud Familiar Pedro Morales Campos (Yungay) | 330 - Area Pensionado
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital Comunitario de Salud Familiar de Bulnes | Área aleatoria: Área Médico-Quirúrgico Cuidados Básicos
# ==========================
# 🔍 Extrayendo datos para: Hospital Comunitario de Salud Familiar de Bulnes | Área Médico-Quirúrgico Cuidados Básicos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 2.13
# ✅ RMSE (camas): 2.15
# 📉 Error promedio porcentual: 0.19%
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital Comunitario de Salud Familiar de El Carmen | Área aleatoria: Área Cuidados Intermedios Adultos
# ==========================
# 🔍 Extrayendo datos para: Hospital Comunitario de Salud Familiar de El Carmen | Área Cuidados Intermedios Adultos
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital Comunitario de Salud Familiar de Quirihue | Área aleatoria: 413 - Área Neonatología Cuidados Básicos
# ==========================
# 🔍 Extrayendo datos para: Hospital Comunitario de Salud Familiar de Quirihue | 413 - Área Neonatología Cuidados Básicos
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital El Pino (Santiago, San Bernardo) | Área aleatoria: 428 - Área de Hospitalización de Cuidados Intensivos en Psiquiatría Adulto
# ==========================
# 🔍 Extrayendo datos para: Hospital El Pino (Santiago, San Bernardo) | 428 - Área de Hospitalización de Cuidados Intensivos en Psiquiatría Adulto
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital Hanga Roa (Isla De Pascua) | Área aleatoria: 414 - Área Neonatología Cuidados Intensivos
# ==========================
# 🔍 Extrayendo datos para: Hospital Hanga Roa (Isla De Pascua) | 414 - Área Neonatología Cuidados Intensivos
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital Intercultural Kallvu Llanka (Cañete) | Área aleatoria: Área Neonatología Cuidados Básicos
# ==========================
# 🔍 Extrayendo datos para: Hospital Intercultural Kallvu Llanka (Cañete) | Área Neonatología Cuidados Básicos
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital Juan Morey (La Unión) | Área aleatoria: 428 - Área de Hospitalización de Cuidados Intensivos en Psiquiatría Adulto
# ==========================
# 🔍 Extrayendo datos para: Hospital Juan Morey (La Unión) | 428 - Área de Hospitalización de Cuidados Intensivos en Psiquiatría Adulto
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital Juana Ross de Edwards (Peñablanca, Villa Alemana) | Área aleatoria: 405 - Área Cuidados Intensivos Adultos
# ==========================
# 🔍 Extrayendo datos para: Hospital Juana Ross de Edwards (Peñablanca, Villa Alemana) | 405 - Área Cuidados Intensivos Adultos
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital Las Higueras (Talcahuano) | Área aleatoria: 428 - Área de Hospitalización de Cuidados Intensivos en Psiquiatría Adulto
# ==========================
# 🔍 Extrayendo datos para: Hospital Las Higueras (Talcahuano) | 428 - Área de Hospitalización de Cuidados Intensivos en Psiquiatría Adulto
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital Lord Cochrane | Área aleatoria: 411 - Área Cuidados Intensivos Pediátricos
# ==========================
# 🔍 Extrayendo datos para: Hospital Lord Cochrane | 411 - Área Cuidados Intensivos Pediátricos
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital Padre Alberto Hurtado (San Ramón) | Área aleatoria: Área Neonatología Cuidados Intensivos
# ==========================
# 🔍 Extrayendo datos para: Hospital Padre Alberto Hurtado (San Ramón) | Área Neonatología Cuidados Intensivos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 4.06
# ✅ RMSE (camas): 5.47
# 📉 Error promedio porcentual: 9.53%
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital Presidente Carlos Ibáñez del Campo (Linares) | Área aleatoria: Área Neonatología Cuidados Básicos
# ==========================
# 🔍 Extrayendo datos para: Hospital Presidente Carlos Ibáñez del Campo (Linares) | Área Neonatología Cuidados Básicos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 6.60
# ✅ RMSE (camas): 6.93
# 📉 Error promedio porcentual: 1.06%
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital Provincial del Huasco Monseñor Fernando Ariztía Ruiz (Vallenar) | Área aleatoria: 408 - Área Médica Pediátrica Cuidados Medios
# ==========================
# 🔍 Extrayendo datos para: Hospital Provincial del Huasco Monseñor Fernando Ariztía Ruiz (Vallenar) | 408 - Área Médica Pediátrica Cuidados Medios
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 4.77
# ✅ RMSE (camas): 7.46
# 📉 Error promedio porcentual: 3.97%
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital Psiquiátrico El Peral (Santiago, Puente Alto) | Área aleatoria: Área Neonatología Cuidados Intermedios
# ==========================
# 🔍 Extrayendo datos para: Hospital Psiquiátrico El Peral (Santiago, Puente Alto) | Área Neonatología Cuidados Intermedios
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital San Agustín (La Ligua) | Área aleatoria: Área Obstetricia
# ==========================
# 🔍 Extrayendo datos para: Hospital San Agustín (La Ligua) | Área Obstetricia
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 7.24
# ✅ RMSE (camas): 8.45
# 📉 Error promedio porcentual: 1.06%
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital San Antonio (Putaendo) | Área aleatoria: Área Médico-Quirúrgico Pediátrica Cuidados Medios
# ==========================
# 🔍 Extrayendo datos para: Hospital San Antonio (Putaendo) | Área Médico-Quirúrgico Pediátrica Cuidados Medios
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital San Francisco (Llaillay) | Área aleatoria: Área Médico-Quirúrgico Pediátrica Cuidados Medios
# ==========================
# 🔍 Extrayendo datos para: Hospital San Francisco (Llaillay) | Área Médico-Quirúrgico Pediátrica Cuidados Medios
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital San José (Casablanca) | Área aleatoria: Área Neonatología Cuidados Básicos
# ==========================
# 🔍 Extrayendo datos para: Hospital San José (Casablanca) | Área Neonatología Cuidados Básicos
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital San José (Coronel) | Área aleatoria: Área Médica Adulto Cuidados Medios
# ==========================
# 🔍 Extrayendo datos para: Hospital San José (Coronel) | Área Médica Adulto Cuidados Medios
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 8.24
# ✅ RMSE (camas): 8.55
# 📉 Error promedio porcentual: 4.24%
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital San José (Melipilla) | Área aleatoria: Área Cuidados Intensivos Adultos
# ==========================
# 🔍 Extrayendo datos para: Hospital San José (Melipilla) | Área Cuidados Intensivos Adultos
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital San José (Parral) | Área aleatoria: Área Cuidados Intensivos Adultos
# ==========================
# 🔍 Extrayendo datos para: Hospital San José (Parral) | Área Cuidados Intensivos Adultos
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital San José de Maipo | Área aleatoria: 420 - Área Psiquiatría Adulto Larga estadía
# ==========================
# 🔍 Extrayendo datos para: Hospital San José de Maipo | 420 - Área Psiquiatría Adulto Larga estadía
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital San Juan de Dios (Cauquenes) | Área aleatoria: 330 - Área Pensionado
# ==========================
# 🔍 Extrayendo datos para: Hospital San Juan de Dios (Cauquenes) | 330 - Área Pensionado
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 0.35
# ✅ RMSE (camas): 0.35
# 📉 Error promedio porcentual: 0.23%
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital San Juan de Dios (Combarbalá) | Área aleatoria: 420 - Área Psiquiatría Adulto Larga estadía
# ==========================
# 🔍 Extrayendo datos para: Hospital San Juan de Dios (Combarbalá) | 420 - Área Psiquiatría Adulto Larga estadía
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital San Juan de Dios (Curicó) | Área aleatoria: 401 - Área Médica Adulto Cuidados Básicos
# ==========================
# 🔍 Extrayendo datos para: Hospital San Juan de Dios (Curicó) | 401 - Área Médica Adulto Cuidados Básicos
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital San Juan de Dios (La Serena) | Área aleatoria: Área Psiquiatría Adulto Larga estadía
# ==========================
# 🔍 Extrayendo datos para: Hospital San Juan de Dios (La Serena) | Área Psiquiatría Adulto Larga estadía
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital San Juan de Dios (Los Andes) | Área aleatoria: 406 - Área Cuidados Intermedios Adultos
# ==========================
# 🔍 Extrayendo datos para: Hospital San Juan de Dios (Los Andes) | 406 - Área Cuidados Intermedios Adultos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 36.83
# ✅ RMSE (camas): 52.21
# 📉 Error promedio porcentual: 10.28%
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital San Juan de Dios (Santiago, Santiago) | Área aleatoria: Área Médico-Quirúrgico Pediátrica Cuidados Básicos
# ==========================
# 🔍 Extrayendo datos para: Hospital San Juan de Dios (Santiago, Santiago) | Área Médico-Quirúrgico Pediátrica Cuidados Básicos
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital San Luis (Buin) | Área aleatoria: 402 - Área Médica Adulto Cuidados Medios
# ==========================
# 🔍 Extrayendo datos para: Hospital San Luis (Buin) | 402 - Área Médica Adulto Cuidados Medios
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 16.29
# ✅ RMSE (camas): 19.25
# 📉 Error promedio porcentual: 2.26%
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital San Pablo (Coquimbo) | Área aleatoria: Área Neonatología Cuidados Intensivos
# ==========================
# 🔍 Extrayendo datos para: Hospital San Pablo (Coquimbo) | Área Neonatología Cuidados Intensivos
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital San Pedro (Los Vilos) | Área aleatoria: 402 - Área Médica Adulto Cuidados Medios
# ==========================
# 🔍 Extrayendo datos para: Hospital San Pedro (Los Vilos) | 402 - Área Médica Adulto Cuidados Medios
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# ❌ No se pudo preparar el dataset.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital San Vicente de Tagua-Tagua | Área aleatoria: Área Médica Pediátrica Cuidados Medios
# ==========================
# 🔍 Extrayendo datos para: Hospital San Vicente de Tagua-Tagua | Área Médica Pediátrica Cuidados Medios
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital Traumatológico (Concepción) | Área aleatoria: Área Médico-Quirúrgico Cuidados Medios
# ==========================
# 🔍 Extrayendo datos para: Hospital Traumatológico (Concepción) | Área Médico-Quirúrgico Cuidados Medios
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Ancud | Área aleatoria: Área Médica Pediátrica Cuidados Medios
# ==========================
# 🔍 Extrayendo datos para: Hospital de Ancud | Área Médica Pediátrica Cuidados Medios
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# ❌ No se pudo preparar el dataset.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Calbuco | Área aleatoria: 413 - Área Neonatología Cuidados Básicos
# ==========================
# 🔍 Extrayendo datos para: Hospital de Calbuco | 413 - Área Neonatología Cuidados Básicos
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Carahue | Área aleatoria: 409 - Área Médico-Quirúrgico Pediátrica Cuidados Básicos
# ==========================
# 🔍 Extrayendo datos para: Hospital de Carahue | 409 - Área Médico-Quirúrgico Pediátrica Cuidados Básicos
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Castro | Área aleatoria: 415 - Área Neonatología Cuidados Intermedios
# ==========================
# 🔍 Extrayendo datos para: Hospital de Castro | 415 - Área Neonatología Cuidados Intermedios
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 5.61
# ✅ RMSE (camas): 6.85
# 📉 Error promedio porcentual: 3.56%
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Collipulli | Área aleatoria: Datos Establecimiento
# ==========================
# 🔍 Extrayendo datos para: Hospital de Collipulli | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 93.62
# ✅ RMSE (camas): 112.02
# 📉 Error promedio porcentual: 9.45%
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Constitución | Área aleatoria: 407 - Área Médica Pediátrica Cuidados Básicos
# ==========================
# 🔍 Extrayendo datos para: Hospital de Constitución | 407 - Área Médica Pediátrica Cuidados Básicos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 2.97
# ✅ RMSE (camas): 4.97
# 📉 Error promedio porcentual: 0.65%
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Contulmo | Área aleatoria: Área Médica Adulto Cuidados Medios
# ==========================
# 🔍 Extrayendo datos para: Hospital de Contulmo | Área Médica Adulto Cuidados Medios
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Corral | Área aleatoria: Área Cuidados Intensivos Pediátricos
# ==========================
# 🔍 Extrayendo datos para: Hospital de Corral | Área Cuidados Intensivos Pediátricos
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Curacaví | Área aleatoria: 415 - Área Neonatología Cuidados Intermedios
# ==========================
# 🔍 Extrayendo datos para: Hospital de Curacaví | 415 - Área Neonatología Cuidados Intermedios
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Curepto | Área aleatoria: Área Obstetricia
# ==========================
# 🔍 Extrayendo datos para: Hospital de Curepto | Área Obstetricia
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Fresia | Área aleatoria: 408 - Área Médica Pediátrica Cuidados Medios
# ==========================
# 🔍 Extrayendo datos para: Hospital de Fresia | 408 - Área Médica Pediátrica Cuidados Medios
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Frutillar | Área aleatoria: 413 - Área Neonatología Cuidados Básicos
# ==========================
# 🔍 Extrayendo datos para: Hospital de Frutillar | 413 - Área Neonatología Cuidados Básicos
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Futaleufú | Área aleatoria: 428 - Área de Hospitalización de Cuidados Intensivos en Psiquiatría Adulto
# ==========================
# 🔍 Extrayendo datos para: Hospital de Futaleufú | 428 - Área de Hospitalización de Cuidados Intensivos en Psiquiatría Adulto
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Galvarino | Área aleatoria: Área Pensionado
# ==========================
# 🔍 Extrayendo datos para: Hospital de Galvarino | Área Pensionado
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Gorbea | Área aleatoria: 409 - Área Médico-Quirúrgico Pediátrica Cuidados Básicos
# ==========================
# 🔍 Extrayendo datos para: Hospital de Gorbea | 409 - Área Médico-Quirúrgico Pediátrica Cuidados Básicos
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Hualañé | Área aleatoria: Área Médica Adulto Cuidados Medios
# ==========================
# 🔍 Extrayendo datos para: Hospital de Hualañé | Área Médica Adulto Cuidados Medios
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Lanco | Área aleatoria: 429 - Área de Hospitalización de Cuidados Intensivos en Psiquiatría Infanto Adolescente
# ==========================
# 🔍 Extrayendo datos para: Hospital de Lanco | 429 - Área de Hospitalización de Cuidados Intensivos en Psiquiatría Infanto Adolescente
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Lebu | Área aleatoria: 330 - Área Pensionado
# ==========================
# 🔍 Extrayendo datos para: Hospital de Lebu | 330 - Área Pensionado
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Litueche | Área aleatoria: Área Psiquiatría Adulto Corta estadía
# ==========================
# 🔍 Extrayendo datos para: Hospital de Litueche | Área Psiquiatría Adulto Corta estadía
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Llanquihue | Área aleatoria: Área Neonatología Cuidados Intensivos
# ==========================
# 🔍 Extrayendo datos para: Hospital de Llanquihue | Área Neonatología Cuidados Intensivos
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Lolol | Área aleatoria: Área Psiquiatría Adulto Mediana estadía
# ==========================
# 🔍 Extrayendo datos para: Hospital de Lolol | Área Psiquiatría Adulto Mediana estadía
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Lonquimay | Área aleatoria: 416 - Área Obstetricia
# ==========================
# 🔍 Extrayendo datos para: Hospital de Lonquimay | 416 - Área Obstetricia
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Los Lagos | Área aleatoria: 408 - Área Médica Pediátrica Cuidados Medios
# ==========================
# 🔍 Extrayendo datos para: Hospital de Los Lagos | 408 - Área Médica Pediátrica Cuidados Medios
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Lota | Área aleatoria: Área Médica Pediátrica Cuidados Medios
# ==========================
# 🔍 Extrayendo datos para: Hospital de Lota | Área Médica Pediátrica Cuidados Medios
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Marchigüe | Área aleatoria: 419 - Área Psiquiatría Adulto Mediana estadía
# ==========================
# 🔍 Extrayendo datos para: Hospital de Marchigüe | 419 - Área Psiquiatría Adulto Mediana estadía
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Maullín | Área aleatoria: Área Psiquiatría Infanto-adolescente corta estadía
# ==========================
# 🔍 Extrayendo datos para: Hospital de Maullín | Área Psiquiatría Infanto-adolescente corta estadía
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Mejillones | Área aleatoria: 409 - Área Médico-Quirúrgico Pediátrica Cuidados Básicos
# ==========================
# 🔍 Extrayendo datos para: Hospital de Mejillones | 409 - Área Médico-Quirúrgico Pediátrica Cuidados Básicos
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Molina | Área aleatoria: 412 - Área Cuidados Intermedios Pediátricos
# ==========================
# 🔍 Extrayendo datos para: Hospital de Molina | 412 - Área Cuidados Intermedios Pediátricos
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Nancagua | Área aleatoria: Área Cuidados Intermedios Adultos
# ==========================
# 🔍 Extrayendo datos para: Hospital de Nancagua | Área Cuidados Intermedios Adultos
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Paillaco | Área aleatoria: Área Médica Adulto Cuidados Medios
# ==========================
# 🔍 Extrayendo datos para: Hospital de Paillaco | Área Médica Adulto Cuidados Medios
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Peñaflor | Área aleatoria: Área Médica Adulto Cuidados Básicos
# ==========================
# 🔍 Extrayendo datos para: Hospital de Peñaflor | Área Médica Adulto Cuidados Básicos
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Pichidegua | Área aleatoria: Área Cuidados Intensivos Pediátricos
# ==========================
# 🔍 Extrayendo datos para: Hospital de Pichidegua | Área Cuidados Intensivos Pediátricos
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Pichilemu | Área aleatoria: 401 - Área Médica Adulto Cuidados Básicos
# ==========================
# 🔍 Extrayendo datos para: Hospital de Pichilemu | 401 - Área Médica Adulto Cuidados Básicos
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Pitrufquén | Área aleatoria: 412 - Área Cuidados Intermedios Pediátricos
# ==========================
# 🔍 Extrayendo datos para: Hospital de Pitrufquén | 412 - Área Cuidados Intermedios Pediátricos
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Puerto Montt | Área aleatoria: 408 - Área Médica Pediátrica Cuidados Medios
# ==========================
# 🔍 Extrayendo datos para: Hospital de Puerto Montt | 408 - Área Médica Pediátrica Cuidados Medios
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Puerto Octay | Área aleatoria: Área Neonatología Cuidados Intensivos
# ==========================
# 🔍 Extrayendo datos para: Hospital de Puerto Octay | Área Neonatología Cuidados Intensivos
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Purén | Área aleatoria: 330 - Área Pensionado
# ==========================
# 🔍 Extrayendo datos para: Hospital de Purén | 330 - Área Pensionado
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 12.61
# ✅ RMSE (camas): 17.44
# 📉 Error promedio porcentual: 14.76%
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Quellón | Área aleatoria: Área Psiquiatría Infanto-adolescente corta estadía
# ==========================
# 🔍 Extrayendo datos para: Hospital de Quellón | Área Psiquiatría Infanto-adolescente corta estadía
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Quilpué | Área aleatoria: Área Cuidados Intensivos Adultos
# ==========================
# 🔍 Extrayendo datos para: Hospital de Quilpué | Área Cuidados Intensivos Adultos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 2.62
# ✅ RMSE (camas): 3.16
# 📉 Error promedio porcentual: 2.18%
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Río Bueno | Área aleatoria: 405 - Área Cuidados Intensivos Adultos
# ==========================
# 🔍 Extrayendo datos para: Hospital de Río Bueno | 405 - Área Cuidados Intensivos Adultos
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Río Negro | Área aleatoria: 410 - Área Médico-Quirúrgico Pediátrica Cuidados Medios
# ==========================
# 🔍 Extrayendo datos para: Hospital de Río Negro | 410 - Área Médico-Quirúrgico Pediátrica Cuidados Medios
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Salamanca | Área aleatoria: 401 - Área Médica Adulto Cuidados Básicos
# ==========================
# 🔍 Extrayendo datos para: Hospital de Salamanca | 401 - Área Médica Adulto Cuidados Básicos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 130.01
# ✅ RMSE (camas): 156.16
# 📉 Error promedio porcentual: 63.68%
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Teno | Área aleatoria: 330 - Área Pensionado
# ==========================
# 🔍 Extrayendo datos para: Hospital de Teno | 330 - Área Pensionado
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Toltén | Área aleatoria: 416 - Área Obstetricia
# ==========================
# 🔍 Extrayendo datos para: Hospital de Toltén | 416 - Área Obstetricia
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 4.02
# ✅ RMSE (camas): 6.15
# 📉 Error promedio porcentual: 9.20%
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Tomé | Área aleatoria: Área Psiquiatría Adulto Mediana estadía
# ==========================
# 🔍 Extrayendo datos para: Hospital de Tomé | Área Psiquiatría Adulto Mediana estadía
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Vilcún | Área aleatoria: Área Psiquiatría Adulto Corta estadía
# ==========================
# 🔍 Extrayendo datos para: Hospital de Vilcún | Área Psiquiatría Adulto Corta estadía
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Hospital de Villarrica | Área aleatoria: Datos Establecimiento
# ==========================
# 🔍 Extrayendo datos para: Hospital de Villarrica | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 202.42
# ✅ RMSE (camas): 339.65
# 📉 Error promedio porcentual: 7.59%
#
# ==========================
# 🏥 Evaluando entrenamiento: Instituto Nacional Geriátrico Presidente Eduardo Frei Montalva | Área aleatoria: Área Psiquiatría Infanto-adolescente corta estadía
# ==========================
# 🔍 Extrayendo datos para: Instituto Nacional Geriátrico Presidente Eduardo Frei Montalva | Área Psiquiatría Infanto-adolescente corta estadía
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Instituto Nacional de Enfermedades Respiratorias y Cirugía Torácica | Área aleatoria: 413 - Área Neonatología Cuidados Básicos
# ==========================
# 🔍 Extrayendo datos para: Instituto Nacional de Enfermedades Respiratorias y Cirugía Torácica | 413 - Área Neonatología Cuidados Básicos
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#
# ==========================
# 🏥 Evaluando entrenamiento: Instituto Nacional de Rehabilitación Infantil Presidente Pedro Aguirre Cerda | Área aleatoria: 330 - Área Pensionado
# ==========================
# 🔍 Extrayendo datos para: Instituto Nacional de Rehabilitación Infantil Presidente Pedro Aguirre Cerda | 330 - Área Pensionado
# ⚠️ No se encontraron datos para ese hospital y área.
# ❌ No se encontraron datos para el hospital o área especificada.
#          Fecha    Real     Predicho  Error Absoluto  Error Porcentual (%)  \
# 0   2015-10-01  3363.0  3324.772949       38.227051              1.136695
# 1   2015-11-01  2830.0  2681.626953      148.373047              5.242864
# 2   2015-12-01  3446.0  3324.772949      121.227051              3.517906
# 3   2020-09-01   678.0   674.895386        3.104614              0.457908
# 4   2020-10-01   711.0   706.427002        4.572998              0.643178
# ..         ...     ...          ...             ...                   ...
# 242 2024-10-01  2954.0  2268.814453      685.185547             23.195178
# 243 2024-11-01  2774.0  2141.202637      632.797363             22.811729
# 244 2024-12-01  3008.0  2267.984619      740.015381             24.601575
# 245 2025-01-01  3012.0  2237.214844      774.785156             25.723279
# 246 2025-02-01  2735.0  2061.339600      673.660400             24.631093
#
#                                               Hospital  \
# 0    Complejo Hospitalario San José (Santiago, Inde...
# 1    Complejo Hospitalario San José (Santiago, Inde...
# 2    Complejo Hospitalario San José (Santiago, Inde...
# 3               Hospital Adalberto Steeger (Talagante)
# 4               Hospital Adalberto Steeger (Talagante)
# ..                                                 ...
# 242                             Hospital de Villarrica
# 243                             Hospital de Villarrica
# 244                             Hospital de Villarrica
# 245                             Hospital de Villarrica
# 246                             Hospital de Villarrica
#
#                                           Área
# 0       Área Médico-Quirúrgico Cuidados Medios
# 1       Área Médico-Quirúrgico Cuidados Medios
# 2       Área Médico-Quirúrgico Cuidados Medios
# 3    401 - Área Médica Adulto Cuidados Básicos
# 4    401 - Área Médica Adulto Cuidados Básicos
# ..                                         ...
# 242                      Datos Establecimiento
# 243                      Datos Establecimiento
# 244                      Datos Establecimiento
# 245                      Datos Establecimiento
# 246                      Datos Establecimiento
#
# [247 rows x 7 columns]

# %%
# Unir todos los resultados
df_entrenamiento_resultados = pd.concat(resultados_entrenamiento_todos, ignore_index=True)
dataframe=df_entrenamiento_resultados

dataframe_ordenado = dataframe.sort_values(by="Error Porcentual (%)", ascending=False)


dataframe_ordenado.head(50)
# Out:
#          Fecha    Real     Predicho  Error Absoluto  Error Porcentual (%)  \
# 201 2025-02-01   172.0   383.393219      211.393219            122.903034
# 193 2024-06-01   186.0   398.997833      212.997833            114.514964
# 199 2024-12-01   191.0   398.109680      207.109680            108.434388
# 200 2025-01-01   195.0   399.901489      204.901489            105.077687
# 198 2024-11-01   192.0   391.026093      199.026093            103.659423
# 192 2024-05-01   193.0   391.120880      198.120880            102.653306
# 189 2024-02-01   203.0   392.245361      189.245361             93.224316
# 191 2024-04-01   207.0   389.709839      182.709839             88.265623
# 188 2024-01-01   208.0   391.263000      183.263000             88.107212
# 190 2024-03-01   219.0   402.801697      183.801697             83.927715
# 197 2024-10-01   214.0   391.064453      177.064453             82.740399
# 196 2024-09-01   236.0   390.570099      154.570099             65.495805
# 195 2024-08-01   254.0   398.716888      144.716888             56.975153
# 194 2024-07-01   259.0   404.400055      145.400055             56.139017
# 219 2024-12-01    36.0    53.841480       17.841480             49.559667
# 218 2024-11-01    39.0    52.737675       13.737675             35.224807
# 176 2017-10-01    87.0    58.163559       28.836441             33.145335
# 14  2021-08-01   379.0   479.936432      100.936432             26.632304
# 245 2025-01-01  3012.0  2237.214844      774.785156             25.723279
# 246 2025-02-01  2735.0  2061.339600      673.660400             24.631093
# 244 2024-12-01  3008.0  2267.984619      740.015381             24.601575
# 242 2024-10-01  2954.0  2268.814453      685.185547             23.195178
# 243 2024-11-01  2774.0  2141.202637      632.797363             22.811729
# 99  2024-08-01   372.0   287.951935       84.048065             22.593566
# 101 2024-10-01   372.0   289.145416       82.854584             22.272738
# 103 2024-12-01   372.0   290.841309       81.158691             21.816853
# 104 2025-01-01   372.0   290.921478       81.078522             21.795302
# 98  2024-07-01   372.0   290.937592       81.062408             21.790970
# 105 2025-02-01   372.0   291.610321       80.389679             21.610129
# 53  2015-12-01    43.0    52.202171        9.202171             21.400398
# 100 2024-09-01   360.0   288.637360       71.362640             19.822956
# 102 2024-11-01   360.0   290.333252       69.666748             19.351874
# 217 2024-10-01    43.0    51.091644        8.091644             18.817777
# 97  2024-06-01   360.0   294.737946       65.262054             18.128348
# 166 2025-01-01  1054.0   879.801697      174.198303             16.527353
# 237 2024-05-01  2635.0  2217.638428      417.361572             15.839149
# 241 2024-09-01  2673.0  2267.890869      405.109131             15.155598
# 151 2023-10-01  1023.0   879.754395      143.245605             14.002503
# 154 2024-01-01  1023.0   879.801697      143.198303             13.997879
# 165 2024-12-01  1023.0   881.378418      141.621582             13.843752
# 163 2024-10-01  1023.0   881.378418      141.621582             13.843752
# 153 2023-12-01  1023.0   881.378418      141.621582             13.843752
# 161 2024-08-01  1023.0   881.378418      141.621582             13.843752
# 160 2024-07-01  1023.0   881.378418      141.621582             13.843752
# 158 2024-05-01  1023.0   881.378418      141.621582             13.843752
# 156 2024-03-01  1023.0   881.378418      141.621582             13.843752
# 157 2024-04-01  1020.0   881.378418      138.621582             13.590351
# 221 2025-02-01    47.0    53.384716        6.384716             13.584502
# 214 2024-07-01    49.0    55.452785        6.452785             13.168950
# 213 2024-06-01    46.0    52.053726        6.053726             13.160274
#
#                                        Hospital  \
# 201                       Hospital de Salamanca
# 193                       Hospital de Salamanca
# 199                       Hospital de Salamanca
# 200                       Hospital de Salamanca
# 198                       Hospital de Salamanca
# 192                       Hospital de Salamanca
# 189                       Hospital de Salamanca
# 191                       Hospital de Salamanca
# 188                       Hospital de Salamanca
# 190                       Hospital de Salamanca
# 197                       Hospital de Salamanca
# 196                       Hospital de Salamanca
# 195                       Hospital de Salamanca
# 194                       Hospital de Salamanca
# 219                          Hospital de Toltén
# 218                          Hospital de Toltén
# 176                           Hospital de Purén
# 14       Hospital Adalberto Steeger (Talagante)
# 245                      Hospital de Villarrica
# 246                      Hospital de Villarrica
# 244                      Hospital de Villarrica
# 242                      Hospital de Villarrica
# 243                      Hospital de Villarrica
# 99        Hospital San Juan de Dios (Los Andes)
# 101       Hospital San Juan de Dios (Los Andes)
# 103       Hospital San Juan de Dios (Los Andes)
# 104       Hospital San Juan de Dios (Los Andes)
# 98        Hospital San Juan de Dios (Los Andes)
# 105       Hospital San Juan de Dios (Los Andes)
# 53   Hospital Padre Alberto Hurtado (San Ramón)
# 100       Hospital San Juan de Dios (Los Andes)
# 102       Hospital San Juan de Dios (Los Andes)
# 217                          Hospital de Toltén
# 97        Hospital San Juan de Dios (Los Andes)
# 166                      Hospital de Collipulli
# 237                      Hospital de Villarrica
# 241                      Hospital de Villarrica
# 151                      Hospital de Collipulli
# 154                      Hospital de Collipulli
# 165                      Hospital de Collipulli
# 163                      Hospital de Collipulli
# 153                      Hospital de Collipulli
# 161                      Hospital de Collipulli
# 160                      Hospital de Collipulli
# 158                      Hospital de Collipulli
# 156                      Hospital de Collipulli
# 157                      Hospital de Collipulli
# 221                          Hospital de Toltén
# 214                          Hospital de Toltén
# 213                          Hospital de Toltén
#
#                                           Área
# 201  401 - Área Médica Adulto Cuidados Básicos
# 193  401 - Área Médica Adulto Cuidados Básicos
# 199  401 - Área Médica Adulto Cuidados Básicos
# 200  401 - Área Médica Adulto Cuidados Básicos
# 198  401 - Área Médica Adulto Cuidados Básicos
# 192  401 - Área Médica Adulto Cuidados Básicos
# 189  401 - Área Médica Adulto Cuidados Básicos
# 191  401 - Área Médica Adulto Cuidados Básicos
# 188  401 - Área Médica Adulto Cuidados Básicos
# 190  401 - Área Médica Adulto Cuidados Básicos
# 197  401 - Área Médica Adulto Cuidados Básicos
# 196  401 - Área Médica Adulto Cuidados Básicos
# 195  401 - Área Médica Adulto Cuidados Básicos
# 194  401 - Área Médica Adulto Cuidados Básicos
# 219                     416 - Área Obstetricia
# 218                     416 - Área Obstetricia
# 176                      330 - Área Pensionado
# 14   401 - Área Médica Adulto Cuidados Básicos
# 245                      Datos Establecimiento
# 246                      Datos Establecimiento
# 244                      Datos Establecimiento
# 242                      Datos Establecimiento
# 243                      Datos Establecimiento
# 99     406 - Área Cuidados Intermedios Adultos
# 101    406 - Área Cuidados Intermedios Adultos
# 103    406 - Área Cuidados Intermedios Adultos
# 104    406 - Área Cuidados Intermedios Adultos
# 98     406 - Área Cuidados Intermedios Adultos
# 105    406 - Área Cuidados Intermedios Adultos
# 53       Área Neonatología Cuidados Intensivos
# 100    406 - Área Cuidados Intermedios Adultos
# 102    406 - Área Cuidados Intermedios Adultos
# 217                     416 - Área Obstetricia
# 97     406 - Área Cuidados Intermedios Adultos
# 166                      Datos Establecimiento
# 237                      Datos Establecimiento
# 241                      Datos Establecimiento
# 151                      Datos Establecimiento
# 154                      Datos Establecimiento
# 165                      Datos Establecimiento
# 163                      Datos Establecimiento
# 153                      Datos Establecimiento
# 161                      Datos Establecimiento
# 160                      Datos Establecimiento
# 158                      Datos Establecimiento
# 156                      Datos Establecimiento
# 157                      Datos Establecimiento
# 221                     416 - Área Obstetricia
# 214                     416 - Área Obstetricia
# 213                     416 - Área Obstetricia

# %%
promedio = dataframe["Error Porcentual (%)"].mean()

print("El promedio de la columna es:", promedio)
# Out:
# El promedio de la columna es: 9.998263622142609
