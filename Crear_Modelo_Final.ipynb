# %%
import pandas as pd
from datetime import datetime

# %%
"""
Mes -> 	Fecha del mes en formato YYYY-MM-DD. Representa el mes al que corresponden los datos climáticos.
temperature_2m_max	-> Temperatura máxima promedio del mes medida a 2 metros de altura, en grados Celsius (°C).
temperature_2m_min -> Temperatura mínima promedio del mes, también a 2 metros de altura, en grados Celsius (°C).
precipitation_sum -> Precipitación total del mes en milímetros (mm). Suma de toda el agua caída durante ese mes.
winddirection_10m_dominant -> Dirección dominante del viento a 10 metros de altura, en grados. Se mide en sentido azimutal desde el norte. (Ej.: 0° = norte, 90° = este, etc.).
SEREMI -> Nombre de la región sanitaria (SEREMI) a la que corresponde esta fila.
"""
# Out:
# '\nMes -> \tFecha del mes en formato YYYY-MM-DD. Representa el mes al que corresponden los datos climáticos.\ntemperature_2m_max\t-> Temperatura máxima promedio del mes medida a 2 metros de altura, en grados Celsius (°C).\ntemperature_2m_min -> Temperatura mínima promedio del mes, también a 2 metros de altura, en grados Celsius (°C).\nprecipitation_sum -> Precipitación total del mes en milímetros (mm). Suma de toda el agua caída durante ese mes.\nwinddirection_10m_dominant -> Dirección dominante del viento a 10 metros de altura, en grados. Se mide en sentido azimutal desde el norte. (Ej.: 0° = norte, 90° = este, etc.).\nSEREMI -> Nombre de la región sanitaria (SEREMI) a la que corresponde esta fila.\n'

# %% [markdown]
# ### Creación de DataSet's de clima mensual por año y SEREMI:

# %%
# 1. Cargar todos los archivos seremi
seremi_data = {
    "2014": pd.read_csv("seremi_2014.csv"),
    "2015": pd.read_csv("seremi_2015.csv"),
    "2016": pd.read_csv("seremi_2016.csv"),
    "2017": pd.read_csv("seremi_2017.csv"),
    "2018": pd.read_csv("seremi_2018.csv"),
    "2019": pd.read_csv("seremi_2019.csv"),
    "2020": pd.read_csv("seremi_2020.csv"),
    "2021": pd.read_csv("seremi_2021.csv"),
    "2022": pd.read_csv("seremi_2022.csv"),
    "2023": pd.read_csv("seremi_2023.csv"),
    "2024": pd.read_csv("seremi_2024.csv"),
    "2025": pd.read_csv("seremi_2025.csv"),
}

# 2. Función para procesar cada dataset climático
def procesar_datasets_climaticos(seremi_data_dict):
    def grados_a_cardinal(grados):
        if pd.isna(grados):
            return None
        direcciones = ['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW']
        index = int((grados + 22.5) % 360 // 45)
        return direcciones[index]

    for año, df in seremi_data_dict.items():
        # Eliminar columna innecesaria
        if "Unnamed: 0" in df.columns:
            df = df.drop(columns=["Unnamed: 0"])

        # Crear columna cardinal
        if "winddirection_10m_dominant" in df.columns:
            df["wind_direction_cardinal"] = df["winddirection_10m_dominant"].apply(grados_a_cardinal)

        # Renombrar columnas
        df = df.rename(columns={
            "temperature_2m_max": "Temperatura Máxima",
            "temperature_2m_min": "Temperatura Mínima",
            "precipitation_sum": "Precipitaciones (suma)",
            "winddirection_10m_dominant": "Dirección Viento"
        })

        # Limpiar columna de grados si existe y renombrar cardinal
        if "Dirección Viento" in df.columns:
            df = df.drop(columns=["Dirección Viento"])
        if "wind_direction_cardinal" in df.columns:
            df = df.rename(columns={"wind_direction_cardinal": "Dirección del Viento"})

        # Guardar el dataframe procesado
        seremi_data_dict[año] = df

    return seremi_data_dict

# 3. Aplicar la función a todos los datasets climáticos
seremi_data = procesar_datasets_climaticos(seremi_data)

# 4. Verificar que todo esté correcto (opcional)
seremi_data["2015"].head(12)
# Out:
#            Mes  Temperatura Máxima  Temperatura Mínima  \
# 0   2015-01-01           12.277419            6.867742
# 1   2015-02-01           12.142857            7.100000
# 2   2015-03-01           11.561290            6.393548
# 3   2015-04-01            9.093333            4.446667
# 4   2015-05-01            5.935484            2.541935
# 5   2015-06-01            3.943333            1.150000
# 6   2015-07-01            3.032258           -0.138710
# 7   2015-08-01            4.180645            0.509677
# 8   2015-09-01            5.266667            1.120000
# 9   2015-10-01            8.925806            2.803226
# 10  2015-11-01            9.626667            4.630000
# 11  2015-12-01           11.200000            5.090323
#
#     Precipitaciones (suma)      SEREMI Dirección del Viento
# 0                     33.7  Magallanes                    W
# 1                     36.9  Magallanes                    W
# 2                     92.1  Magallanes                    W
# 3                     57.9  Magallanes                    W
# 4                    100.0  Magallanes                    S
# 5                     92.8  Magallanes                   SW
# 6                     98.4  Magallanes                   SW
# 7                     59.8  Magallanes                   SW
# 8                     46.0  Magallanes                   SW
# 9                     24.2  Magallanes                   SW
# 10                    44.3  Magallanes                    W
# 11                    26.0  Magallanes                    W

# %% [markdown]
# ### Creación de DataSet's sobre ocupación de camas por mes y por año según hospital y área:

# %%
# Archivos filtrados hospitalarios
archivos_filtrados = {
    "2014": "2014_filtrado.csv",
    "2015": "2015_filtrado.csv",
    "2016": "2016_filtrado.csv",
    "2017": "2017_filtrado.csv",
    "2018": "2018_filtrado.csv",
    "2019": "2019_filtrado.csv",
    "2020": "2020_filtrado.csv",
    "2021": "2021_filtrado.csv",
    "2022": "2022_filtrado.csv",
    "2023": "2023_filtrado.csv",
    "2024": "2024_filtrado.csv",
    "2025": "2025_filtrado.csv"
}

# Diccionario para guardar los dataframes ya limpios
filtrado_limpio = {}

# Abreviaturas de los meses
meses_abreviados = ['Ene', 'Feb', 'Mar', 'Abr', 'May', 'Jun',
                    'Jul', 'Ago', 'Sep', 'Oct', 'Nov', 'Dic']

# Columnas que se eliminarán si existen
columnas_a_eliminar = ["Cód. SS/SEREMI", "Cód. Estab.", "Cód. Nivel Cuidado", "Acum", "Año"]

# Procesamiento de los archivos
for año, archivo in archivos_filtrados.items():
    # Cargar CSV
    df = pd.read_csv(archivo)

    # Eliminar filas irrelevantes
    df = df[~df["Nombre Establecimiento"].isin(["Datos País", "Datos Servicio Salud"])].copy()

    # Eliminar columnas innecesarias
    df = df.drop(columns=columnas_a_eliminar, errors='ignore')

    # Renombrar columnas clave
    df = df.rename(columns={
        "Nombre SS/SEREMI": "SEREMI",
        "Nombre Nivel Cuidado": "Area"
    })

    # Renombrar columnas de meses abreviados por fecha
    nuevo_nombre_columnas = {}
    año_int = int(año)

    for i, mes_abrev in enumerate(meses_abreviados, start=1):
        if mes_abrev in df.columns:
            fecha = datetime(año_int, i, 1).strftime('%Y-%m-%d')
            nuevo_nombre_columnas[mes_abrev] = fecha

    df = df.rename(columns=nuevo_nombre_columnas)

    # Guardar DataFrame limpio
    filtrado_limpio[año] = df

# Ejemplo: verificar que todo cargó bien
filtrado_limpio["2020"].head()
# Out:
#          SEREMI  Nombre Establecimiento                   Area  \
# 24  Antofagasta  Hospital de Mejillones  Datos Establecimiento
# 25  Antofagasta  Hospital de Mejillones  Datos Establecimiento
# 26  Antofagasta  Hospital de Mejillones  Datos Establecimiento
# 27  Antofagasta  Hospital de Mejillones  Datos Establecimiento
# 28  Antofagasta  Hospital de Mejillones  Datos Establecimiento
#
#                         Glosa  2020-01-01  2020-02-01  2020-03-01  2020-04-01  \
# 24      Dias Cama Disponibles       279.0       261.0       279.0       270.0
# 25         Dias Cama Ocupados        79.0        65.0        43.0       256.0
# 26             Dias de Estada        79.0        65.0        43.0       256.0
# 27  Promedio Cama Disponibles         9.0         9.0         9.0         9.0
# 28          Numero de Egresos        13.0        21.0        13.0        14.0
#
#     2020-05-01  2020-06-01  2020-07-01  2020-08-01  2020-09-01  2020-10-01  \
# 24       279.0       270.0       279.0       279.0       270.0      270.00
# 25         8.0        35.0        45.0        72.0       130.0       74.00
# 26         8.0        35.0        45.0        72.0       130.0       74.00
# 27         9.0         9.0         9.0         9.0         9.0        8.71
# 28         4.0        12.0         6.0        10.0        11.0       13.00
#
#     2020-11-01  2020-12-01
# 24       270.0       279.0
# 25        36.0        48.0
# 26        36.0        48.0
# 27         9.0         9.0
# 28        11.0        13.0

# %% [markdown]
# ### Unión de datos:

# %%
#
def extraer_info_hospital_area_todo_el_año(hospital_nombre, area_nombre):
    registros = []

    for año, df in filtrado_limpio.items():
        df_seremi = seremi_data[año].copy()

        # Aseguramos que 'Mes' esté en formato datetime
        df_seremi['Mes'] = pd.to_datetime(df_seremi['Mes'], errors='coerce')
        df_seremi.dropna(subset=['Mes'], inplace=True)
        df_seremi['Mes'] = df_seremi['Mes'].dt.to_period("M").dt.to_timestamp()

        columnas_mes = [col for col in df.columns if col.startswith("20")]
        for col in columnas_mes:
            # Filtro hospitalario por hospital, área y mes
            df_tmp = df[
                (df["Nombre Establecimiento"] == hospital_nombre) &
                (df["Area"] == area_nombre)
            ][["SEREMI", "Nombre Establecimiento", "Area", "Glosa", col]].copy()

            if df_tmp.empty:
                continue

            df_tmp = df_tmp.rename(columns={col: "Valor"})
            df_tmp["Fecha"] = pd.to_datetime(col)

            # Filtro climático por seremi y mes
            clima_mes = df_seremi[df_seremi["Mes"] == df_tmp["Fecha"].iloc[0]].copy()
            df_merge = df_tmp.merge(clima_mes, on=["SEREMI"], how="left")

            registros.append(df_merge)

    if registros:
        return pd.concat(registros, ignore_index=True).sort_values("Fecha")
    else:
        print("⚠️ No se encontraron datos para ese hospital y área.")
        return pd.DataFrame()

# Ejemplo de prueba
ejemplo_df = extraer_info_hospital_area_todo_el_año(
    "Hospital Barros Luco Trudeau (Santiago, San Miguel)",
    "401 - Área Médica Adulto Cuidados Básicos"
)

dataframe=ejemplo_df

dataframe.head()
# Out:
#               SEREMI                             Nombre Establecimiento  \
# 0  Metropolitano Sur  Hospital Barros Luco Trudeau (Santiago, San Mi...
# 1  Metropolitano Sur  Hospital Barros Luco Trudeau (Santiago, San Mi...
# 2  Metropolitano Sur  Hospital Barros Luco Trudeau (Santiago, San Mi...
# 3  Metropolitano Sur  Hospital Barros Luco Trudeau (Santiago, San Mi...
# 4  Metropolitano Sur  Hospital Barros Luco Trudeau (Santiago, San Mi...
#
#                                         Area                      Glosa  \
# 0  401 - Área Médica Adulto Cuidados Básicos      Dias Cama Disponibles
# 1  401 - Área Médica Adulto Cuidados Básicos         Dias Cama Ocupados
# 2  401 - Área Médica Adulto Cuidados Básicos             Dias de Estada
# 3  401 - Área Médica Adulto Cuidados Básicos  Promedio Cama Disponibles
# 4  401 - Área Médica Adulto Cuidados Básicos          Numero de Egresos
#
#     Valor      Fecha        Mes  Temperatura Máxima  Temperatura Mínima  \
# 0  3469.0 2016-01-01 2016-01-01           28.664516                16.0
# 1  3135.0 2016-01-01 2016-01-01           28.664516                16.0
# 2  2879.0 2016-01-01 2016-01-01           28.664516                16.0
# 3   111.9 2016-01-01 2016-01-01           28.664516                16.0
# 4   332.0 2016-01-01 2016-01-01           28.664516                16.0
#
#    Precipitaciones (suma) Dirección del Viento
# 0                    11.2                   SW
# 1                    11.2                   SW
# 2                    11.2                   SW
# 3                    11.2                   SW
# 4                    11.2                   SW

# %%
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV, train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
def preparar_dataset_climatico(df):
    df_pivot = df.pivot(index='Fecha', columns='Glosa', values='Valor').reset_index()

    columnas_necesarias = ['Dias Cama Disponibles', 'Dias Cama Ocupados',
                           'Promedio Cama Disponibles', 'Numero de Egresos']
    if not all(col in df_pivot.columns for col in columnas_necesarias):
        print("❌ Datos insuficientes para generar el modelo.")
        return None

    clima = df.drop_duplicates(subset='Fecha')[[
        'Fecha', 'Temperatura Máxima', 'Temperatura Mínima',
        'Precipitaciones (suma)', 'Dirección del Viento'
    ]]

    df_pivot = pd.merge(df_pivot, clima, on='Fecha', how='left')
    df_pivot = pd.get_dummies(df_pivot, columns=['Dirección del Viento'], prefix='Viento')

    df_pivot = df_pivot.sort_values('Fecha')
    df_pivot['Mes'] = df_pivot['Fecha'].dt.month
    df_pivot['Trimestre'] = df_pivot['Fecha'].dt.quarter
    df_pivot['lag_1'] = df_pivot['Dias Cama Disponibles'].shift(1)
    df_pivot['lag_2'] = df_pivot['Dias Cama Disponibles'].shift(2)
    df_pivot['porcentaje_ocupacion'] = df_pivot['Dias Cama Ocupados'] / df_pivot['Dias Cama Disponibles']
    df_pivot['variacion_disponibles'] = df_pivot['Dias Cama Disponibles'].diff()
    df_pivot['ocupados_media_movil'] = df_pivot['Dias Cama Ocupados'].rolling(window=3).mean()
    df_pivot['promedio_media_movil'] = df_pivot['Promedio Cama Disponibles'].rolling(window=3).mean()
    df_pivot['egresos_media_movil'] = df_pivot['Numero de Egresos'].rolling(window=3).mean()

    return df_pivot.dropna().copy()

# %%
# Pipeline final robusto con clima + hospital + evaluación completa y errores porcentuales

def pipeline_final_mae_reducido(hospital, area):
    print(f"🔍 Extrayendo datos para: {hospital} | {area}")
    df_base = extraer_info_hospital_area_todo_el_año(hospital, area)

    if df_base.empty:
        print("❌ No se encontraron datos para el hospital o área especificada.")
        return None

    print("🧪 Preparando dataset con variables hospitalarias y climáticas...")
    df_modelo = preparar_dataset_climatico(df_base)

    if df_modelo is None or df_modelo.empty:
        print("❌ No se pudo preparar el dataset.")
        return None

    # Definir features dinámicamente
    features = [
        'Dias Cama Ocupados',
        'Promedio Cama Disponibles',
        'Numero de Egresos',
        'Mes', 'Trimestre',
        'lag_1', 'lag_2',
        'porcentaje_ocupacion',
        'variacion_disponibles',
        'ocupados_media_movil',
        'promedio_media_movil',
        'egresos_media_movil',
        'Temperatura Máxima',
        'Temperatura Mínima',
        'Precipitaciones (suma)'
    ] + [col for col in df_modelo.columns if col.startswith('Viento_')]

    # Separar entrenamiento y prueba (último 20% como evaluación)
    X = df_modelo[features]
    y = df_modelo['Dias Cama Disponibles']
    X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=False, test_size=0.2)

    print("🔧 Ajustando modelo con GridSearchCV...")
    param_grid = {
        'n_estimators': [50, 100],
        'max_depth': [2, 3],
        'learning_rate': [0.05, 0.1]
    }

    model = XGBRegressor(n_jobs=1, random_state=42)
    grid_search = GridSearchCV(
        estimator=model,
        param_grid=param_grid,
        scoring='neg_mean_absolute_error',
        cv=TimeSeriesSplit(n_splits=3),
        verbose=1
    )
    grid_search.fit(X_train, y_train)
    mejor_modelo = grid_search.best_estimator_
    print("📌 Mejores parámetros encontrados:", grid_search.best_params_)

    print("📊 Evaluando sobre el 20% final de los datos...")

    y_pred = mejor_modelo.predict(X_test)
    mae = mean_absolute_error(y_test, y_pred)
    rmse = mean_squared_error(y_test, y_pred) ** 0.5
    error_pct = np.mean(np.abs((y_test.values - y_pred) / y_test.values)) * 100

    resultados = pd.DataFrame({
        'Fecha': df_modelo['Fecha'].iloc[-len(y_test):].values,
        'Real': y_test.values,
        'Predicho': y_pred,
        'Error Absoluto': np.abs(y_test.values - y_pred),
        'Error Porcentual (%)': np.abs((y_test.values - y_pred) / y_test.values) * 100
    })

    print(f"✅ MAE (camas): {mae:.2f}")
    print(f"✅ RMSE (camas): {rmse:.2f}")
    print(f"📉 Error promedio porcentual: {error_pct:.2f}%")

    return resultados

# %%
resultados_final = pipeline_final_mae_reducido(
    "Hospital Barros Luco Trudeau (Santiago, San Miguel)",
    "401 - Área Médica Adulto Cuidados Básicos"
)

display(resultados_final)
# Out:
# 🔍 Extrayendo datos para: Hospital Barros Luco Trudeau (Santiago, San Miguel) | 401 - Área Médica Adulto Cuidados Básicos
# 🧪 Preparando dataset con variables hospitalarias y climáticas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 66.96
# ✅ RMSE (camas): 87.72
# 📉 Error promedio porcentual: 3.04%
#         Fecha    Real     Predicho  Error Absoluto  Error Porcentual (%)
# 0  2023-05-01  2329.0  2254.683350       74.316650              3.190925
# 1  2023-06-01  2250.0  2236.470215       13.529785              0.601324
# 2  2023-07-01  2325.0  2259.773926       65.226074              2.805423
# 3  2023-08-01  2325.0  2269.901367       55.098633              2.369834
# 4  2023-09-01  2252.0  2256.211670        4.211670              0.187019
# 5  2023-10-01  2334.0  2273.539795       60.460205              2.590412
# 6  2023-11-01  2252.0  2250.232910        1.767090              0.078468
# 7  2023-12-01  2144.0  2104.215576       39.784424              1.855617
# 8  2024-01-01  2146.0  2111.233154       34.766846              1.620077
# 9  2024-02-01  2035.0  2155.288574      120.288574              5.910986
# 10 2024-03-01  2458.0  2269.182861      188.817139              7.681739
# 11 2024-04-01  2400.0  2249.398682      150.601318              6.275055
# 12 2024-05-01  2465.0  2262.073486      202.926514              8.232313
# 13 2024-06-01  1739.0  1886.918213      147.918213              8.505935
# 14 2024-07-01  2173.0  2128.998291       44.001709              2.024929
# 15 2024-08-01  2196.0  2179.371094       16.628906              0.757236
# 16 2024-09-01  2117.0  2164.982422       47.982422              2.266529
# 17 2024-10-01  2131.0  2113.190918       17.809082              0.835715
# 18 2024-11-01  2044.0  2101.441162       57.441162              2.810233
# 19 2024-12-01  2245.0  2206.920898       38.079102              1.696174
# 20 2025-01-01  2152.0  2115.870850       36.129150              1.678864
# 21 2025-02-01  1912.0  1967.303955       55.303955              2.892466

# %%
##############################
##############################
##DESDE AQUI, NUEVAS PRUEBAS##
##############################
##############################

# %%
# Ampliamos la función `preparar_dataset_climatico` con nuevas features derivados:
# - tasas
# - cruces entre clima y variables hospitalarias
# - más variaciones

def preparar_dataset_climatico(df):
    df_pivot = df.pivot(index='Fecha', columns='Glosa', values='Valor').reset_index()

    columnas_necesarias = ['Dias Cama Disponibles', 'Dias Cama Ocupados',
                           'Promedio Cama Disponibles', 'Numero de Egresos']
    if not all(col in df_pivot.columns for col in columnas_necesarias):
        print("❌ Datos insuficientes para generar el modelo.")
        return None

    # Añadir clima
    clima = df.drop_duplicates(subset='Fecha')[[
        'Fecha', 'Temperatura Máxima', 'Temperatura Mínima',
        'Precipitaciones (suma)', 'Dirección del Viento'
    ]]

    df_pivot = pd.merge(df_pivot, clima, on='Fecha', how='left')
    df_pivot = pd.get_dummies(df_pivot, columns=['Dirección del Viento'], prefix='Viento')

    # Ordenar temporalmente
    df_pivot = df_pivot.sort_values('Fecha')

    # Variables temporales básicas
    df_pivot['Mes'] = df_pivot['Fecha'].dt.month
    df_pivot['Trimestre'] = df_pivot['Fecha'].dt.quarter
    df_pivot['lag_1'] = df_pivot['Dias Cama Disponibles'].shift(1)
    df_pivot['lag_2'] = df_pivot['Dias Cama Disponibles'].shift(2)
    df_pivot['porcentaje_ocupacion'] = df_pivot['Dias Cama Ocupados'] / df_pivot['Dias Cama Disponibles']
    df_pivot['variacion_disponibles'] = df_pivot['Dias Cama Disponibles'].diff()
    df_pivot['ocupados_media_movil'] = df_pivot['Dias Cama Ocupados'].rolling(window=3).mean()
    df_pivot['promedio_media_movil'] = df_pivot['Promedio Cama Disponibles'].rolling(window=3).mean()
    df_pivot['egresos_media_movil'] = df_pivot['Numero de Egresos'].rolling(window=3).mean()

    # 🔧 Nuevas features derivadas:
    df_pivot['tasa_egresos'] = df_pivot['Numero de Egresos'] / df_pivot['Dias Cama Ocupados']
    df_pivot['tasa_ocupacion_promedio'] = df_pivot['Dias Cama Ocupados'] / df_pivot['Promedio Cama Disponibles']
    df_pivot['variacion_ocupados'] = df_pivot['Dias Cama Ocupados'].diff()
    df_pivot['variacion_egresos'] = df_pivot['Numero de Egresos'].diff()

    # 🔁 Cruces con clima
    df_pivot['ocupados_x_temp'] = df_pivot['Dias Cama Ocupados'] * df_pivot['Temperatura Máxima']
    df_pivot['egresos_x_precipitacion'] = df_pivot['Numero de Egresos'] * df_pivot['Precipitaciones (suma)']
    df_pivot['ocupacion_pct_x_tempmin'] = df_pivot['porcentaje_ocupacion'] * df_pivot['Temperatura Mínima']

    return df_pivot.dropna().copy()

# %%
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV, train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
from xgboost import XGBRegressor
import numpy as np

def pipeline_final_mae_reducido(hospital, area):
    print(f"🔍 Extrayendo datos para: {hospital} | {area}")
    df_base = extraer_info_hospital_area_todo_el_año(hospital, area)

    if df_base.empty:
        print("❌ No se encontraron datos para el hospital o área especificada.")
        return None

    print("🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...")
    df_modelo = preparar_dataset_climatico(df_base)

    if df_modelo is None or df_modelo.empty:
        print("❌ No se pudo preparar el dataset.")
        return None

    # Features dinámicos
    features = [
        'Dias Cama Ocupados',
        'Promedio Cama Disponibles',
        'Numero de Egresos',
        'Mes', 'Trimestre',
        'lag_1', 'lag_2',
        'porcentaje_ocupacion',
        'variacion_disponibles',
        'ocupados_media_movil',
        'promedio_media_movil',
        'egresos_media_movil',
        'tasa_egresos',
        'tasa_ocupacion_promedio',
        'variacion_ocupados',
        'variacion_egresos',
        'ocupados_x_temp',
        'egresos_x_precipitacion',
        'ocupacion_pct_x_tempmin',
        'Temperatura Máxima',
        'Temperatura Mínima',
        'Precipitaciones (suma)'
    ] + [col for col in df_modelo.columns if col.startswith('Viento_')]

    # Separar entrenamiento y test (último 20% como test)
    X = df_modelo[features]
    y = df_modelo['Dias Cama Disponibles']
    X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=False, test_size=0.2)

    print("🔧 Ajustando modelo con GridSearchCV...")
    param_grid = {
        'n_estimators': [50, 100],
        'max_depth': [2, 3],
        'learning_rate': [0.05, 0.1]
    }

    model = XGBRegressor(n_jobs=1, random_state=42)
    grid_search = GridSearchCV(
        estimator=model,
        param_grid=param_grid,
        scoring='neg_mean_absolute_error',
        cv=TimeSeriesSplit(n_splits=3),
        verbose=1
    )
    grid_search.fit(X_train, y_train)
    mejor_modelo = grid_search.best_estimator_

    print("📌 Mejores parámetros encontrados:", grid_search.best_params_)

    print("📊 Evaluando sobre el 20% final de los datos...")

    y_pred = mejor_modelo.predict(X_test)
    mae = mean_absolute_error(y_test, y_pred)
    rmse = mean_squared_error(y_test, y_pred) ** 0.5
    error_pct = np.mean(np.abs((y_test.values - y_pred) / y_test.values)) * 100

    resultados = pd.DataFrame({
        'Fecha': df_modelo['Fecha'].iloc[-len(y_test):].values,
        'Real': y_test.values,
        'Predicho': y_pred,
        'Error Absoluto': np.abs(y_test.values - y_pred),
        'Error Porcentual (%)': np.abs((y_test.values - y_pred) / y_test.values) * 100
    })

    print(f"✅ MAE (camas): {mae:.2f}")
    print(f"✅ RMSE (camas): {rmse:.2f}")
    print(f"📉 Error promedio porcentual: {error_pct:.2f}%")

    return resultados

# %%
hospital = "Hospital Barros Luco Trudeau (Santiago, San Miguel)"
area = "401 - Área Médica Adulto Cuidados Básicos"

resultados_mejorado = pipeline_final_mae_reducido(hospital, area)

if resultados_mejorado is not None:
    display(resultados_mejorado)
# Out:
# 🔍 Extrayendo datos para: Hospital Barros Luco Trudeau (Santiago, San Miguel) | 401 - Área Médica Adulto Cuidados Básicos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 67.76
# ✅ RMSE (camas): 88.44
# 📉 Error promedio porcentual: 3.06%
#         Fecha    Real     Predicho  Error Absoluto  Error Porcentual (%)
# 0  2023-05-01  2329.0  2265.841309       63.158691              2.711837
# 1  2023-06-01  2250.0  2222.516602       27.483398              1.221484
# 2  2023-07-01  2325.0  2253.972656       71.027344              3.054940
# 3  2023-08-01  2325.0  2261.367676       63.632324              2.736874
# 4  2023-09-01  2252.0  2246.199951        5.800049              0.257551
# 5  2023-10-01  2334.0  2260.542480       73.457520              3.147280
# 6  2023-11-01  2252.0  2241.694092       10.305908              0.457634
# 7  2023-12-01  2144.0  2106.540771       37.459229              1.747166
# 8  2024-01-01  2146.0  2122.444336       23.555664              1.097654
# 9  2024-02-01  2035.0  2146.662354      111.662354              5.487094
# 10 2024-03-01  2458.0  2261.966309      196.033691              7.975333
# 11 2024-04-01  2400.0  2235.706787      164.293213              6.845551
# 12 2024-05-01  2465.0  2261.795898      203.204102              8.243574
# 13 2024-06-01  1739.0  1874.112183      135.112183              7.769533
# 14 2024-07-01  2173.0  2130.724854       42.275146              1.945474
# 15 2024-08-01  2196.0  2178.020508       17.979492              0.818738
# 16 2024-09-01  2117.0  2171.161377       54.161377              2.558402
# 17 2024-10-01  2131.0  2111.153320       19.846680              0.931332
# 18 2024-11-01  2044.0  2103.759766       59.759766              2.923668
# 19 2024-12-01  2245.0  2220.129639       24.870361              1.107811
# 20 2025-01-01  2152.0  2110.583496       41.416504              1.924559
# 21 2025-02-01  1912.0  1956.241089       44.241089              2.313864

# %%
# Lista de hospitales y área para evaluar con el mismo pipeline robusto
hospitales_a_evaluar = [
    ("Hospital Barros Luco Trudeau (Santiago, San Miguel)", "401 - Área Médica Adulto Cuidados Básicos"),
    ("Complejo Hospitalario San José (Santiago, Independencia)", "401 - Área Médica Adulto Cuidados Básicos"),
    ("Hospital Carlos Van Buren (Valparaíso)", "401 - Área Médica Adulto Cuidados Básicos"),
    ("Hospital Clínico Herminda Martín (Chillán)", "401 - Área Médica Adulto Cuidados Básicos"),
    ("Hospital El Pino (Santiago, San Bernardo)", "401 - Área Médica Adulto Cuidados Básicos"),
]

# Diccionario para almacenar resultados
resultados_todos = {}

# Evaluar cada hospital
for hospital, area in hospitales_a_evaluar:
    print("\n==========================")
    print(f"🏥 Evaluando: {hospital}")
    print("==========================")
    resultados = pipeline_final_mae_reducido(hospital, area)
    if resultados is not None:
        resultados_todos[hospital] = resultados

# Mostrar un ejemplo del primer hospital evaluado
primer_hospital = list(resultados_todos.keys())[0]
resultados_todos[primer_hospital].head()
# Out:
# ==========================
# 🏥 Evaluando: Hospital Barros Luco Trudeau (Santiago, San Miguel)
# ==========================
# 🔍 Extrayendo datos para: Hospital Barros Luco Trudeau (Santiago, San Miguel) | 401 - Área Médica Adulto Cuidados Básicos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 67.76
# ✅ RMSE (camas): 88.44
# 📉 Error promedio porcentual: 3.06%
#
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia)
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | 401 - Área Médica Adulto Cuidados Básicos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 67.90
# ✅ RMSE (camas): 96.07
# 📉 Error promedio porcentual: 3.34%
#
# ==========================
# 🏥 Evaluando: Hospital Carlos Van Buren (Valparaíso)
# ==========================
# 🔍 Extrayendo datos para: Hospital Carlos Van Buren (Valparaíso) | 401 - Área Médica Adulto Cuidados Básicos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 50.13
# ✅ RMSE (camas): 65.11
# 📉 Error promedio porcentual: 1.92%
#
# ==========================
# 🏥 Evaluando: Hospital Clínico Herminda Martín (Chillán)
# ==========================
# 🔍 Extrayendo datos para: Hospital Clínico Herminda Martín (Chillán) | 401 - Área Médica Adulto Cuidados Básicos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 280.88
# ✅ RMSE (camas): 319.47
# 📉 Error promedio porcentual: 13.43%
#
# ==========================
# 🏥 Evaluando: Hospital El Pino (Santiago, San Bernardo)
# ==========================
# 🔍 Extrayendo datos para: Hospital El Pino (Santiago, San Bernardo) | 401 - Área Médica Adulto Cuidados Básicos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 25.62
# ✅ RMSE (camas): 30.84
# 📉 Error promedio porcentual: 2.46%
#        Fecha    Real     Predicho  Error Absoluto  Error Porcentual (%)
# 0 2023-05-01  2329.0  2265.841309       63.158691              2.711837
# 1 2023-06-01  2250.0  2222.516602       27.483398              1.221484
# 2 2023-07-01  2325.0  2253.972656       71.027344              3.054940
# 3 2023-08-01  2325.0  2261.367676       63.632324              2.736874
# 4 2023-09-01  2252.0  2246.199951        5.800049              0.257551

# %%
# Función para extraer todos los pares únicos (hospital, área) desde los datos combinados
def extraer_hospitales_y_areas_validos(combinados):
    pares_hospital_area = set()

    for df in combinados.values():
        if "Nombre Establecimiento" in df.columns and "Area" in df.columns:
            pares = df[["Nombre Establecimiento", "Area"]].dropna().drop_duplicates()
            for _, row in pares.iterrows():
                pares_hospital_area.add((row["Nombre Establecimiento"], row["Area"]))

    return sorted(list(pares_hospital_area))

# Extraer todos los hospitales y áreas válidos
hospitales_areas_validos = extraer_hospitales_y_areas_validos(combinados)

# Mostrar los primeros 10 pares para verificar
hospitales_areas_validos[:10]
# Out:
# [('Complejo Hospitalario San José (Santiago, Independencia)',
#   '330 - Área Pensionado'),
#  ('Complejo Hospitalario San José (Santiago, Independencia)',
#   '401 - Área Médica Adulto Cuidados Básicos'),
#  ('Complejo Hospitalario San José (Santiago, Independencia)',
#   '402 - Área Médica Adulto Cuidados Medios'),
#  ('Complejo Hospitalario San José (Santiago, Independencia)',
#   '403 - Área Médico-Quirúrgico Cuidados Básicos'),
#  ('Complejo Hospitalario San José (Santiago, Independencia)',
#   '404 - Área Médico-Quirúrgico Cuidados Medios'),
#  ('Complejo Hospitalario San José (Santiago, Independencia)',
#   '405 - Área Cuidados Intensivos Adultos'),
#  ('Complejo Hospitalario San José (Santiago, Independencia)',
#   '406 - Área Cuidados Intermedios Adultos'),
#  ('Complejo Hospitalario San José (Santiago, Independencia)',
#   '413 - Área Neonatología Cuidados Básicos'),
#  ('Complejo Hospitalario San José (Santiago, Independencia)',
#   '414 - Área Neonatología Cuidados Intensivos'),
#  ('Complejo Hospitalario San José (Santiago, Independencia)',
#   '415 - Área Neonatología Cuidados Intermedios')]

# %%
import numpy as np

# Evaluar solo los primeros 30 hospitales y su primera área válida
resultados_todos = {}
pares_a_evaluar = hospitales_areas_validos[:30]

for hospital, area in pares_a_evaluar:
    try:
        print("\n==========================")
        print(f"🏥 Evaluando: {hospital} | Área: {area}")
        print("==========================")
        resultados = pipeline_final_mae_reducido(hospital, area)
        if resultados is not None:
            resultados_todos[f"{hospital} | {area}"] = resultados
    except Exception as e:
        print(f"❌ Error en {hospital} con área {area}: {e}")
        continue

# Crear resumen comparativo de MAE y error porcentual
resumen_comparativo = []

for nombre_completo, resultados in resultados_todos.items():
    if "Error Absoluto" in resultados.columns and "Error Porcentual (%)" in resultados.columns:
        mae = resultados["Error Absoluto"].mean()
        error_pct = resultados["Error Porcentual (%)"].mean()
        resumen_comparativo.append({
            "Hospital | Área": nombre_completo,
            "MAE (camas)": round(mae, 2),
            "Error Porcentual Promedio (%)": round(error_pct, 2)
        })

df_resumen_comparativo = pd.DataFrame(resumen_comparativo).sort_values("MAE (camas)").reset_index(drop=True)

import ace_tools as tools
tools.display_dataframe_to_user(name="Comparación de desempeño (30 hospitales)", dataframe=df_resumen_comparativo)
# Out:
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: 330 - Área Pensionado
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | 330 - Área Pensionado
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# ❌ No se pudo preparar el dataset.
#
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: 401 - Área Médica Adulto Cuidados Básicos
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | 401 - Área Médica Adulto Cuidados Básicos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 67.90
# ✅ RMSE (camas): 96.07
# 📉 Error promedio porcentual: 3.34%
#
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: 402 - Área Médica Adulto Cuidados Medios
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | 402 - Área Médica Adulto Cuidados Medios
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 9.36
# ✅ RMSE (camas): 18.41
# 📉 Error promedio porcentual: 0.45%
#
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: 403 - Área Médico-Quirúrgico Cuidados Básicos
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | 403 - Área Médico-Quirúrgico Cuidados Básicos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 245.66
# ✅ RMSE (camas): 270.78
# 📉 Error promedio porcentual: 5.24%
#
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: 404 - Área Médico-Quirúrgico Cuidados Medios
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | 404 - Área Médico-Quirúrgico Cuidados Medios
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 54.83
# ✅ RMSE (camas): 114.61
# 📉 Error promedio porcentual: 10.26%
#
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: 405 - Área Cuidados Intensivos Adultos
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | 405 - Área Cuidados Intensivos Adultos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 62.36
# ✅ RMSE (camas): 71.00
# 📉 Error promedio porcentual: 6.05%
#
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: 406 - Área Cuidados Intermedios Adultos
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | 406 - Área Cuidados Intermedios Adultos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 82.90
# ✅ RMSE (camas): 185.03
# 📉 Error promedio porcentual: 5.32%
#
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: 413 - Área Neonatología Cuidados Básicos
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | 413 - Área Neonatología Cuidados Básicos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 7.82
# ✅ RMSE (camas): 12.17
# 📉 Error promedio porcentual: 1.65%
#
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: 414 - Área Neonatología Cuidados Intensivos
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | 414 - Área Neonatología Cuidados Intensivos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 15.56
# ✅ RMSE (camas): 44.97
# 📉 Error promedio porcentual: 6.76%
#
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: 415 - Área Neonatología Cuidados Intermedios
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | 415 - Área Neonatología Cuidados Intermedios
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 10.98
# ✅ RMSE (camas): 18.34
# 📉 Error promedio porcentual: 1.36%
#
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: 416 - Área Obstetricia
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | 416 - Área Obstetricia
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 131.25
# ✅ RMSE (camas): 199.70
# 📉 Error promedio porcentual: 4.65%
#
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: Datos Establecimiento
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 238.07
# ✅ RMSE (camas): 295.47
# 📉 Error promedio porcentual: 1.40%
#
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: Área Cuidados Intensivos Adultos
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | Área Cuidados Intensivos Adultos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 0.78
# ✅ RMSE (camas): 1.24
# 📉 Error promedio porcentual: 0.24%
#
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: Área Cuidados Intermedios Adultos
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | Área Cuidados Intermedios Adultos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 6.56
# ✅ RMSE (camas): 8.76
# 📉 Error promedio porcentual: 0.70%
#
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: Área Médico-Quirúrgico Cuidados Básicos
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | Área Médico-Quirúrgico Cuidados Básicos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 17.54
# ✅ RMSE (camas): 20.17
# 📉 Error promedio porcentual: 0.20%
#
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: Área Médico-Quirúrgico Cuidados Medios
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | Área Médico-Quirúrgico Cuidados Medios
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 57.45
# ✅ RMSE (camas): 68.61
# 📉 Error promedio porcentual: 1.73%
#
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: Área Neonatología Cuidados Básicos
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | Área Neonatología Cuidados Básicos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 5.88
# ✅ RMSE (camas): 6.67
# 📉 Error promedio porcentual: 1.38%
#
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: Área Neonatología Cuidados Intensivos
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | Área Neonatología Cuidados Intensivos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 16.27
# ✅ RMSE (camas): 18.06
# 📉 Error promedio porcentual: 4.12%
#
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: Área Neonatología Cuidados Intermedios
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | Área Neonatología Cuidados Intermedios
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 7.20
# ✅ RMSE (camas): 7.24
# 📉 Error promedio porcentual: 0.84%
#
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: Área Obstetricia
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | Área Obstetricia
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 8.40
# ✅ RMSE (camas): 13.28
# 📉 Error promedio porcentual: 0.23%
#
# ==========================
# 🏥 Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: Área Pensionado
# ==========================
# 🔍 Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | Área Pensionado
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 9.68
# ✅ RMSE (camas): 12.61
# 📉 Error promedio porcentual: 1.58%
#
# ==========================
# 🏥 Evaluando: Hospital Adalberto Steeger (Talagante) | Área: 330 - Area Pensionado
# ==========================
# 🔍 Extrayendo datos para: Hospital Adalberto Steeger (Talagante) | 330 - Area Pensionado
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 46.89
# ✅ RMSE (camas): 74.85
# 📉 Error promedio porcentual: 20.84%
#
# ==========================
# 🏥 Evaluando: Hospital Adalberto Steeger (Talagante) | Área: 330 - Área Pensionado
# ==========================
# 🔍 Extrayendo datos para: Hospital Adalberto Steeger (Talagante) | 330 - Área Pensionado
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 6.05
# ✅ RMSE (camas): 7.25
# 📉 Error promedio porcentual: 1.55%
#
# ==========================
# 🏥 Evaluando: Hospital Adalberto Steeger (Talagante) | Área: 401 - Área Médica Adulto Cuidados Básicos
# ==========================
# 🔍 Extrayendo datos para: Hospital Adalberto Steeger (Talagante) | 401 - Área Médica Adulto Cuidados Básicos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 34.28
# ✅ RMSE (camas): 56.20
# 📉 Error promedio porcentual: 5.59%
#
# ==========================
# 🏥 Evaluando: Hospital Adalberto Steeger (Talagante) | Área: 402 - Área Médica Adulto Cuidados Medios
# ==========================
# 🔍 Extrayendo datos para: Hospital Adalberto Steeger (Talagante) | 402 - Área Médica Adulto Cuidados Medios
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 125.02
# ✅ RMSE (camas): 152.12
# 📉 Error promedio porcentual: 29.75%
#
# ==========================
# 🏥 Evaluando: Hospital Adalberto Steeger (Talagante) | Área: 403 - Área Médico-Quirúrgico Cuidados Básicos
# ==========================
# 🔍 Extrayendo datos para: Hospital Adalberto Steeger (Talagante) | 403 - Área Médico-Quirúrgico Cuidados Básicos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 13.24
# ✅ RMSE (camas): 20.85
# 📉 Error promedio porcentual: 13.87%
#
# ==========================
# 🏥 Evaluando: Hospital Adalberto Steeger (Talagante) | Área: 404 - Área Médico-Quirúrgico Cuidados Medios
# ==========================
# 🔍 Extrayendo datos para: Hospital Adalberto Steeger (Talagante) | 404 - Área Médico-Quirúrgico Cuidados Medios
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 48.27
# ✅ RMSE (camas): 74.36
# 📉 Error promedio porcentual: 2.54%
#
# ==========================
# 🏥 Evaluando: Hospital Adalberto Steeger (Talagante) | Área: 405 - Área Cuidados Intensivos Adultos
# ==========================
# 🔍 Extrayendo datos para: Hospital Adalberto Steeger (Talagante) | 405 - Área Cuidados Intensivos Adultos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 0.91
# ✅ RMSE (camas): 1.64
# 📉 Error promedio porcentual: 0.51%
#
# ==========================
# 🏥 Evaluando: Hospital Adalberto Steeger (Talagante) | Área: 406 - Área Cuidados Intermedios Adultos
# ==========================
# 🔍 Extrayendo datos para: Hospital Adalberto Steeger (Talagante) | 406 - Área Cuidados Intermedios Adultos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 11.90
# ✅ RMSE (camas): 21.78
# 📉 Error promedio porcentual: 2.48%
#
# ==========================
# 🏥 Evaluando: Hospital Adalberto Steeger (Talagante) | Área: 407 - Área Médica Pediátrica Cuidados Básicos
# ==========================
# 🔍 Extrayendo datos para: Hospital Adalberto Steeger (Talagante) | 407 - Área Médica Pediátrica Cuidados Básicos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# 📊 Evaluando sobre el 20% final de los datos...
# ✅ MAE (camas): 17.01
# ✅ RMSE (camas): 21.18
# 📉 Error promedio porcentual: 18.79%
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[63], line 34
#      26         resumen_comparativo.append({
#      27             "Hospital | Área": nombre_completo,
#      28             "MAE (camas)": round(mae, 2),
#      29             "Error Porcentual Promedio (%)": round(error_pct, 2)
#      30         })
#      32 df_resumen_comparativo = pd.DataFrame(resumen_comparativo).sort_values("MAE (camas)").reset_index(drop=True)
# ---> 34 import ace_tools as tools
#      35 tools.display_dataframe_to_user(name="Comparación de desempeño (30 hospitales)", dataframe=df_resumen_comparativo)
#
# ModuleNotFoundError: No module named 'ace_tools'

# %%
# Crear tabla resumen con hospital, área, MAE y porcentaje de error

tabla_resumen = []

for nombre_completo, resultados in resultados_todos.items():
    if "Error Absoluto" in resultados.columns and "Error Porcentual (%)" in resultados.columns:
        hospital, area = nombre_completo.split(" | ", 1)
        mae = resultados["Error Absoluto"].mean()
        error_pct = resultados["Error Porcentual (%)"].mean()
        tabla_resumen.append({
            "Hospital": hospital,
            "Área": area,
            "MAE (camas)": round(mae, 2),
            "Error Porcentual Promedio (%)": round(error_pct, 2)
        })

df_tabla_resumen = pd.DataFrame(tabla_resumen).sort_values("MAE (camas)").reset_index(drop=True)

dataframe=df_tabla_resumen

dataframe
# Out:
#                                              Hospital  \
# 0   Complejo Hospitalario San José (Santiago, Inde...
# 1              Hospital Adalberto Steeger (Talagante)
# 2   Complejo Hospitalario San José (Santiago, Inde...
# 3              Hospital Adalberto Steeger (Talagante)
# 4   Complejo Hospitalario San José (Santiago, Inde...
# 5   Complejo Hospitalario San José (Santiago, Inde...
# 6   Complejo Hospitalario San José (Santiago, Inde...
# 7   Complejo Hospitalario San José (Santiago, Inde...
# 8   Complejo Hospitalario San José (Santiago, Inde...
# 9   Complejo Hospitalario San José (Santiago, Inde...
# 10  Complejo Hospitalario San José (Santiago, Inde...
# 11             Hospital Adalberto Steeger (Talagante)
# 12             Hospital Adalberto Steeger (Talagante)
# 13  Complejo Hospitalario San José (Santiago, Inde...
# 14  Complejo Hospitalario San José (Santiago, Inde...
# 15             Hospital Adalberto Steeger (Talagante)
# 16  Complejo Hospitalario San José (Santiago, Inde...
# 17             Hospital Adalberto Steeger (Talagante)
# 18             Hospital Adalberto Steeger (Talagante)
# 19             Hospital Adalberto Steeger (Talagante)
# 20  Complejo Hospitalario San José (Santiago, Inde...
# 21  Complejo Hospitalario San José (Santiago, Inde...
# 22  Complejo Hospitalario San José (Santiago, Inde...
# 23  Complejo Hospitalario San José (Santiago, Inde...
# 24  Complejo Hospitalario San José (Santiago, Inde...
# 25             Hospital Adalberto Steeger (Talagante)
# 26  Complejo Hospitalario San José (Santiago, Inde...
# 27  Complejo Hospitalario San José (Santiago, Inde...
# 28  Complejo Hospitalario San José (Santiago, Inde...
#
#                                              Área  MAE (camas)  \
# 0                Área Cuidados Intensivos Adultos         0.78
# 1          405 - Área Cuidados Intensivos Adultos         0.91
# 2              Área Neonatología Cuidados Básicos         5.88
# 3                           330 - Área Pensionado         6.05
# 4               Área Cuidados Intermedios Adultos         6.56
# 5          Área Neonatología Cuidados Intermedios         7.20
# 6        413 - Área Neonatología Cuidados Básicos         7.82
# 7                                Área Obstetricia         8.40
# 8        402 - Área Médica Adulto Cuidados Medios         9.36
# 9                                 Área Pensionado         9.68
# 10   415 - Área Neonatología Cuidados Intermedios        10.98
# 11        406 - Área Cuidados Intermedios Adultos        11.90
# 12  403 - Área Médico-Quirúrgico Cuidados Básicos        13.24
# 13    414 - Área Neonatología Cuidados Intensivos        15.56
# 14          Área Neonatología Cuidados Intensivos        16.27
# 15  407 - Área Médica Pediátrica Cuidados Básicos        17.01
# 16        Área Médico-Quirúrgico Cuidados Básicos        17.54
# 17      401 - Área Médica Adulto Cuidados Básicos        34.28
# 18                          330 - Area Pensionado        46.89
# 19   404 - Área Médico-Quirúrgico Cuidados Medios        48.27
# 20   404 - Área Médico-Quirúrgico Cuidados Medios        54.83
# 21         Área Médico-Quirúrgico Cuidados Medios        57.45
# 22         405 - Área Cuidados Intensivos Adultos        62.36
# 23      401 - Área Médica Adulto Cuidados Básicos        67.90
# 24        406 - Área Cuidados Intermedios Adultos        82.90
# 25       402 - Área Médica Adulto Cuidados Medios       125.02
# 26                         416 - Área Obstetricia       131.25
# 27                          Datos Establecimiento       238.07
# 28  403 - Área Médico-Quirúrgico Cuidados Básicos       245.66
#
#     Error Porcentual Promedio (%)
# 0                            0.24
# 1                            0.51
# 2                            1.38
# 3                            1.55
# 4                            0.70
# 5                            0.84
# 6                            1.65
# 7                            0.23
# 8                            0.45
# 9                            1.58
# 10                           1.36
# 11                           2.48
# 12                          13.87
# 13                           6.76
# 14                           4.12
# 15                          18.79
# 16                           0.20
# 17                           5.59
# 18                          20.84
# 19                           2.54
# 20                          10.26
# 21                           1.73
# 22                           6.05
# 23                           3.34
# 24                           5.32
# 25                          29.75
# 26                           4.65
# 27                           1.40
# 28                           5.24

# %%
#######################################
#######################################
##DESDE AQUI, NUEVO MODELO ->LightGBM##
#######################################
#######################################

# %%
# !pip install lightgbm
# Out:
# Requirement already satisfied: lightgbm in /Users/claudiomoravernal/.pyenv/versions/3.10.6/envs/SENDA_Chile/lib/python3.10/site-packages (4.6.0)
# Requirement already satisfied: numpy>=1.17.0 in /Users/claudiomoravernal/.pyenv/versions/3.10.6/envs/SENDA_Chile/lib/python3.10/site-packages (from lightgbm) (2.2.4)
# Requirement already satisfied: scipy in /Users/claudiomoravernal/.pyenv/versions/3.10.6/envs/SENDA_Chile/lib/python3.10/site-packages (from lightgbm) (1.15.2)

# %%
# Importar LightGBM
from lightgbm import LGBMRegressor

# Nueva versión del pipeline usando LightGBM en vez de XGBoost
def pipeline_lightgbm_mae_reducido(hospital, area):
    print(f"🔍 [LGBM] Extrayendo datos para: {hospital} | {area}")
    df_base = extraer_info_hospital_area_todo_el_año(hospital, area)

    if df_base.empty:
        print("❌ No se encontraron datos para el hospital o área especificada.")
        return None

    print("🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...")
    df_modelo = preparar_dataset_climatico(df_base)

    if df_modelo is None or df_modelo.empty:
        print("❌ No se pudo preparar el dataset.")
        return None

    # Selección de features
    features = [
        'Dias Cama Ocupados',
        'Promedio Cama Disponibles',
        'Numero de Egresos',
        'Mes', 'Trimestre',
        'lag_1', 'lag_2',
        'porcentaje_ocupacion',
        'variacion_disponibles',
        'ocupados_media_movil',
        'promedio_media_movil',
        'egresos_media_movil',
        'tasa_egresos',
        'tasa_ocupacion_promedio',
        'variacion_ocupados',
        'variacion_egresos',
        'ocupados_x_temp',
        'egresos_x_precipitacion',
        'ocupacion_pct_x_tempmin',
        'Temperatura Máxima',
        'Temperatura Mínima',
        'Precipitaciones (suma)'
    ] + [col for col in df_modelo.columns if col.startswith('Viento_')]

    # Separar train/test
    X = df_modelo[features]
    y = df_modelo['Dias Cama Disponibles']
    X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=False, test_size=0.2)

    print("🔧 Ajustando modelo LightGBM con GridSearchCV...")
    param_grid = {
        'n_estimators': [50, 100],
        'max_depth': [2, 3],
        'learning_rate': [0.05, 0.1]
    }

    model = LGBMRegressor(n_jobs=1, random_state=42, verbose=-1)

    grid_search = GridSearchCV(
        estimator=model,
        param_grid=param_grid,
        scoring='neg_mean_absolute_error',
        cv=TimeSeriesSplit(n_splits=3),
        verbose=1
    )
    grid_search.fit(X_train, y_train)
    mejor_modelo = grid_search.best_estimator_

    print("📌 [LGBM] Mejores parámetros encontrados:", grid_search.best_params_)

    # Evaluación
    y_pred = mejor_modelo.predict(X_test)
    mae = mean_absolute_error(y_test, y_pred)
    rmse = mean_squared_error(y_test, y_pred) ** 0.5
    error_pct = np.mean(np.abs((y_test.values - y_pred) / y_test.values)) * 100

    resultados = pd.DataFrame({
        'Fecha': df_modelo['Fecha'].iloc[-len(y_test):].values,
        'Real': y_test.values,
        'Predicho': y_pred,
        'Error Absoluto': np.abs(y_test.values - y_pred),
        'Error Porcentual (%)': np.abs((y_test.values - y_pred) / y_test.values) * 100
    })

    print(f"✅ [LGBM] MAE (camas): {mae:.2f}")
    print(f"✅ [LGBM] RMSE (camas): {rmse:.2f}")
    print(f"📉 [LGBM] Error porcentual promedio: {error_pct:.2f}%")

    return resultados

# %%
# Ejecutamos el pipeline LightGBM con un hospital de ejemplo para comparar con XGBoost
hospital = "Hospital Barros Luco Trudeau (Santiago, San Miguel)"
area = "401 - Área Médica Adulto Cuidados Básicos"

resultados_lgbm = pipeline_lightgbm_mae_reducido(hospital, area)

# Mostrar resultados si están disponibles
if resultados_lgbm is not None:
    resultados_lgbm.head()
# Out:
# 🔍 [LGBM] Extrayendo datos para: Hospital Barros Luco Trudeau (Santiago, San Miguel) | 401 - Área Médica Adulto Cuidados Básicos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo LightGBM con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 [LGBM] Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# ✅ [LGBM] MAE (camas): 122.76
# ✅ [LGBM] RMSE (camas): 153.64
# 📉 [LGBM] Error porcentual promedio: 5.72%

# %%
import numpy as np

# Evaluar LightGBM sobre los primeros 30 hospitales y sus áreas
resultados_lgbm_todos = {}
pares_a_evaluar = hospitales_areas_validos[:30]

for hospital, area in pares_a_evaluar:
    try:
        print("\n==========================")
        print(f"🏥 [LGBM] Evaluando: {hospital} | Área: {area}")
        print("==========================")
        resultados = pipeline_lightgbm_mae_reducido(hospital, area)
        if resultados is not None:
            resultados_lgbm_todos[f"{hospital} | {area}"] = resultados
    except Exception as e:
        print(f"❌ Error en {hospital} con área {area}: {e}")
        continue

# Crear tabla resumen de resultados
resumen_lgbm = []

for nombre_completo, resultados in resultados_lgbm_todos.items():
    if "Error Absoluto" in resultados.columns and "Error Porcentual (%)" in resultados.columns:
        hospital, area = nombre_completo.split(" | ", 1)
        mae = resultados["Error Absoluto"].mean()
        error_pct = resultados["Error Porcentual (%)"].mean()
        resumen_lgbm.append({
            "Hospital": hospital,
            "Área": area,
            "MAE (camas)": round(mae, 2),
            "Error Porcentual Promedio (%)": round(error_pct, 2)
        })
# Out:
# ==========================
# 🏥 [LGBM] Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: 330 - Área Pensionado
# ==========================
# 🔍 [LGBM] Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | 330 - Área Pensionado
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# ❌ No se pudo preparar el dataset.
#
# ==========================
# 🏥 [LGBM] Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: 401 - Área Médica Adulto Cuidados Básicos
# ==========================
# 🔍 [LGBM] Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | 401 - Área Médica Adulto Cuidados Básicos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo LightGBM con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 [LGBM] Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# ✅ [LGBM] MAE (camas): 147.25
# ✅ [LGBM] RMSE (camas): 181.52
# 📉 [LGBM] Error porcentual promedio: 7.40%
#
# ==========================
# 🏥 [LGBM] Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: 402 - Área Médica Adulto Cuidados Medios
# ==========================
# 🔍 [LGBM] Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | 402 - Área Médica Adulto Cuidados Medios
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo LightGBM con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 [LGBM] Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# ✅ [LGBM] MAE (camas): 54.64
# ✅ [LGBM] RMSE (camas): 71.72
# 📉 [LGBM] Error porcentual promedio: 2.57%
#
# ==========================
# 🏥 [LGBM] Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: 403 - Área Médico-Quirúrgico Cuidados Básicos
# ==========================
# 🔍 [LGBM] Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | 403 - Área Médico-Quirúrgico Cuidados Básicos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo LightGBM con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 [LGBM] Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# ✅ [LGBM] MAE (camas): 373.97
# ✅ [LGBM] RMSE (camas): 426.44
# 📉 [LGBM] Error porcentual promedio: 7.88%
#
# ==========================
# 🏥 [LGBM] Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: 404 - Área Médico-Quirúrgico Cuidados Medios
# ==========================
# 🔍 [LGBM] Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | 404 - Área Médico-Quirúrgico Cuidados Medios
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo LightGBM con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 [LGBM] Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# ✅ [LGBM] MAE (camas): 172.87
# ✅ [LGBM] RMSE (camas): 234.12
# 📉 [LGBM] Error porcentual promedio: 23.89%
#
# ==========================
# 🏥 [LGBM] Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: 405 - Área Cuidados Intensivos Adultos
# ==========================
# 🔍 [LGBM] Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | 405 - Área Cuidados Intensivos Adultos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo LightGBM con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 [LGBM] Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# ✅ [LGBM] MAE (camas): 121.81
# ✅ [LGBM] RMSE (camas): 186.67
# 📉 [LGBM] Error porcentual promedio: 11.82%
#
# ==========================
# 🏥 [LGBM] Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: 406 - Área Cuidados Intermedios Adultos
# ==========================
# 🔍 [LGBM] Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | 406 - Área Cuidados Intermedios Adultos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo LightGBM con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 [LGBM] Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# ✅ [LGBM] MAE (camas): 77.68
# ✅ [LGBM] RMSE (camas): 90.33
# 📉 [LGBM] Error porcentual promedio: 4.74%
#
# ==========================
# 🏥 [LGBM] Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: 413 - Área Neonatología Cuidados Básicos
# ==========================
# 🔍 [LGBM] Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | 413 - Área Neonatología Cuidados Básicos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo LightGBM con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 [LGBM] Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# ✅ [LGBM] MAE (camas): 14.60
# ✅ [LGBM] RMSE (camas): 15.61
# 📉 [LGBM] Error porcentual promedio: 2.99%
#
# ==========================
# 🏥 [LGBM] Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: 414 - Área Neonatología Cuidados Intensivos
# ==========================
# 🔍 [LGBM] Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | 414 - Área Neonatología Cuidados Intensivos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo LightGBM con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 [LGBM] Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# ✅ [LGBM] MAE (camas): 16.61
# ✅ [LGBM] RMSE (camas): 48.33
# 📉 [LGBM] Error porcentual promedio: 7.28%
#
# ==========================
# 🏥 [LGBM] Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: 415 - Área Neonatología Cuidados Intermedios
# ==========================
# 🔍 [LGBM] Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | 415 - Área Neonatología Cuidados Intermedios
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo LightGBM con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 [LGBM] Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# ✅ [LGBM] MAE (camas): 18.20
# ✅ [LGBM] RMSE (camas): 31.16
# 📉 [LGBM] Error porcentual promedio: 2.28%
#
# ==========================
# 🏥 [LGBM] Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: 416 - Área Obstetricia
# ==========================
# 🔍 [LGBM] Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | 416 - Área Obstetricia
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo LightGBM con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 [LGBM] Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# ✅ [LGBM] MAE (camas): 152.51
# ✅ [LGBM] RMSE (camas): 225.25
# 📉 [LGBM] Error porcentual promedio: 5.41%
#
# ==========================
# 🏥 [LGBM] Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: Datos Establecimiento
# ==========================
# 🔍 [LGBM] Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | Datos Establecimiento
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo LightGBM con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 [LGBM] Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 50}
# ✅ [LGBM] MAE (camas): 337.72
# ✅ [LGBM] RMSE (camas): 433.09
# 📉 [LGBM] Error porcentual promedio: 2.00%
#
# ==========================
# 🏥 [LGBM] Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: Área Cuidados Intensivos Adultos
# ==========================
# 🔍 [LGBM] Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | Área Cuidados Intensivos Adultos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo LightGBM con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 [LGBM] Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# ✅ [LGBM] MAE (camas): 5.59
# ✅ [LGBM] RMSE (camas): 5.60
# 📉 [LGBM] Error porcentual promedio: 1.66%
#
# ==========================
# 🏥 [LGBM] Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: Área Cuidados Intermedios Adultos
# ==========================
# 🔍 [LGBM] Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | Área Cuidados Intermedios Adultos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo LightGBM con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 [LGBM] Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# ✅ [LGBM] MAE (camas): 14.92
# ✅ [LGBM] RMSE (camas): 21.14
# 📉 [LGBM] Error porcentual promedio: 1.60%
#
# ==========================
# 🏥 [LGBM] Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: Área Médico-Quirúrgico Cuidados Básicos
# ==========================
# 🔍 [LGBM] Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | Área Médico-Quirúrgico Cuidados Básicos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo LightGBM con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 [LGBM] Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# ✅ [LGBM] MAE (camas): 148.96
# ✅ [LGBM] RMSE (camas): 152.11
# 📉 [LGBM] Error porcentual promedio: 1.67%
#
# ==========================
# 🏥 [LGBM] Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: Área Médico-Quirúrgico Cuidados Medios
# ==========================
# 🔍 [LGBM] Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | Área Médico-Quirúrgico Cuidados Medios
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo LightGBM con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 [LGBM] Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# ✅ [LGBM] MAE (camas): 183.45
# ✅ [LGBM] RMSE (camas): 219.61
# 📉 [LGBM] Error porcentual promedio: 5.92%
#
# ==========================
# 🏥 [LGBM] Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: Área Neonatología Cuidados Básicos
# ==========================
# 🔍 [LGBM] Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | Área Neonatología Cuidados Básicos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo LightGBM con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 [LGBM] Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# ✅ [LGBM] MAE (camas): 48.89
# ✅ [LGBM] RMSE (camas): 49.37
# 📉 [LGBM] Error porcentual promedio: 11.44%
#
# ==========================
# 🏥 [LGBM] Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: Área Neonatología Cuidados Intensivos
# ==========================
# 🔍 [LGBM] Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | Área Neonatología Cuidados Intensivos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo LightGBM con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 [LGBM] Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# ✅ [LGBM] MAE (camas): 28.56
# ✅ [LGBM] RMSE (camas): 29.27
# 📉 [LGBM] Error porcentual promedio: 7.16%
#
# ==========================
# 🏥 [LGBM] Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: Área Neonatología Cuidados Intermedios
# ==========================
# 🔍 [LGBM] Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | Área Neonatología Cuidados Intermedios
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo LightGBM con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 [LGBM] Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# ✅ [LGBM] MAE (camas): 28.68
# ✅ [LGBM] RMSE (camas): 31.79
# 📉 [LGBM] Error porcentual promedio: 3.32%
#
# ==========================
# 🏥 [LGBM] Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: Área Obstetricia
# ==========================
# 🔍 [LGBM] Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | Área Obstetricia
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo LightGBM con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 [LGBM] Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# ✅ [LGBM] MAE (camas): 59.05
# ✅ [LGBM] RMSE (camas): 60.70
# 📉 [LGBM] Error porcentual promedio: 1.60%
#
# ==========================
# 🏥 [LGBM] Evaluando: Complejo Hospitalario San José (Santiago, Independencia) | Área: Área Pensionado
# ==========================
# 🔍 [LGBM] Extrayendo datos para: Complejo Hospitalario San José (Santiago, Independencia) | Área Pensionado
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo LightGBM con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 [LGBM] Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# ✅ [LGBM] MAE (camas): 11.84
# ✅ [LGBM] RMSE (camas): 15.18
# 📉 [LGBM] Error porcentual promedio: 1.91%
#
# ==========================
# 🏥 [LGBM] Evaluando: Hospital Adalberto Steeger (Talagante) | Área: 330 - Area Pensionado
# ==========================
# 🔍 [LGBM] Extrayendo datos para: Hospital Adalberto Steeger (Talagante) | 330 - Area Pensionado
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo LightGBM con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 [LGBM] Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# ✅ [LGBM] MAE (camas): 112.06
# ✅ [LGBM] RMSE (camas): 146.26
# 📉 [LGBM] Error porcentual promedio: 71.77%
#
# ==========================
# 🏥 [LGBM] Evaluando: Hospital Adalberto Steeger (Talagante) | Área: 330 - Área Pensionado
# ==========================
# 🔍 [LGBM] Extrayendo datos para: Hospital Adalberto Steeger (Talagante) | 330 - Área Pensionado
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo LightGBM con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 [LGBM] Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# ✅ [LGBM] MAE (camas): 10.44
# ✅ [LGBM] RMSE (camas): 13.48
# 📉 [LGBM] Error porcentual promedio: 2.69%
#
# ==========================
# 🏥 [LGBM] Evaluando: Hospital Adalberto Steeger (Talagante) | Área: 401 - Área Médica Adulto Cuidados Básicos
# ==========================
# 🔍 [LGBM] Extrayendo datos para: Hospital Adalberto Steeger (Talagante) | 401 - Área Médica Adulto Cuidados Básicos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo LightGBM con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 [LGBM] Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# ✅ [LGBM] MAE (camas): 52.80
# ✅ [LGBM] RMSE (camas): 81.21
# 📉 [LGBM] Error porcentual promedio: 9.16%
#
# ==========================
# 🏥 [LGBM] Evaluando: Hospital Adalberto Steeger (Talagante) | Área: 402 - Área Médica Adulto Cuidados Medios
# ==========================
# 🔍 [LGBM] Extrayendo datos para: Hospital Adalberto Steeger (Talagante) | 402 - Área Médica Adulto Cuidados Medios
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo LightGBM con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 [LGBM] Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# ✅ [LGBM] MAE (camas): 127.08
# ✅ [LGBM] RMSE (camas): 154.55
# 📉 [LGBM] Error porcentual promedio: 32.82%
#
# ==========================
# 🏥 [LGBM] Evaluando: Hospital Adalberto Steeger (Talagante) | Área: 403 - Área Médico-Quirúrgico Cuidados Básicos
# ==========================
# 🔍 [LGBM] Extrayendo datos para: Hospital Adalberto Steeger (Talagante) | 403 - Área Médico-Quirúrgico Cuidados Básicos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo LightGBM con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 [LGBM] Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# ✅ [LGBM] MAE (camas): 159.70
# ✅ [LGBM] RMSE (camas): 163.26
# 📉 [LGBM] Error porcentual promedio: 140.76%
#
# ==========================
# 🏥 [LGBM] Evaluando: Hospital Adalberto Steeger (Talagante) | Área: 404 - Área Médico-Quirúrgico Cuidados Medios
# ==========================
# 🔍 [LGBM] Extrayendo datos para: Hospital Adalberto Steeger (Talagante) | 404 - Área Médico-Quirúrgico Cuidados Medios
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo LightGBM con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 [LGBM] Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50}
# ✅ [LGBM] MAE (camas): 562.49
# ✅ [LGBM] RMSE (camas): 568.78
# 📉 [LGBM] Error porcentual promedio: 30.19%
#
# ==========================
# 🏥 [LGBM] Evaluando: Hospital Adalberto Steeger (Talagante) | Área: 405 - Área Cuidados Intensivos Adultos
# ==========================
# 🔍 [LGBM] Extrayendo datos para: Hospital Adalberto Steeger (Talagante) | 405 - Área Cuidados Intensivos Adultos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo LightGBM con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 [LGBM] Mejores parámetros encontrados: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 100}
# ✅ [LGBM] MAE (camas): 11.14
# ✅ [LGBM] RMSE (camas): 13.54
# 📉 [LGBM] Error porcentual promedio: 6.13%
#
# ==========================
# 🏥 [LGBM] Evaluando: Hospital Adalberto Steeger (Talagante) | Área: 406 - Área Cuidados Intermedios Adultos
# ==========================
# 🔍 [LGBM] Extrayendo datos para: Hospital Adalberto Steeger (Talagante) | 406 - Área Cuidados Intermedios Adultos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo LightGBM con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 [LGBM] Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# ✅ [LGBM] MAE (camas): 75.61
# ✅ [LGBM] RMSE (camas): 94.30
# 📉 [LGBM] Error porcentual promedio: 19.86%
#
# ==========================
# 🏥 [LGBM] Evaluando: Hospital Adalberto Steeger (Talagante) | Área: 407 - Área Médica Pediátrica Cuidados Básicos
# ==========================
# 🔍 [LGBM] Extrayendo datos para: Hospital Adalberto Steeger (Talagante) | 407 - Área Médica Pediátrica Cuidados Básicos
# 🧪 Preparando dataset con variables hospitalarias, climáticas y derivadas...
# 🔧 Ajustando modelo LightGBM con GridSearchCV...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# 📌 [LGBM] Mejores parámetros encontrados: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# ✅ [LGBM] MAE (camas): 105.78
# ✅ [LGBM] RMSE (camas): 126.42
# 📉 [LGBM] Error porcentual promedio: 61.53%
#                                              Hospital  \
# 0   Complejo Hospitalario San José (Santiago, Inde...
# 1              Hospital Adalberto Steeger (Talagante)
# 2              Hospital Adalberto Steeger (Talagante)
# 3   Complejo Hospitalario San José (Santiago, Inde...
# 4   Complejo Hospitalario San José (Santiago, Inde...
# 5   Complejo Hospitalario San José (Santiago, Inde...
# 6   Complejo Hospitalario San José (Santiago, Inde...
# 7   Complejo Hospitalario San José (Santiago, Inde...
# 8   Complejo Hospitalario San José (Santiago, Inde...
# 9   Complejo Hospitalario San José (Santiago, Inde...
# 10  Complejo Hospitalario San José (Santiago, Inde...
# 11             Hospital Adalberto Steeger (Talagante)
# 12  Complejo Hospitalario San José (Santiago, Inde...
# 13  Complejo Hospitalario San José (Santiago, Inde...
# 14             Hospital Adalberto Steeger (Talagante)
# 15  Complejo Hospitalario San José (Santiago, Inde...
# 16             Hospital Adalberto Steeger (Talagante)
# 17             Hospital Adalberto Steeger (Talagante)
# 18  Complejo Hospitalario San José (Santiago, Inde...
# 19             Hospital Adalberto Steeger (Talagante)
# 20  Complejo Hospitalario San José (Santiago, Inde...
# 21  Complejo Hospitalario San José (Santiago, Inde...
# 22  Complejo Hospitalario San José (Santiago, Inde...
# 23             Hospital Adalberto Steeger (Talagante)
# 24  Complejo Hospitalario San José (Santiago, Inde...
# 25  Complejo Hospitalario San José (Santiago, Inde...
# 26  Complejo Hospitalario San José (Santiago, Inde...
# 27  Complejo Hospitalario San José (Santiago, Inde...
# 28             Hospital Adalberto Steeger (Talagante)
#
#                                              Área  MAE (camas)  \
# 0                Área Cuidados Intensivos Adultos         5.59
# 1                           330 - Área Pensionado        10.44
# 2          405 - Área Cuidados Intensivos Adultos        11.14
# 3                                 Área Pensionado        11.84
# 4        413 - Área Neonatología Cuidados Básicos        14.60
# 5               Área Cuidados Intermedios Adultos        14.92
# 6     414 - Área Neonatología Cuidados Intensivos        16.61
# 7    415 - Área Neonatología Cuidados Intermedios        18.20
# 8           Área Neonatología Cuidados Intensivos        28.56
# 9          Área Neonatología Cuidados Intermedios        28.68
# 10             Área Neonatología Cuidados Básicos        48.89
# 11      401 - Área Médica Adulto Cuidados Básicos        52.80
# 12       402 - Área Médica Adulto Cuidados Medios        54.64
# 13                               Área Obstetricia        59.05
# 14        406 - Área Cuidados Intermedios Adultos        75.61
# 15        406 - Área Cuidados Intermedios Adultos        77.68
# 16  407 - Área Médica Pediátrica Cuidados Básicos       105.78
# 17                          330 - Area Pensionado       112.06
# 18         405 - Área Cuidados Intensivos Adultos       121.81
# 19       402 - Área Médica Adulto Cuidados Medios       127.08
# 20      401 - Área Médica Adulto Cuidados Básicos       147.25
# 21        Área Médico-Quirúrgico Cuidados Básicos       148.96
# 22                         416 - Área Obstetricia       152.51
# 23  403 - Área Médico-Quirúrgico Cuidados Básicos       159.70
# 24   404 - Área Médico-Quirúrgico Cuidados Medios       172.87
# 25         Área Médico-Quirúrgico Cuidados Medios       183.45
# 26                          Datos Establecimiento       337.72
# 27  403 - Área Médico-Quirúrgico Cuidados Básicos       373.97
# 28   404 - Área Médico-Quirúrgico Cuidados Medios       562.49
#
#     Error Porcentual Promedio (%)
# 0                            1.66
# 1                            2.69
# 2                            6.13
# 3                            1.91
# 4                            2.99
# 5                            1.60
# 6                            7.28
# 7                            2.28
# 8                            7.16
# 9                            3.32
# 10                          11.44
# 11                           9.16
# 12                           2.57
# 13                           1.60
# 14                          19.86
# 15                           4.74
# 16                          61.53
# 17                          71.77
# 18                          11.82
# 19                          32.82
# 20                           7.40
# 21                           1.67
# 22                           5.41
# 23                         140.76
# 24                          23.89
# 25                           5.92
# 26                           2.00
# 27                           7.88
# 28                          30.19

# %%
# Mostrar tabla ordenada
df_resumen_lgbm = pd.DataFrame(resumen_lgbm).sort_values("MAE (camas)").reset_index(drop=True)

dataframe2=df_resumen_lgbm
dataframe2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 2
#       1 # Mostrar tabla ordenada
# ----> 2 df_resumen_lgbm = pd.DataFrame(resumen_lgbm).sort_values("MAE (camas)").reset_index(drop=True)
#       4 dataframe2=df_resumen_lgbm
#       5 dataframe2
#
# NameError: name 'resumen_lgbm' is not defined

# %%
# Generar tabla resumen de LightGBM (vuelve a correr esta si es necesario)
resumen_lgbm = []

for nombre_completo, resultados in resultados_lgbm_todos.items():
    if "Error Absoluto" in resultados.columns and "Error Porcentual (%)" in resultados.columns:
        hospital, area = nombre_completo.split(" | ", 1)
        mae = resultados["Error Absoluto"].mean()
        error_pct = resultados["Error Porcentual (%)"].mean()
        resumen_lgbm.append({
            "Hospital": hospital,
            "Área": area,
            "MAE (camas)": round(mae, 2),
            "Error Porcentual Promedio (%)": round(error_pct, 2)
        })

df_resumen_lgbm = pd.DataFrame(resumen_lgbm).sort_values("MAE (camas)").reset_index(drop=True)

# %%
# Comparar XGBoost vs LightGBM en MAE
df_comparacion = pd.merge(
    df_tabla_resumen,
    df_resumen_lgbm,
    on=["Hospital", "Área"],
    suffixes=("_XGBoost", "_LightGBM")
)

# Determinar modelo ganador
df_comparacion["Modelo Ganador (MAE)"] = df_comparacion.apply(
    lambda row: "XGBoost" if row["MAE (camas)_XGBoost"] < row["MAE (camas)_LightGBM"] else "LightGBM",
    axis=1
)

df_comparacion["Diferencia MAE"] = (
    df_comparacion["MAE (camas)_XGBoost"] - df_comparacion["MAE (camas)_LightGBM"]
).round(2)

dataframe=df_comparacion
dataframe
# Out:
#                                              Hospital  \
# 0   Complejo Hospitalario San José (Santiago, Inde...
# 1              Hospital Adalberto Steeger (Talagante)
# 2   Complejo Hospitalario San José (Santiago, Inde...
# 3              Hospital Adalberto Steeger (Talagante)
# 4   Complejo Hospitalario San José (Santiago, Inde...
# 5   Complejo Hospitalario San José (Santiago, Inde...
# 6   Complejo Hospitalario San José (Santiago, Inde...
# 7   Complejo Hospitalario San José (Santiago, Inde...
# 8   Complejo Hospitalario San José (Santiago, Inde...
# 9   Complejo Hospitalario San José (Santiago, Inde...
# 10  Complejo Hospitalario San José (Santiago, Inde...
# 11             Hospital Adalberto Steeger (Talagante)
# 12             Hospital Adalberto Steeger (Talagante)
# 13  Complejo Hospitalario San José (Santiago, Inde...
# 14  Complejo Hospitalario San José (Santiago, Inde...
# 15             Hospital Adalberto Steeger (Talagante)
# 16  Complejo Hospitalario San José (Santiago, Inde...
# 17             Hospital Adalberto Steeger (Talagante)
# 18             Hospital Adalberto Steeger (Talagante)
# 19             Hospital Adalberto Steeger (Talagante)
# 20  Complejo Hospitalario San José (Santiago, Inde...
# 21  Complejo Hospitalario San José (Santiago, Inde...
# 22  Complejo Hospitalario San José (Santiago, Inde...
# 23  Complejo Hospitalario San José (Santiago, Inde...
# 24  Complejo Hospitalario San José (Santiago, Inde...
# 25             Hospital Adalberto Steeger (Talagante)
# 26  Complejo Hospitalario San José (Santiago, Inde...
# 27  Complejo Hospitalario San José (Santiago, Inde...
# 28  Complejo Hospitalario San José (Santiago, Inde...
#
#                                              Área  MAE (camas)_XGBoost  \
# 0                Área Cuidados Intensivos Adultos                 0.78
# 1          405 - Área Cuidados Intensivos Adultos                 0.91
# 2              Área Neonatología Cuidados Básicos                 5.88
# 3                           330 - Área Pensionado                 6.05
# 4               Área Cuidados Intermedios Adultos                 6.56
# 5          Área Neonatología Cuidados Intermedios                 7.20
# 6        413 - Área Neonatología Cuidados Básicos                 7.82
# 7                                Área Obstetricia                 8.40
# 8        402 - Área Médica Adulto Cuidados Medios                 9.36
# 9                                 Área Pensionado                 9.68
# 10   415 - Área Neonatología Cuidados Intermedios                10.98
# 11        406 - Área Cuidados Intermedios Adultos                11.90
# 12  403 - Área Médico-Quirúrgico Cuidados Básicos                13.24
# 13    414 - Área Neonatología Cuidados Intensivos                15.56
# 14          Área Neonatología Cuidados Intensivos                16.27
# 15  407 - Área Médica Pediátrica Cuidados Básicos                17.01
# 16        Área Médico-Quirúrgico Cuidados Básicos                17.54
# 17      401 - Área Médica Adulto Cuidados Básicos                34.28
# 18                          330 - Area Pensionado                46.89
# 19   404 - Área Médico-Quirúrgico Cuidados Medios                48.27
# 20   404 - Área Médico-Quirúrgico Cuidados Medios                54.83
# 21         Área Médico-Quirúrgico Cuidados Medios                57.45
# 22         405 - Área Cuidados Intensivos Adultos                62.36
# 23      401 - Área Médica Adulto Cuidados Básicos                67.90
# 24        406 - Área Cuidados Intermedios Adultos                82.90
# 25       402 - Área Médica Adulto Cuidados Medios               125.02
# 26                         416 - Área Obstetricia               131.25
# 27                          Datos Establecimiento               238.07
# 28  403 - Área Médico-Quirúrgico Cuidados Básicos               245.66
#
#     Error Porcentual Promedio (%)_XGBoost  MAE (camas)_LightGBM  \
# 0                                    0.24                  5.59
# 1                                    0.51                 11.14
# 2                                    1.38                 48.89
# 3                                    1.55                 10.44
# 4                                    0.70                 14.92
# 5                                    0.84                 28.68
# 6                                    1.65                 14.60
# 7                                    0.23                 59.05
# 8                                    0.45                 54.64
# 9                                    1.58                 11.84
# 10                                   1.36                 18.20
# 11                                   2.48                 75.61
# 12                                  13.87                159.70
# 13                                   6.76                 16.61
# 14                                   4.12                 28.56
# 15                                  18.79                105.78
# 16                                   0.20                148.96
# 17                                   5.59                 52.80
# 18                                  20.84                112.06
# 19                                   2.54                562.49
# 20                                  10.26                172.87
# 21                                   1.73                183.45
# 22                                   6.05                121.81
# 23                                   3.34                147.25
# 24                                   5.32                 77.68
# 25                                  29.75                127.08
# 26                                   4.65                152.51
# 27                                   1.40                337.72
# 28                                   5.24                373.97
#
#     Error Porcentual Promedio (%)_LightGBM Modelo Ganador (MAE)  \
# 0                                     1.66              XGBoost
# 1                                     6.13              XGBoost
# 2                                    11.44              XGBoost
# 3                                     2.69              XGBoost
# 4                                     1.60              XGBoost
# 5                                     3.32              XGBoost
# 6                                     2.99              XGBoost
# 7                                     1.60              XGBoost
# 8                                     2.57              XGBoost
# 9                                     1.91              XGBoost
# 10                                    2.28              XGBoost
# 11                                   19.86              XGBoost
# 12                                  140.76              XGBoost
# 13                                    7.28              XGBoost
# 14                                    7.16              XGBoost
# 15                                   61.53              XGBoost
# 16                                    1.67              XGBoost
# 17                                    9.16              XGBoost
# 18                                   71.77              XGBoost
# 19                                   30.19              XGBoost
# 20                                   23.89              XGBoost
# 21                                    5.92              XGBoost
# 22                                   11.82              XGBoost
# 23                                    7.40              XGBoost
# 24                                    4.74             LightGBM
# 25                                   32.82              XGBoost
# 26                                    5.41              XGBoost
# 27                                    2.00              XGBoost
# 28                                    7.88              XGBoost
#
#     Diferencia MAE
# 0            -4.81
# 1           -10.23
# 2           -43.01
# 3            -4.39
# 4            -8.36
# 5           -21.48
# 6            -6.78
# 7           -50.65
# 8           -45.28
# 9            -2.16
# 10           -7.22
# 11          -63.71
# 12         -146.46
# 13           -1.05
# 14          -12.29
# 15          -88.77
# 16         -131.42
# 17          -18.52
# 18          -65.17
# 19         -514.22
# 20         -118.04
# 21         -126.00
# 22          -59.45
# 23          -79.35
# 24            5.22
# 25           -2.06
# 26          -21.26
# 27          -99.65
# 28         -128.31

# %%
#######################################
#######################################
##DESDE AQUI, PROBAR NUEVAS FEATURES###
#######################################
#######################################

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV, train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
import pandas as pd
import numpy as np

# Lista de hospitales a evaluar
hospitales_a_evaluar = [
    "Hospital Barros Luco Trudeau (Santiago, San Miguel)",
    "Hospital Dr. Ernesto Torres Galdames (Iquique)",
    "Complejo Hospitalario San José (Santiago, Independencia)",
    "Hospital Carlos Van Buren (Valparaíso)",
    "Hospital Clínico Herminda Martín (Chillán)",
    "Hospital El Pino (Santiago, San Bernardo)",
    "Hospital de Puerto Montt",
    "Hospital Regional de Antofagasta",
    "Hospital de Coquimbo",
    "Hospital de Talca"
]

# Esta área será usada para todos por simplicidad (puedes personalizar)
area_default = "401 - Área Médica Adulto Cuidados Básicos"

# Función principal ya definida antes, ahora la aplicamos masivamente
def evaluar_modelo_con_estacionalidad(hospital, area):
    df_largo = extraer_info_hospital_area_todo_el_año(hospital, area)
    if df_largo.empty:
        return None

    df_pivot = df_largo.pivot(index='Fecha', columns='Glosa', values='Valor').reset_index()
    columnas_necesarias = ['Dias Cama Disponibles', 'Dias Cama Ocupados',
                           'Promedio Cama Disponibles', 'Numero de Egresos']
    if not all(col in df_pivot.columns for col in columnas_necesarias):
        return None

    df_pivot = df_pivot.sort_values('Fecha')
    df_pivot['Mes'] = df_pivot['Fecha'].dt.month
    df_pivot['Trimestre'] = df_pivot['Fecha'].dt.quarter
    df_pivot['lag_1'] = df_pivot['Dias Cama Disponibles'].shift(1)
    df_pivot['lag_2'] = df_pivot['Dias Cama Disponibles'].shift(2)
    df_pivot['porcentaje_ocupacion'] = df_pivot['Dias Cama Ocupados'] / df_pivot['Dias Cama Disponibles']
    df_pivot['variacion_disponibles'] = df_pivot['Dias Cama Disponibles'].diff()
    df_pivot['ocupados_media_movil'] = df_pivot['Dias Cama Ocupados'].rolling(window=3).mean()
    df_pivot['promedio_media_movil'] = df_pivot['Promedio Cama Disponibles'].rolling(window=3).mean()
    df_pivot['egresos_media_movil'] = df_pivot['Numero de Egresos'].rolling(window=3).mean()
    df_pivot['same_month_last_year'] = df_pivot['Dias Cama Disponibles'].shift(12)
    df_pivot['hist_avg_mes'] = df_pivot.groupby('Mes')['Dias Cama Disponibles'].transform('mean')
    df_modelo = df_pivot.dropna().copy()

    features = [
        'Dias Cama Ocupados',
        'Promedio Cama Disponibles',
        'Numero de Egresos',
        'Mes', 'Trimestre',
        'lag_1', 'lag_2',
        'porcentaje_ocupacion',
        'variacion_disponibles',
        'ocupados_media_movil',
        'promedio_media_movil',
        'egresos_media_movil',
        'same_month_last_year',
        'hist_avg_mes'
    ]

    X = df_modelo[features]
    y = df_modelo['Dias Cama Disponibles']
    X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=False, test_size=0.2)

    tscv = TimeSeriesSplit(n_splits=3)
    param_grid = {
        'n_estimators': [50, 100],
        'max_depth': [2, 3],
        'learning_rate': [0.05, 0.1]
    }
    modelo_xgb = XGBRegressor(n_jobs=1, random_state=42)
    grid_search = GridSearchCV(modelo_xgb, param_grid, scoring='neg_mean_absolute_error', cv=tscv, verbose=0)
    grid_search.fit(X_train, y_train)

    mejor_modelo = grid_search.best_estimator_
    y_pred = mejor_modelo.predict(X_test)

    resultados = pd.DataFrame({
        'Fecha': df_modelo['Fecha'].iloc[-len(y_test):].values,
        'Real': y_test.values,
        'Predicho': y_pred,
        'Error Absoluto': np.abs(y_test.values - y_pred),
        'Error Porcentual (%)': np.abs((y_test.values - y_pred) / y_test.values) * 100
    })

    resumen = {
        "Hospital": hospital,
        "Área": area,
        "MAE": mean_absolute_error(y_test, y_pred),
        "Error %": np.mean(resultados['Error Porcentual (%)'])
    }

    return resumen

# Evaluar para todos los hospitales
resultados_multiples = []
for hosp in hospitales_a_evaluar:
    resultado = evaluar_modelo_con_estacionalidad(hosp, area_default)
    if resultado:
        resultados_multiples.append(resultado)

dataframe_result=df_resultados_hospitales

dataframe_result
# Out:
# ⚠️ No se encontraron datos para ese hospital y área.
# ⚠️ No se encontraron datos para ese hospital y área.
# ⚠️ No se encontraron datos para ese hospital y área.
# ⚠️ No se encontraron datos para ese hospital y área.
#                                             Hospital  \
# 0  Hospital Barros Luco Trudeau (Santiago, San Mi...
# 1  Complejo Hospitalario San José (Santiago, Inde...
# 2             Hospital Carlos Van Buren (Valparaíso)
# 3         Hospital Clínico Herminda Martín (Chillán)
# 4          Hospital El Pino (Santiago, San Bernardo)
# 5                           Hospital de Puerto Montt
#
#                                         Área         MAE    Error %
# 0  401 - Área Médica Adulto Cuidados Básicos   60.805017   2.845284
# 1  401 - Área Médica Adulto Cuidados Básicos  194.859090   9.504034
# 2  401 - Área Médica Adulto Cuidados Básicos   38.057153   1.452190
# 3  401 - Área Médica Adulto Cuidados Básicos  205.300684  10.085671
# 4  401 - Área Médica Adulto Cuidados Básicos   19.791855   1.921970
# 5  401 - Área Médica Adulto Cuidados Básicos  197.631835  65.040586

# %%
# Crear tabla resumen desde resultados del nuevo modelo con estacionalidad
tabla_resumen_estacionalidad = []

for nombre_completo, resultados in resumen.items():
    if isinstance(resultados, pd.DataFrame) and \
       "Error Absoluto" in resultados.columns and \
       "Error Porcentual (%)" in resultados.columns:
        
        hospital, area = nombre_completo.split(" | ", 1)
        mae = resultados["Error Absoluto"].mean()
        error_pct = resultados["Error Porcentual (%)"].mean()
        
        tabla_resumen_estacionalidad.append({
            "Hospital": hospital,
            "Área": area,
            "MAE (camas)": round(mae, 2),
            "Error Porcentual Promedio (%)": round(error_pct, 2)
        })

df_tabla_resumen_estacionalidad = (
    pd.DataFrame(tabla_resumen_estacionalidad)
    .sort_values("MAE (camas)")
    .reset_index(drop=True)
)

dataframe=df_tabla_resumen_estacionalidad


df_tabla_resumen_estacionalidad
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[77], line 4
#       1 # Crear tabla resumen desde resultados del nuevo modelo con estacionalidad
#       2 tabla_resumen_estacionalidad = []
# ----> 4 for nombre_completo, resultados in resumen.items():
#       5     if isinstance(resultados, pd.DataFrame) and \
#       6        "Error Absoluto" in resultados.columns and \
#       7        "Error Porcentual (%)" in resultados.columns:
#       9         hospital, area = nombre_completo.split(" | ", 1)
#
# NameError: name 'resumen' is not defined
